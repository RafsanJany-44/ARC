# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Preprocessing_Null_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd



primary_dataset = pd.read_csv('https://raw.githubusercontent.com/RafsanJany-44/Machine-School/main/datasets/penguins.csv')

# %%
primary_dataset.shape
# Out:
# (344, 17)

# %%
primary_dataset.head(5)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %% [markdown]
# #Checking Null/NaN values

# %%
primary_dataset.isnull().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %%
print('Total number of null value:', primary_dataset.isnull().sum().sum())
print('Total number of columns:', primary_dataset.isna().any().sum())
# Out:
# Total number of null value: 363
# Total number of columns: 8

# %%
primary_dataset
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# #Filling nan values with a number

# %%
df1 = primary_dataset.fillna(10)

# %%
df1
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
print('Total number of null value:', df1.isnull().sum().sum())
print('Total number of columns:', df1.isna().any().sum())
# Out:
# Total number of null value: 0
# Total number of columns: 0

# %%
primary_dataset
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# #Filling Null value with next value

# %%
df2 = primary_dataset.fillna(method='bfill')

# %%
df2
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# #Filling Null with previous value

# %%
df3 = primary_dataset.fillna(method='pad')

# %%
df3
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# #Fill Null with previous column value

# %%
df5 = primary_dataset.fillna(method='pad',axis=1)

# %%
print("Total number of row: ",df5.isnull().sum().sum())
print("Total number of columns: ",df5.isna().any().sum())
# Out:
# Total number of row:  0
# Total number of columns:  0

# %% [markdown]
# #Fill Null with next column value

# %%
df6 = primary_dataset.fillna(method='bfill',axis=1)

# %%
print("Total number of row: ",df6.isnull().sum().sum())
print("Total number of columns: ",df6.isna().any().sum())
# Out:
# Total number of row:  327
# Total number of columns:  8

# %%
primary_dataset
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
df6
# Out:
#     studyName Sample Number                              Species  Region  \
# 0     PAL0708             1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708             2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708             3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708             4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708             5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...           ...                                  ...     ...
# 339   PAL0910           120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910           121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910           122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910           123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910           124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# #<font color='coral'>Fill Null for different columns with differents values</font>

# %%
df7 = primary_dataset.fillna({'Delta 15 N (o/oo)': 999,
	                            'Delta 13 C (o/oo)':666})

# %%
df7
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# #<font color='coral'>Filling Null for different columns with mean value of that column values</font>

# %%
df8 = primary_dataset.fillna(value = primary_dataset['Delta 15 N (o/oo)'].mean())

# %%
df9 = primary_dataset.fillna({'Delta 15 N (o/oo)': primary_dataset['Delta 15 N (o/oo)'].mean(),
                              'Delta 13 C (o/oo)': primary_dataset['Delta 13 C (o/oo)'].mean()}) #vvvvvvi

# %%
df9
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
df10 = primary_dataset.dropna().reset_index(drop=True)

# %%
df10
# Out:
#    studyName  Sample Number                              Species  Region  \
# 0    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1    PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2    PAL0708             29  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3    PAL0708             30  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4    PAL0708             39  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5    PAL0809             69  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 6    PAL0809             70  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7    PAL0910            121  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8    PAL0910            122  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9    PAL0910            131  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 10   PAL0910            132  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11   PAL0910            139  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ...
