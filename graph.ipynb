# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


data_lstm = pd.read_csv("/content/lstm_log.csv")
data_rnn = pd.read_csv("/content/rnn_log.csv")


data.head()

x = list(data_lstm["epoch"])

y_lstm_accurecy = list(data_lstm["accuracy"])
y_rnn_accurecy = list(data_rnn['accuracy'])

y_lstm_loss = list(data_lstm["loss"])
y_rnn_loss = list(data_rnn['loss'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (10,7))


plt.plot(x, y_lstm_accurecy, '^-', label='LSTM')
plt.plot(x, y_rnn_accurecy, 'D-', label='RNN')
#plt.plot(x*1.0, y4, '1-', label='NaN values')

plt.xlabel('Epoch')
plt.ylabel('Accueacy')
plt.title('Epoch vs Acuracy')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (10,7))


plt.plot(x, y_lstm_loss, '^-', label='LSTM')
plt.plot(x, y_rnn_loss, 'D-', label='RNN')
#plt.plot(x*1.0, y4, '1-', label='NaN values')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss')
plt.legend(loc="upper right")
plt.grid()
plt.show()
