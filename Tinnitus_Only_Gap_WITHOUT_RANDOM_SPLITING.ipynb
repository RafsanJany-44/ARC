# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Tinnitus_Only_Gap_WITHOUT_RANDOM_SPLITING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
#dataset=pd.read_csv("/content/drive/MyDrive/SNU Research/Tinnitus/Tinnitus_106 feature_ALR_EEG_2023.02.02_OnlyGap_No_n0p1p3.csv")
 
dataset=pd.read_csv("/content/drive/MyDrive/Iqram Sir/Tinnitus/Tinnitus_106 feature_ALR_EEG_2023.02.08_OnlyGap_No_n0p1p3.csv")

classes = np.array(sorted(list(set(dataset.iloc[:, 0]))))
result = {}

# %%
set(list(dataset['Class']))
# Out:
# {'Control', 'Tinnitus'}

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset.iloc[:, 0]=encoder.fit_transform(dataset.iloc[:, 0])

# %%
set(list(dataset['Class']))
# Out:
# {0, 1}

# %%
X = dataset.iloc[:,3:]
y = dataset.iloc[:, 0]
col=list(dataset.iloc[0:0,3:])

# %% [markdown]
# # **Feature Check Box**

# %%
def feature_check_box(X_):
  import ipywidgets as widgets
  from IPython.display import display
  new_keys=[]
  for i in X_:
    i=widgets.Checkbox(
      value=False,
      description=str(i),
      disabled=False,
      indent=False
      )
    display(i)
    new_keys.append(i)
  return new_keys

# %%
features=feature_check_box(X_)
# Out:
# Checkbox(value=False, description='n1_gap_peak_ms_20ms', indent=False)
# Checkbox(value=False, description='p2_gap_peak_ms_20ms', indent=False)
# Checkbox(value=False, description='n2_gap_peak_ms_20ms', indent=False)
# Checkbox(value=False, description='n1p2_interval_gap_20ms', indent=False)
# Checkbox(value=False, description='n1n2_interval_gap_20ms', indent=False)
# Checkbox(value=False, description='p2n2_interval_gap_20ms', indent=False)
# Checkbox(value=False, description='n1_gap_peak_amp_20ms', indent=False)
# Checkbox(value=False, description='p2_gap_peak_amp_20ms', indent=False)
# Checkbox(value=False, description='n2_gap_peak_amp_20ms', indent=False)
# Checkbox(value=False, description='n1p2_gap_diff_20ms', indent=False)
# Checkbox(value=False, description='p2n2_gap_diff_20ms', indent=False)
# Checkbox(value=False, description='n1p2_gap_nogap_diff_20ms', indent=False)
# Checkbox(value=False, description='p2n2_gap_nogap_diff_20ms', indent=False)
# Checkbox(value=False, description='n1p2_gap_no_gap_ratio_20ms', indent=False)
# Checkbox(value=False, description='p2n2_gap_no_gap_ratio_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2_LO_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2_UP_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_p2n2_UP_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2n2_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_total_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_total_abs_20ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2n2_by_total_20ms', indent=False)
# Checkbox(value=False, description='alpha_peak_amp_20ms', indent=False)
# Checkbox(value=False, description='alpha_peak_freq_20ms', indent=False)
# Checkbox(value=False, description='beta_peak_amp_20ms', indent=False)
# Checkbox(value=False, description='beta_peak_freq_20ms', indent=False)
# Checkbox(value=False, description='gamma_peak_amp_20ms', indent=False)
# Checkbox(value=False, description='gamma_peak_freq_20ms', indent=False)
# Checkbox(value=False, description='alpha_auc_20ms', indent=False)
# Checkbox(value=False, description='beta_auc_20ms', indent=False)
# Checkbox(value=False, description='gamma_auc_20ms', indent=False)
# Checkbox(value=False, description='total_auc_20ms', indent=False)
# Checkbox(value=False, description='alpha_peak_auc_20ms', indent=False)
# Checkbox(value=False, description='beta_peak_auc_20ms', indent=False)
# Checkbox(value=False, description='gamma_peak_auc_20ms', indent=False)
# Checkbox(value=False, description='ABR_peak_auc_20ms', indent=False)
# Checkbox(value=False, description='ABR_auc_20ms', indent=False)
# Checkbox(value=False, description='n1_gap_peak_ms_50ms', indent=False)
# Checkbox(value=False, description='p2_gap_peak_ms_50ms', indent=False)
# Checkbox(value=False, description='n2_gap_peak_ms_50ms', indent=False)
# Checkbox(value=False, description='n1p2_interval_gap_50ms', indent=False)
# Checkbox(value=False, description='n1n2_interval_gap_50ms', indent=False)
# Checkbox(value=False, description='p2n2_interval_gap_50ms', indent=False)
# Checkbox(value=False, description='n1_gap_peak_amp_50ms', indent=False)
# Checkbox(value=False, description='p2_gap_peak_amp_50ms', indent=False)
# Checkbox(value=False, description='n2_gap_peak_amp_50ms', indent=False)
# Checkbox(value=False, description='n1p2_gap_diff_50ms', indent=False)
# Checkbox(value=False, description='p2n2_gap_diff_50ms', indent=False)
# Checkbox(value=False, description='n1p2_gap_nogap_diff_50ms', indent=False)
# Checkbox(value=False, description='p2n2_gap_nogap_diff_50ms', indent=False)
# Checkbox(value=False, description='n1p2_gap_no_gap_ratio_50ms', indent=False)
# Checkbox(value=False, description='p2n2_gap_no_gap_ratio_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2_LO_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2_UP_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_p2n2_UP_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2n2_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_total_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_total_abs_50ms', indent=False)
# Checkbox(value=False, description='gap_auc_n1p2n2_by_total_50ms', indent=False)
# Checkbox(value=False, description='alpha_peak_amp_50ms', indent=False)
# Checkbox(value=False, description='alpha_peak_freq_50ms', indent=False)
# Checkbox(value=False, description='beta_peak_amp_50ms', indent=False)
# Checkbox(value=False, description='beta_peak_freq_50ms', indent=False)
# Checkbox(value=False, description='gamma_peak_amp_50ms', indent=False)
# Checkbox(value=False, description='gamma_peak_freq_50ms', indent=False)
# Checkbox(value=False, description='alpha_auc_50ms', indent=False)
# Checkbox(value=False, description='beta_auc_50ms', indent=False)
# Checkbox(value=False, description='gamma_auc_50ms', indent=False)
# Checkbox(value=False, description='total_auc_50ms', indent=False)
# Checkbox(value=False, description='alpha_peak_auc_50ms', indent=False)
# Checkbox(value=False, description='beta_peak_auc_50ms', indent=False)
# Checkbox(value=False, description='gamma_peak_auc_50ms', indent=False)
# Checkbox(value=False, description='ABR_peak_auc_50ms', indent=False)
# Checkbox(value=False, description='ABR_auc_50ms', indent=False)

# %% [markdown]
# #Data Spliting

# %% [markdown]
# You can remove it. I added for not to input all the features for every runtime

# %%
number_of_feat = 20

# %% [markdown]
# ###ANOVA with f classifciation

# %%
"""

from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import pandas as pd



fs = SelectKBest(score_func=f_classif, k=5)
fit = fs.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_ANOVA'] 

lyst = featureScores.nlargest(number_of_feat,'Score_ANOVA')

#lyst.to_csv('Filter_Method_ANOVA_with_f_classif.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "ANOVA""""

# %% [markdown]
# ###Pearson's with f regression

# %%
"""from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
import pandas as pd


fs = SelectKBest(score_func=f_regression, k=5)
fit = fs.fit(X,y)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_pearsons'] 


lyst = featureScores.nlargest(number_of_feat,'Score_pearsons')

#lyst.to_csv('Filter_Method_Pearson’s_with_f_regression.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "Pearson""""

# %% [markdown]
# ###Sequential Feature Selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
sfs = SequentialFeatureSelector(knn, n_features_to_select=number_of_feat)
sfs.fit(X, y)
list_of_feat=[]
list_of_feat=list(sfs.get_feature_names_out(col))

df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Filter_Method_Sequential_feat_Selection_KNN.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]

selection_method = "Sequential"

# %%
list_of_feat2=[   
'p2_gap_peak_amp_50ms',
'p2n2_gap_diff_20ms',
'p2n2_gap_diff_50ms',
'p2n2_interval_gap_50ms',
'n2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_by_total_20ms',
'n1_gap_peak_ms_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'n1p2_gap_no_gap_ratio_50ms',
'gap_auc_p2n2_UP_20ms',
'gap_auc_p2n2_UP_50ms',
'n2_gap_peak_ms_50ms',
'gap_auc_n1p2n2_20ms',
'n1p2_gap_diff_50ms',
'gap_auc_total_abs_20ms',
'n1_gap_peak_ms_50ms',
'n1p2_gap_no_gap_ratio_20ms',
'alpha_peak_auc_50ms',
'gamma_peak_freq_50ms',
'ABR_peak_auc_50ms'
    ]

print(len(list_of_feat2))
# Out:
# 20

# %%
list_of_feat3=[  
'p2n2_gap_diff_50ms',
'p2_gap_peak_amp_50ms',
'gap_auc_n1p2n2_by_total_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'p2n2_gap_diff_20ms',
'n1_gap_peak_ms_20ms',
'n2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_50ms',
'gap_auc_n1p2_UP_50ms',
'gap_auc_n1p2_LO_50ms',
'gap_auc_n1p2n2_20ms',
'n1_gap_peak_ms_50ms',
'gap_auc_p2n2_UP_50ms',
'n1p2_gap_no_gap_ratio_20ms',
'p2_gap_peak_amp_20ms',
'alpha_peak_auc_50ms',
'gamma_peak_freq_20ms'
    ]

print(len(list_of_feat3))
# Out:
# 17

# %%
X_new = dataset[list_of_feat]
y_new = dataset.iloc[:, 0]

# %%
"""from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)"""

# %%
X_train=X_new.iloc[:133,:]  
X_test=X_new.iloc[133:,:]
y_train=y_new.iloc[:133]
y_test=y_new.iloc[133:]

# %% [markdown]
# #ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_defult = AdaBoostClassifier(random_state=0)
ada_defult.fit(X_train, y_train)
y_pred = ada_defult.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(ada_defult,1,'AdaBoostClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[11  6]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63        17
#            1       0.57      0.53      0.55        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
# Accurecy:  0.59375

# %%
from sklearn.ensemble import AdaBoostClassifier
N=200
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = AdaBoostClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt
#plot the relationship between K and the testing accuracy
plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/200 round completed......................... Accurecy: 0.59375
# 2/200 round completed......................... Accurecy: 0.625
# 3/200 round completed......................... Accurecy: 0.625
# 4/200 round completed......................... Accurecy: 0.53125
# 5/200 round completed......................... Accurecy: 0.65625
# 6/200 round completed......................... Accurecy: 0.6875
# 7/200 round completed......................... Accurecy: 0.6875
# 8/200 round completed......................... Accurecy: 0.65625
# 9/200 round completed......................... Accurecy: 0.65625
# 10/200 round completed......................... Accurecy: 0.625
# 11/200 round completed......................... Accurecy: 0.65625
# 12/200 round completed......................... Accurecy: 0.65625
# 13/200 round completed......................... Accurecy: 0.65625
# 14/200 round completed......................... Accurecy: 0.59375
# 15/200 round completed......................... Accurecy: 0.59375
# 16/200 round completed......................... Accurecy: 0.5625
# 17/200 round completed......................... Accurecy: 0.53125
# 18/200 round completed......................... Accurecy: 0.5625
# 19/200 round completed......................... Accurecy: 0.5625
# 20/200 round completed......................... Accurecy: 0.5625
# 21/200 round completed......................... Accurecy: 0.5625
# 22/200 round completed......................... Accurecy: 0.59375
# 23/200 round completed......................... Accurecy: 0.53125
# 24/200 round completed......................... Accurecy: 0.59375
# 25/200 round completed......................... Accurecy: 0.59375
# 26/200 round completed......................... Accurecy: 0.59375
# 27/200 round completed......................... Accurecy: 0.5625
# 28/200 round completed......................... Accurecy: 0.59375
# 29/200 round completed......................... Accurecy: 0.5625
# 30/200 round completed......................... Accurecy: 0.625
# 31/200 round completed......................... Accurecy: 0.5625
# 32/200 round completed......................... Accurecy: 0.5625
# 33/200 round completed......................... Accurecy: 0.5625
# 34/200 round completed......................... Accurecy: 0.5625
# 35/200 round completed......................... Accurecy: 0.5625
# 36/200 round completed......................... Accurecy: 0.53125
# 37/200 round completed......................... Accurecy: 0.59375
# 38/200 round completed......................... Accurecy: 0.53125
# 39/200 round completed......................... Accurecy: 0.59375
# 40/200 round completed......................... Accurecy: 0.5625
# 41/200 round completed......................... Accurecy: 0.5625
# 42/200 round completed......................... Accurecy: 0.5625
# 43/200 round completed......................... Accurecy: 0.5625
# 44/200 round completed......................... Accurecy: 0.5625
# 45/200 round completed......................... Accurecy: 0.5625
# 46/200 round completed......................... Accurecy: 0.5625
# 47/200 round completed......................... Accurecy: 0.59375
# 48/200 round completed......................... Accurecy: 0.5625
# 49/200 round completed......................... Accurecy: 0.5625
# 50/200 round completed......................... Accurecy: 0.59375
# 51/200 round completed......................... Accurecy: 0.625
# 52/200 round completed......................... Accurecy: 0.65625
# 53/200 round completed......................... Accurecy: 0.65625
# 54/200 round completed......................... Accurecy: 0.65625
# 55/200 round completed......................... Accurecy: 0.625
# 56/200 round completed......................... Accurecy: 0.65625
# 57/200 round completed......................... Accurecy: 0.65625
# 58/200 round completed......................... Accurecy: 0.625
# 59/200 round completed......................... Accurecy: 0.625
# 60/200 round completed......................... Accurecy: 0.59375
# 61/200 round completed......................... Accurecy: 0.5625
# 62/200 round completed......................... Accurecy: 0.5625
# 63/200 round completed......................... Accurecy: 0.5625
# 64/200 round completed......................... Accurecy: 0.5625
# 65/200 round completed......................... Accurecy: 0.5625
# 66/200 round completed......................... Accurecy: 0.5625
# 67/200 round completed......................... Accurecy: 0.5625
# 68/200 round completed......................... Accurecy: 0.5625
# 69/200 round completed......................... Accurecy: 0.5625
# 70/200 round completed......................... Accurecy: 0.5625
# 71/200 round completed......................... Accurecy: 0.5625
# 72/200 round completed......................... Accurecy: 0.5625
# 73/200 round completed......................... Accurecy: 0.5625
# 74/200 round completed......................... Accurecy: 0.5625
# 75/200 round completed......................... Accurecy: 0.5625
# 76/200 round completed......................... Accurecy: 0.5625
# 77/200 round completed......................... Accurecy: 0.53125
# 78/200 round completed......................... Accurecy: 0.5625
# 79/200 round completed......................... Accurecy: 0.5625
# 80/200 round completed......................... Accurecy: 0.5625
# 81/200 round completed......................... Accurecy: 0.5625
# 82/200 round completed......................... Accurecy: 0.5625
# 83/200 round completed......................... Accurecy: 0.5625
# 84/200 round completed......................... Accurecy: 0.5625
# 85/200 round completed......................... Accurecy: 0.5625
# 86/200 round completed......................... Accurecy: 0.5625
# 87/200 round completed......................... Accurecy: 0.59375
# 88/200 round completed......................... Accurecy: 0.5625
# 89/200 round completed......................... Accurecy: 0.59375
# 90/200 round completed......................... Accurecy: 0.5625
# 91/200 round completed......................... Accurecy: 0.5625
# 92/200 round completed......................... Accurecy: 0.5625
# 93/200 round completed......................... Accurecy: 0.5625
# 94/200 round completed......................... Accurecy: 0.5625
# 95/200 round completed......................... Accurecy: 0.59375
# 96/200 round completed......................... Accurecy: 0.59375
# 97/200 round completed......................... Accurecy: 0.59375
# 98/200 round completed......................... Accurecy: 0.59375
# 99/200 round completed......................... Accurecy: 0.59375
# 100/200 round completed......................... Accurecy: 0.59375
# 101/200 round completed......................... Accurecy: 0.59375
# 102/200 round completed......................... Accurecy: 0.59375
# 103/200 round completed......................... Accurecy: 0.59375
# 104/200 round completed......................... Accurecy: 0.59375
# 105/200 round completed......................... Accurecy: 0.625
# 106/200 round completed......................... Accurecy: 0.625
# 107/200 round completed......................... Accurecy: 0.625
# 108/200 round completed......................... Accurecy: 0.625
# 109/200 round completed......................... Accurecy: 0.59375
# 110/200 round completed......................... Accurecy: 0.59375
# 111/200 round completed......................... Accurecy: 0.59375
# 112/200 round completed......................... Accurecy: 0.625
# 113/200 round completed......................... Accurecy: 0.625
# 114/200 round completed......................... Accurecy: 0.59375
# 115/200 round completed......................... Accurecy: 0.59375
# 116/200 round completed......................... Accurecy: 0.625
# 117/200 round completed......................... Accurecy: 0.59375
# 118/200 round completed......................... Accurecy: 0.5625
# 119/200 round completed......................... Accurecy: 0.59375
# 120/200 round completed......................... Accurecy: 0.5625
# 121/200 round completed......................... Accurecy: 0.5625
# 122/200 round completed......................... Accurecy: 0.5625
# 123/200 round completed......................... Accurecy: 0.5625
# 124/200 round completed......................... Accurecy: 0.5625
# 125/200 round completed......................... Accurecy: 0.5625
# 126/200 round completed......................... Accurecy: 0.5625
# 127/200 round completed......................... Accurecy: 0.5625
# 128/200 round completed......................... Accurecy: 0.59375
# 129/200 round completed......................... Accurecy: 0.59375
# 130/200 round completed......................... Accurecy: 0.59375
# 131/200 round completed......................... Accurecy: 0.59375
# 132/200 round completed......................... Accurecy: 0.59375
# 133/200 round completed......................... Accurecy: 0.5625
# 134/200 round completed......................... Accurecy: 0.5625
# 135/200 round completed......................... Accurecy: 0.5625
# 136/200 round completed......................... Accurecy: 0.59375
# 137/200 round completed......................... Accurecy: 0.59375
# 138/200 round completed......................... Accurecy: 0.5625
# 139/200 round completed......................... Accurecy: 0.5625
# 140/200 round completed......................... Accurecy: 0.59375
# 141/200 round completed......................... Accurecy: 0.5625
# 142/200 round completed......................... Accurecy: 0.5625
# 143/200 round completed......................... Accurecy: 0.59375
# 144/200 round completed......................... Accurecy: 0.59375
# 145/200 round completed......................... Accurecy: 0.59375
# 146/200 round completed......................... Accurecy: 0.59375
# 147/200 round completed......................... Accurecy: 0.59375
# 148/200 round completed......................... Accurecy: 0.59375
# 149/200 round completed......................... Accurecy: 0.59375
# 150/200 round completed......................... Accurecy: 0.59375
# 151/200 round completed......................... Accurecy: 0.59375
# 152/200 round completed......................... Accurecy: 0.59375
# 153/200 round completed......................... Accurecy: 0.59375
# 154/200 round completed......................... Accurecy: 0.59375
# 155/200 round completed......................... Accurecy: 0.59375
# 156/200 round completed......................... Accurecy: 0.59375
# 157/200 round completed......................... Accurecy: 0.59375
# 158/200 round completed......................... Accurecy: 0.59375
# 159/200 round completed......................... Accurecy: 0.59375
# 160/200 round completed......................... Accurecy: 0.59375
# 161/200 round completed......................... Accurecy: 0.59375
# 162/200 round completed......................... Accurecy: 0.59375
# 163/200 round completed......................... Accurecy: 0.59375
# 164/200 round completed......................... Accurecy: 0.59375
# 165/200 round completed......................... Accurecy: 0.59375
# 166/200 round completed......................... Accurecy: 0.59375
# 167/200 round completed......................... Accurecy: 0.59375
# 168/200 round completed......................... Accurecy: 0.59375
# 169/200 round completed......................... Accurecy: 0.625
# 170/200 round completed......................... Accurecy: 0.625
# 171/200 round completed......................... Accurecy: 0.59375
# 172/200 round completed......................... Accurecy: 0.59375
# 173/200 round completed......................... Accurecy: 0.625
# 174/200 round completed......................... Accurecy: 0.59375
# 175/200 round completed......................... Accurecy: 0.59375
# 176/200 round completed......................... Accurecy: 0.59375
# 177/200 round completed......................... Accurecy: 0.59375
# 178/200 round completed......................... Accurecy: 0.59375
# 179/200 round completed......................... Accurecy: 0.59375
# 180/200 round completed......................... Accurecy: 0.59375
# 181/200 round completed......................... Accurecy: 0.59375
# 182/200 round completed......................... Accurecy: 0.59375
# 183/200 round completed......................... Accurecy: 0.59375
# 184/200 round completed......................... Accurecy: 0.59375
# 185/200 round completed......................... Accurecy: 0.59375
# 186/200 round completed......................... Accurecy: 0.59375
# 187/200 round completed......................... Accurecy: 0.59375
# 188/200 round completed......................... Accurecy: 0.59375
# 189/200 round completed......................... Accurecy: 0.59375
# 190/200 round completed......................... Accurecy: 0.59375
# 191/200 round completed......................... Accurecy: 0.59375
# 192/200 round completed......................... Accurecy: 0.59375
# 193/200 round completed......................... Accurecy: 0.59375
# 194/200 round completed......................... Accurecy: 0.59375
# 195/200 round completed......................... Accurecy: 0.59375
# 196/200 round completed......................... Accurecy: 0.59375
# 197/200 round completed......................... Accurecy: 0.59375
# 198/200 round completed......................... Accurecy: 0.59375
# 199/200 round completed......................... Accurecy: 0.59375
# 200/200 round completed......................... Accurecy: 0.59375
# The best n_estimators:
# 6

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_best_estimator = AdaBoostClassifier(n_estimators=best_estimator,random_state=0)
ada_best_estimator.fit(X_train, y_train)
y_pred = ada_best_estimator.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(ada_best_estimator,1,'AdaBoostClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[14  3]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.82      0.74        17
#            1       0.73      0.53      0.62        15
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.68      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
# Accurecy:  0.6875

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Graddient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold

gradBoost_default = GradientBoostingClassifier(random_state=0)
gradBoost_default.fit(X_train, y_train)
y_pred = gradBoost_default.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(gradBoost_default,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[13  4]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72        17
#            1       0.69      0.60      0.64        15
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.68      0.68        32
# weighted avg       0.69      0.69      0.69        32
#
# Accurecy:  0.6875

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = GradientBoostingClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/150 round completed......................... Accurecy: 0.625
# 2/150 round completed......................... Accurecy: 0.59375
# 3/150 round completed......................... Accurecy: 0.5625
# 4/150 round completed......................... Accurecy: 0.65625
# 5/150 round completed......................... Accurecy: 0.5625
# 6/150 round completed......................... Accurecy: 0.65625
# 7/150 round completed......................... Accurecy: 0.65625
# 8/150 round completed......................... Accurecy: 0.59375
# 9/150 round completed......................... Accurecy: 0.59375
# 10/150 round completed......................... Accurecy: 0.625
# 11/150 round completed......................... Accurecy: 0.65625
# 12/150 round completed......................... Accurecy: 0.65625
# 13/150 round completed......................... Accurecy: 0.65625
# 14/150 round completed......................... Accurecy: 0.6875
# 15/150 round completed......................... Accurecy: 0.65625
# 16/150 round completed......................... Accurecy: 0.65625
# 17/150 round completed......................... Accurecy: 0.625
# 18/150 round completed......................... Accurecy: 0.65625
# 19/150 round completed......................... Accurecy: 0.65625
# 20/150 round completed......................... Accurecy: 0.65625
# 21/150 round completed......................... Accurecy: 0.65625
# 22/150 round completed......................... Accurecy: 0.65625
# 23/150 round completed......................... Accurecy: 0.65625
# 24/150 round completed......................... Accurecy: 0.65625
# 25/150 round completed......................... Accurecy: 0.65625
# 26/150 round completed......................... Accurecy: 0.65625
# 27/150 round completed......................... Accurecy: 0.65625
# 28/150 round completed......................... Accurecy: 0.6875
# 29/150 round completed......................... Accurecy: 0.6875
# 30/150 round completed......................... Accurecy: 0.6875
# 31/150 round completed......................... Accurecy: 0.6875
# 32/150 round completed......................... Accurecy: 0.65625
# 33/150 round completed......................... Accurecy: 0.65625
# 34/150 round completed......................... Accurecy: 0.65625
# 35/150 round completed......................... Accurecy: 0.65625
# 36/150 round completed......................... Accurecy: 0.65625
# 37/150 round completed......................... Accurecy: 0.65625
# 38/150 round completed......................... Accurecy: 0.65625
# 39/150 round completed......................... Accurecy: 0.65625
# 40/150 round completed......................... Accurecy: 0.65625
# 41/150 round completed......................... Accurecy: 0.65625
# 42/150 round completed......................... Accurecy: 0.65625
# 43/150 round completed......................... Accurecy: 0.65625
# 44/150 round completed......................... Accurecy: 0.65625
# 45/150 round completed......................... Accurecy: 0.65625
# 46/150 round completed......................... Accurecy: 0.6875
# 47/150 round completed......................... Accurecy: 0.6875
# 48/150 round completed......................... Accurecy: 0.71875
# 49/150 round completed......................... Accurecy: 0.6875
# 50/150 round completed......................... Accurecy: 0.6875
# 51/150 round completed......................... Accurecy: 0.6875
# 52/150 round completed......................... Accurecy: 0.6875
# 53/150 round completed......................... Accurecy: 0.6875
# 54/150 round completed......................... Accurecy: 0.71875
# 55/150 round completed......................... Accurecy: 0.6875
# 56/150 round completed......................... Accurecy: 0.6875
# 57/150 round completed......................... Accurecy: 0.6875
# 58/150 round completed......................... Accurecy: 0.6875
# 59/150 round completed......................... Accurecy: 0.6875
# 60/150 round completed......................... Accurecy: 0.6875
# 61/150 round completed......................... Accurecy: 0.6875
# 62/150 round completed......................... Accurecy: 0.6875
# 63/150 round completed......................... Accurecy: 0.6875
# 64/150 round completed......................... Accurecy: 0.6875
# 65/150 round completed......................... Accurecy: 0.6875
# 66/150 round completed......................... Accurecy: 0.6875
# 67/150 round completed......................... Accurecy: 0.6875
# 68/150 round completed......................... Accurecy: 0.6875
# 69/150 round completed......................... Accurecy: 0.6875
# 70/150 round completed......................... Accurecy: 0.6875
# 71/150 round completed......................... Accurecy: 0.6875
# 72/150 round completed......................... Accurecy: 0.6875
# 73/150 round completed......................... Accurecy: 0.6875
# 74/150 round completed......................... Accurecy: 0.6875
# 75/150 round completed......................... Accurecy: 0.6875
# 76/150 round completed......................... Accurecy: 0.6875
# 77/150 round completed......................... Accurecy: 0.6875
# 78/150 round completed......................... Accurecy: 0.6875
# 79/150 round completed......................... Accurecy: 0.6875
# 80/150 round completed......................... Accurecy: 0.6875
# 81/150 round completed......................... Accurecy: 0.6875
# 82/150 round completed......................... Accurecy: 0.6875
# 83/150 round completed......................... Accurecy: 0.6875
# 84/150 round completed......................... Accurecy: 0.6875
# 85/150 round completed......................... Accurecy: 0.6875
# 86/150 round completed......................... Accurecy: 0.6875
# 87/150 round completed......................... Accurecy: 0.6875
# 88/150 round completed......................... Accurecy: 0.6875
# 89/150 round completed......................... Accurecy: 0.6875
# 90/150 round completed......................... Accurecy: 0.6875
# 91/150 round completed......................... Accurecy: 0.6875
# 92/150 round completed......................... Accurecy: 0.6875
# 93/150 round completed......................... Accurecy: 0.6875
# 94/150 round completed......................... Accurecy: 0.6875
# 95/150 round completed......................... Accurecy: 0.6875
# 96/150 round completed......................... Accurecy: 0.6875
# 97/150 round completed......................... Accurecy: 0.6875
# 98/150 round completed......................... Accurecy: 0.6875
# 99/150 round completed......................... Accurecy: 0.6875
# 100/150 round completed......................... Accurecy: 0.6875
# 101/150 round completed......................... Accurecy: 0.6875
# 102/150 round completed......................... Accurecy: 0.6875
# 103/150 round completed......................... Accurecy: 0.6875
# 104/150 round completed......................... Accurecy: 0.6875
# 105/150 round completed......................... Accurecy: 0.6875
# 106/150 round completed......................... Accurecy: 0.6875
# 107/150 round completed......................... Accurecy: 0.6875
# 108/150 round completed......................... Accurecy: 0.6875
# 109/150 round completed......................... Accurecy: 0.6875
# 110/150 round completed......................... Accurecy: 0.6875
# 111/150 round completed......................... Accurecy: 0.6875
# 112/150 round completed......................... Accurecy: 0.6875
# 113/150 round completed......................... Accurecy: 0.6875
# 114/150 round completed......................... Accurecy: 0.6875
# 115/150 round completed......................... Accurecy: 0.6875
# 116/150 round completed......................... Accurecy: 0.6875
# 117/150 round completed......................... Accurecy: 0.6875
# 118/150 round completed......................... Accurecy: 0.6875
# 119/150 round completed......................... Accurecy: 0.6875
# 120/150 round completed......................... Accurecy: 0.6875
# 121/150 round completed......................... Accurecy: 0.6875
# 122/150 round completed......................... Accurecy: 0.6875
# 123/150 round completed......................... Accurecy: 0.6875
# 124/150 round completed......................... Accurecy: 0.6875
# 125/150 round completed......................... Accurecy: 0.6875
# 126/150 round completed......................... Accurecy: 0.6875
# 127/150 round completed......................... Accurecy: 0.6875
# 128/150 round completed......................... Accurecy: 0.6875
# 129/150 round completed......................... Accurecy: 0.6875
# 130/150 round completed......................... Accurecy: 0.6875
# 131/150 round completed......................... Accurecy: 0.6875
# 132/150 round completed......................... Accurecy: 0.6875
# 133/150 round completed......................... Accurecy: 0.6875
# 134/150 round completed......................... Accurecy: 0.6875
# 135/150 round completed......................... Accurecy: 0.6875
# 136/150 round completed......................... Accurecy: 0.6875
# 137/150 round completed......................... Accurecy: 0.6875
# 138/150 round completed......................... Accurecy: 0.6875
# 139/150 round completed......................... Accurecy: 0.6875
# 140/150 round completed......................... Accurecy: 0.6875
# 141/150 round completed......................... Accurecy: 0.6875
# 142/150 round completed......................... Accurecy: 0.6875
# 143/150 round completed......................... Accurecy: 0.6875
# 144/150 round completed......................... Accurecy: 0.6875
# 145/150 round completed......................... Accurecy: 0.6875
# 146/150 round completed......................... Accurecy: 0.6875
# 147/150 round completed......................... Accurecy: 0.6875
# 148/150 round completed......................... Accurecy: 0.6875
# 149/150 round completed......................... Accurecy: 0.6875
# 150/150 round completed......................... Accurecy: 0.6875
# The best n_estimators:
# 48

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=30
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = GradientBoostingClassifier(max_depth=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/30 round completed......................... Accurecy: 0.59375
# 2/30 round completed......................... Accurecy: 0.59375
# 3/30 round completed......................... Accurecy: 0.6875
# 4/30 round completed......................... Accurecy: 0.65625
# 5/30 round completed......................... Accurecy: 0.65625
# 6/30 round completed......................... Accurecy: 0.625
# 7/30 round completed......................... Accurecy: 0.65625
# 8/30 round completed......................... Accurecy: 0.625
# 9/30 round completed......................... Accurecy: 0.625
# 10/30 round completed......................... Accurecy: 0.625
# 11/30 round completed......................... Accurecy: 0.625
# 12/30 round completed......................... Accurecy: 0.625
# 13/30 round completed......................... Accurecy: 0.625
# 14/30 round completed......................... Accurecy: 0.625
# 15/30 round completed......................... Accurecy: 0.625
# 16/30 round completed......................... Accurecy: 0.625
# 17/30 round completed......................... Accurecy: 0.625
# 18/30 round completed......................... Accurecy: 0.625
# 19/30 round completed......................... Accurecy: 0.625
# 20/30 round completed......................... Accurecy: 0.625
# 21/30 round completed......................... Accurecy: 0.625
# 22/30 round completed......................... Accurecy: 0.625
# 23/30 round completed......................... Accurecy: 0.625
# 24/30 round completed......................... Accurecy: 0.625
# 25/30 round completed......................... Accurecy: 0.625
# 26/30 round completed......................... Accurecy: 0.625
# 27/30 round completed......................... Accurecy: 0.625
# 28/30 round completed......................... Accurecy: 0.625
# 29/30 round completed......................... Accurecy: 0.625
# 30/30 round completed......................... Accurecy: 0.625
# The best Depth:
# 3

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_estimator = GradientBoostingClassifier(n_estimators=best_estimator,random_state=0)
gradBoost_estimator.fit(X_train, y_train)
y_pred = gradBoost_estimator.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(gradBoost_estimator,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[14  3]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76        17
#            1       0.75      0.60      0.67        15
#
#     accuracy                           0.72        32
#    macro avg       0.72      0.71      0.71        32
# weighted avg       0.72      0.72      0.71        32
#
# Accurecy:  0.71875

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_depth = GradientBoostingClassifier(max_depth=best_depth,random_state=0)
gradBoost_depth.fit(X_train, y_train)
y_pred = gradBoost_depth.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))

result[(gradBoost_depth,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[13  4]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72        17
#            1       0.69      0.60      0.64        15
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.68      0.68        32
# weighted avg       0.69      0.69      0.69        32
#
# Accurecy:  0.6875

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_all = GradientBoostingClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
gradBoost_all.fit(X_train, y_train)
y_pred = gradBoost_all.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))

result[(gradBoost_all,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[14  3]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76        17
#            1       0.75      0.60      0.67        15
#
#     accuracy                           0.72        32
#    macro avg       0.72      0.71      0.71        32
# weighted avg       0.72      0.72      0.71        32
#
# Accurecy:  0.71875

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_default = RandomForestClassifier(random_state=0)
rf_default.fit(X_train, y_train)
y_pred=rf_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_default,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[9 8]
#  [6 9]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.53      0.56        17
#            1       0.53      0.60      0.56        15
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
# Accurecy:  0.5625

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = RandomForestClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/150 round completed......................... Accurecy: 0.625
# 2/150 round completed......................... Accurecy: 0.65625
# 3/150 round completed......................... Accurecy: 0.53125
# 4/150 round completed......................... Accurecy: 0.65625
# 5/150 round completed......................... Accurecy: 0.6875
# 6/150 round completed......................... Accurecy: 0.5625
# 7/150 round completed......................... Accurecy: 0.65625
# 8/150 round completed......................... Accurecy: 0.625
# 9/150 round completed......................... Accurecy: 0.65625
# 10/150 round completed......................... Accurecy: 0.65625
# 11/150 round completed......................... Accurecy: 0.625
# 12/150 round completed......................... Accurecy: 0.5625
# 13/150 round completed......................... Accurecy: 0.53125
# 14/150 round completed......................... Accurecy: 0.53125
# 15/150 round completed......................... Accurecy: 0.5625
# 16/150 round completed......................... Accurecy: 0.53125
# 17/150 round completed......................... Accurecy: 0.5625
# 18/150 round completed......................... Accurecy: 0.53125
# 19/150 round completed......................... Accurecy: 0.59375
# 20/150 round completed......................... Accurecy: 0.59375
# 21/150 round completed......................... Accurecy: 0.59375
# 22/150 round completed......................... Accurecy: 0.625
# 23/150 round completed......................... Accurecy: 0.625
# 24/150 round completed......................... Accurecy: 0.625
# 25/150 round completed......................... Accurecy: 0.625
# 26/150 round completed......................... Accurecy: 0.59375
# 27/150 round completed......................... Accurecy: 0.5625
# 28/150 round completed......................... Accurecy: 0.59375
# 29/150 round completed......................... Accurecy: 0.5625
# 30/150 round completed......................... Accurecy: 0.5625
# 31/150 round completed......................... Accurecy: 0.59375
# 32/150 round completed......................... Accurecy: 0.59375
# 33/150 round completed......................... Accurecy: 0.625
# 34/150 round completed......................... Accurecy: 0.5625
# 35/150 round completed......................... Accurecy: 0.5625
# 36/150 round completed......................... Accurecy: 0.59375
# 37/150 round completed......................... Accurecy: 0.5625
# 38/150 round completed......................... Accurecy: 0.5625
# 39/150 round completed......................... Accurecy: 0.59375
# 40/150 round completed......................... Accurecy: 0.59375
# 41/150 round completed......................... Accurecy: 0.59375
# 42/150 round completed......................... Accurecy: 0.59375
# 43/150 round completed......................... Accurecy: 0.59375
# 44/150 round completed......................... Accurecy: 0.59375
# 45/150 round completed......................... Accurecy: 0.59375
# 46/150 round completed......................... Accurecy: 0.5625
# 47/150 round completed......................... Accurecy: 0.59375
# 48/150 round completed......................... Accurecy: 0.59375
# 49/150 round completed......................... Accurecy: 0.59375
# 50/150 round completed......................... Accurecy: 0.59375
# 51/150 round completed......................... Accurecy: 0.59375
# 52/150 round completed......................... Accurecy: 0.59375
# 53/150 round completed......................... Accurecy: 0.59375
# 54/150 round completed......................... Accurecy: 0.59375
# 55/150 round completed......................... Accurecy: 0.59375
# 56/150 round completed......................... Accurecy: 0.59375
# 57/150 round completed......................... Accurecy: 0.59375
# 58/150 round completed......................... Accurecy: 0.5625
# 59/150 round completed......................... Accurecy: 0.59375
# 60/150 round completed......................... Accurecy: 0.59375
# 61/150 round completed......................... Accurecy: 0.59375
# 62/150 round completed......................... Accurecy: 0.59375
# 63/150 round completed......................... Accurecy: 0.59375
# 64/150 round completed......................... Accurecy: 0.59375
# 65/150 round completed......................... Accurecy: 0.59375
# 66/150 round completed......................... Accurecy: 0.5625
# 67/150 round completed......................... Accurecy: 0.59375
# 68/150 round completed......................... Accurecy: 0.59375
# 69/150 round completed......................... Accurecy: 0.59375
# 70/150 round completed......................... Accurecy: 0.59375
# 71/150 round completed......................... Accurecy: 0.59375
# 72/150 round completed......................... Accurecy: 0.59375
# 73/150 round completed......................... Accurecy: 0.5625
# 74/150 round completed......................... Accurecy: 0.5625
# 75/150 round completed......................... Accurecy: 0.5625
# 76/150 round completed......................... Accurecy: 0.59375
# 77/150 round completed......................... Accurecy: 0.625
# 78/150 round completed......................... Accurecy: 0.625
# 79/150 round completed......................... Accurecy: 0.625
# 80/150 round completed......................... Accurecy: 0.625
# 81/150 round completed......................... Accurecy: 0.625
# 82/150 round completed......................... Accurecy: 0.625
# 83/150 round completed......................... Accurecy: 0.625
# 84/150 round completed......................... Accurecy: 0.625
# 85/150 round completed......................... Accurecy: 0.59375
# 86/150 round completed......................... Accurecy: 0.5625
# 87/150 round completed......................... Accurecy: 0.5625
# 88/150 round completed......................... Accurecy: 0.5625
# 89/150 round completed......................... Accurecy: 0.5625
# 90/150 round completed......................... Accurecy: 0.5625
# 91/150 round completed......................... Accurecy: 0.5625
# 92/150 round completed......................... Accurecy: 0.5625
# 93/150 round completed......................... Accurecy: 0.5625
# 94/150 round completed......................... Accurecy: 0.59375
# 95/150 round completed......................... Accurecy: 0.5625
# 96/150 round completed......................... Accurecy: 0.59375
# 97/150 round completed......................... Accurecy: 0.5625
# 98/150 round completed......................... Accurecy: 0.5625
# 99/150 round completed......................... Accurecy: 0.5625
# 100/150 round completed......................... Accurecy: 0.5625
# 101/150 round completed......................... Accurecy: 0.5625
# 102/150 round completed......................... Accurecy: 0.5625
# 103/150 round completed......................... Accurecy: 0.5625
# 104/150 round completed......................... Accurecy: 0.59375
# 105/150 round completed......................... Accurecy: 0.5625
# 106/150 round completed......................... Accurecy: 0.59375
# 107/150 round completed......................... Accurecy: 0.59375
# 108/150 round completed......................... Accurecy: 0.59375
# 109/150 round completed......................... Accurecy: 0.5625
# 110/150 round completed......................... Accurecy: 0.5625
# 111/150 round completed......................... Accurecy: 0.5625
# 112/150 round completed......................... Accurecy: 0.5625
# 113/150 round completed......................... Accurecy: 0.5625
# 114/150 round completed......................... Accurecy: 0.5625
# 115/150 round completed......................... Accurecy: 0.5625
# 116/150 round completed......................... Accurecy: 0.5625
# 117/150 round completed......................... Accurecy: 0.5625
# 118/150 round completed......................... Accurecy: 0.5625
# 119/150 round completed......................... Accurecy: 0.5625
# 120/150 round completed......................... Accurecy: 0.5625
# 121/150 round completed......................... Accurecy: 0.5625
# 122/150 round completed......................... Accurecy: 0.5625
# 123/150 round completed......................... Accurecy: 0.5625
# 124/150 round completed......................... Accurecy: 0.5625
# 125/150 round completed......................... Accurecy: 0.5625
# 126/150 round completed......................... Accurecy: 0.5625
# 127/150 round completed......................... Accurecy: 0.5625
# 128/150 round completed......................... Accurecy: 0.5625
# 129/150 round completed......................... Accurecy: 0.5625
# 130/150 round completed......................... Accurecy: 0.53125
# 131/150 round completed......................... Accurecy: 0.5625
# 132/150 round completed......................... Accurecy: 0.5625
# 133/150 round completed......................... Accurecy: 0.5625
# 134/150 round completed......................... Accurecy: 0.5625
# 135/150 round completed......................... Accurecy: 0.5625
# 136/150 round completed......................... Accurecy: 0.5625
# 137/150 round completed......................... Accurecy: 0.5625
# 138/150 round completed......................... Accurecy: 0.5625
# 139/150 round completed......................... Accurecy: 0.5625
# 140/150 round completed......................... Accurecy: 0.5625
# 141/150 round completed......................... Accurecy: 0.5625
# 142/150 round completed......................... Accurecy: 0.5625
# 143/150 round completed......................... Accurecy: 0.5625
# 144/150 round completed......................... Accurecy: 0.53125
# 145/150 round completed......................... Accurecy: 0.53125
# 146/150 round completed......................... Accurecy: 0.53125
# 147/150 round completed......................... Accurecy: 0.53125
# 148/150 round completed......................... Accurecy: 0.53125
# 149/150 round completed......................... Accurecy: 0.53125
# 150/150 round completed......................... Accurecy: 0.53125
# The best n_estimators:
# 5

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = RandomForestClassifier(max_depth=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/150 round completed......................... Accurecy: 0.6875
# 2/150 round completed......................... Accurecy: 0.59375
# 3/150 round completed......................... Accurecy: 0.59375
# 4/150 round completed......................... Accurecy: 0.5625
# 5/150 round completed......................... Accurecy: 0.5625
# 6/150 round completed......................... Accurecy: 0.5625
# 7/150 round completed......................... Accurecy: 0.5625
# 8/150 round completed......................... Accurecy: 0.59375
# 9/150 round completed......................... Accurecy: 0.59375
# 10/150 round completed......................... Accurecy: 0.59375
# 11/150 round completed......................... Accurecy: 0.59375
# 12/150 round completed......................... Accurecy: 0.5625
# 13/150 round completed......................... Accurecy: 0.5625
# 14/150 round completed......................... Accurecy: 0.5625
# 15/150 round completed......................... Accurecy: 0.5625
# 16/150 round completed......................... Accurecy: 0.5625
# 17/150 round completed......................... Accurecy: 0.5625
# 18/150 round completed......................... Accurecy: 0.5625
# 19/150 round completed......................... Accurecy: 0.5625
# 20/150 round completed......................... Accurecy: 0.5625
# 21/150 round completed......................... Accurecy: 0.5625
# 22/150 round completed......................... Accurecy: 0.5625
# 23/150 round completed......................... Accurecy: 0.5625
# 24/150 round completed......................... Accurecy: 0.5625
# 25/150 round completed......................... Accurecy: 0.5625
# 26/150 round completed......................... Accurecy: 0.5625
# 27/150 round completed......................... Accurecy: 0.5625
# 28/150 round completed......................... Accurecy: 0.5625
# 29/150 round completed......................... Accurecy: 0.5625
# 30/150 round completed......................... Accurecy: 0.5625
# 31/150 round completed......................... Accurecy: 0.5625
# 32/150 round completed......................... Accurecy: 0.5625
# 33/150 round completed......................... Accurecy: 0.5625
# 34/150 round completed......................... Accurecy: 0.5625
# 35/150 round completed......................... Accurecy: 0.5625
# 36/150 round completed......................... Accurecy: 0.5625
# 37/150 round completed......................... Accurecy: 0.5625
# 38/150 round completed......................... Accurecy: 0.5625
# 39/150 round completed......................... Accurecy: 0.5625
# 40/150 round completed......................... Accurecy: 0.5625
# 41/150 round completed......................... Accurecy: 0.5625
# 42/150 round completed......................... Accurecy: 0.5625
# 43/150 round completed......................... Accurecy: 0.5625
# 44/150 round completed......................... Accurecy: 0.5625
# 45/150 round completed......................... Accurecy: 0.5625
# 46/150 round completed......................... Accurecy: 0.5625
# 47/150 round completed......................... Accurecy: 0.5625
# 48/150 round completed......................... Accurecy: 0.5625
# 49/150 round completed......................... Accurecy: 0.5625
# 50/150 round completed......................... Accurecy: 0.5625
# 51/150 round completed......................... Accurecy: 0.5625
# 52/150 round completed......................... Accurecy: 0.5625
# 53/150 round completed......................... Accurecy: 0.5625
# 54/150 round completed......................... Accurecy: 0.5625
# 55/150 round completed......................... Accurecy: 0.5625
# 56/150 round completed......................... Accurecy: 0.5625
# 57/150 round completed......................... Accurecy: 0.5625
# 58/150 round completed......................... Accurecy: 0.5625
# 59/150 round completed......................... Accurecy: 0.5625
# 60/150 round completed......................... Accurecy: 0.5625
# 61/150 round completed......................... Accurecy: 0.5625
# 62/150 round completed......................... Accurecy: 0.5625
# 63/150 round completed......................... Accurecy: 0.5625
# 64/150 round completed......................... Accurecy: 0.5625
# 65/150 round completed......................... Accurecy: 0.5625
# 66/150 round completed......................... Accurecy: 0.5625
# 67/150 round completed......................... Accurecy: 0.5625
# 68/150 round completed......................... Accurecy: 0.5625
# 69/150 round completed......................... Accurecy: 0.5625
# 70/150 round completed......................... Accurecy: 0.5625
# 71/150 round completed......................... Accurecy: 0.5625
# 72/150 round completed......................... Accurecy: 0.5625
# 73/150 round completed......................... Accurecy: 0.5625
# 74/150 round completed......................... Accurecy: 0.5625
# 75/150 round completed......................... Accurecy: 0.5625
# 76/150 round completed......................... Accurecy: 0.5625
# 77/150 round completed......................... Accurecy: 0.5625
# 78/150 round completed......................... Accurecy: 0.5625
# 79/150 round completed......................... Accurecy: 0.5625
# 80/150 round completed......................... Accurecy: 0.5625
# 81/150 round completed......................... Accurecy: 0.5625
# 82/150 round completed......................... Accurecy: 0.5625
# 83/150 round completed......................... Accurecy: 0.5625
# 84/150 round completed......................... Accurecy: 0.5625
# 85/150 round completed......................... Accurecy: 0.5625
# 86/150 round completed......................... Accurecy: 0.5625
# 87/150 round completed......................... Accurecy: 0.5625
# 88/150 round completed......................... Accurecy: 0.5625
# 89/150 round completed......................... Accurecy: 0.5625
# 90/150 round completed......................... Accurecy: 0.5625
# 91/150 round completed......................... Accurecy: 0.5625
# 92/150 round completed......................... Accurecy: 0.5625
# 93/150 round completed......................... Accurecy: 0.5625
# 94/150 round completed......................... Accurecy: 0.5625
# 95/150 round completed......................... Accurecy: 0.5625
# 96/150 round completed......................... Accurecy: 0.5625
# 97/150 round completed......................... Accurecy: 0.5625
# 98/150 round completed......................... Accurecy: 0.5625
# 99/150 round completed......................... Accurecy: 0.5625
# 100/150 round completed......................... Accurecy: 0.5625
# 101/150 round completed......................... Accurecy: 0.5625
# 102/150 round completed......................... Accurecy: 0.5625
# 103/150 round completed......................... Accurecy: 0.5625
# 104/150 round completed......................... Accurecy: 0.5625
# 105/150 round completed......................... Accurecy: 0.5625
# 106/150 round completed......................... Accurecy: 0.5625
# 107/150 round completed......................... Accurecy: 0.5625
# 108/150 round completed......................... Accurecy: 0.5625
# 109/150 round completed......................... Accurecy: 0.5625
# 110/150 round completed......................... Accurecy: 0.5625
# 111/150 round completed......................... Accurecy: 0.5625
# 112/150 round completed......................... Accurecy: 0.5625
# 113/150 round completed......................... Accurecy: 0.5625
# 114/150 round completed......................... Accurecy: 0.5625
# 115/150 round completed......................... Accurecy: 0.5625
# 116/150 round completed......................... Accurecy: 0.5625
# 117/150 round completed......................... Accurecy: 0.5625
# 118/150 round completed......................... Accurecy: 0.5625
# 119/150 round completed......................... Accurecy: 0.5625
# 120/150 round completed......................... Accurecy: 0.5625
# 121/150 round completed......................... Accurecy: 0.5625
# 122/150 round completed......................... Accurecy: 0.5625
# 123/150 round completed......................... Accurecy: 0.5625
# 124/150 round completed......................... Accurecy: 0.5625
# 125/150 round completed......................... Accurecy: 0.5625
# 126/150 round completed......................... Accurecy: 0.5625
# 127/150 round completed......................... Accurecy: 0.5625
# 128/150 round completed......................... Accurecy: 0.5625
# 129/150 round completed......................... Accurecy: 0.5625
# 130/150 round completed......................... Accurecy: 0.5625
# 131/150 round completed......................... Accurecy: 0.5625
# 132/150 round completed......................... Accurecy: 0.5625
# 133/150 round completed......................... Accurecy: 0.5625
# 134/150 round completed......................... Accurecy: 0.5625
# 135/150 round completed......................... Accurecy: 0.5625
# 136/150 round completed......................... Accurecy: 0.5625
# 137/150 round completed......................... Accurecy: 0.5625
# 138/150 round completed......................... Accurecy: 0.5625
# 139/150 round completed......................... Accurecy: 0.5625
# 140/150 round completed......................... Accurecy: 0.5625
# 141/150 round completed......................... Accurecy: 0.5625
# 142/150 round completed......................... Accurecy: 0.5625
# 143/150 round completed......................... Accurecy: 0.5625
# 144/150 round completed......................... Accurecy: 0.5625
# 145/150 round completed......................... Accurecy: 0.5625
# 146/150 round completed......................... Accurecy: 0.5625
# 147/150 round completed......................... Accurecy: 0.5625
# 148/150 round completed......................... Accurecy: 0.5625
# 149/150 round completed......................... Accurecy: 0.5625
# 150/150 round completed......................... Accurecy: 0.5625
# The best Depth:
# 1

# %%
from sklearn.ensemble import RandomForestClassifier
rf_estimator = RandomForestClassifier(n_estimators=best_estimator,random_state=0)
rf_estimator.fit(X_train, y_train)
y_pred=rf_estimator.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_estimator,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[10  7]
#  [ 3 12]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67        17
#            1       0.63      0.80      0.71        15
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.69        32
# weighted avg       0.70      0.69      0.69        32
#
# Accurecy:  0.6875

# %%
from sklearn.ensemble import RandomForestClassifier
rf_depth = RandomForestClassifier(max_depth=best_depth,random_state=0)
rf_depth.fit(X_train, y_train)
y_pred=rf_depth.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_depth,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[10  7]
#  [ 3 12]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67        17
#            1       0.63      0.80      0.71        15
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.69        32
# weighted avg       0.70      0.69      0.69        32
#
# Accurecy:  0.6875

# %%
from sklearn.ensemble import RandomForestClassifier
rf_all = RandomForestClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
rf_all.fit(X_train, y_train)
y_pred=rf_all.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_all,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[ 6 11]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.46      0.35      0.40        17
#            1       0.42      0.53      0.47        15
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.43        32
#
# Accurecy:  0.4375

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #XGB

# %%
import xgboost as xgb
xgb_deafult = xgb.XGBClassifier(random_state=0)
xgb_deafult.fit(X_train,y_train)
y_pred = xgb_deafult.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_deafult,4,'xgboost')]=accuracy_score(y_test, y_pred)
# Out:
# [[11  6]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63        17
#            1       0.57      0.53      0.55        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
# Accurecy:  0.59375

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score
N=250
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  xgb_classifier = xgb.XGBClassifier(n_estimators=k,random_state=0)
  xgb_classifier.fit(X_train, y_train)
  y_pred=xgb_classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/250 round completed......................... Accurecy: 0.5
# 2/250 round completed......................... Accurecy: 0.5625
# 3/250 round completed......................... Accurecy: 0.5
# 4/250 round completed......................... Accurecy: 0.5625
# 5/250 round completed......................... Accurecy: 0.53125
# 6/250 round completed......................... Accurecy: 0.59375
# 7/250 round completed......................... Accurecy: 0.625
# 8/250 round completed......................... Accurecy: 0.625
# 9/250 round completed......................... Accurecy: 0.625
# 10/250 round completed......................... Accurecy: 0.625
# 11/250 round completed......................... Accurecy: 0.625
# 12/250 round completed......................... Accurecy: 0.625
# 13/250 round completed......................... Accurecy: 0.625
# 14/250 round completed......................... Accurecy: 0.625
# 15/250 round completed......................... Accurecy: 0.625
# 16/250 round completed......................... Accurecy: 0.625
# 17/250 round completed......................... Accurecy: 0.65625
# 18/250 round completed......................... Accurecy: 0.6875
# 19/250 round completed......................... Accurecy: 0.65625
# 20/250 round completed......................... Accurecy: 0.65625
# 21/250 round completed......................... Accurecy: 0.65625
# 22/250 round completed......................... Accurecy: 0.6875
# 23/250 round completed......................... Accurecy: 0.6875
# 24/250 round completed......................... Accurecy: 0.6875
# 25/250 round completed......................... Accurecy: 0.6875
# 26/250 round completed......................... Accurecy: 0.6875
# 27/250 round completed......................... Accurecy: 0.625
# 28/250 round completed......................... Accurecy: 0.65625
# 29/250 round completed......................... Accurecy: 0.65625
# 30/250 round completed......................... Accurecy: 0.65625
# 31/250 round completed......................... Accurecy: 0.65625
# 32/250 round completed......................... Accurecy: 0.65625
# 33/250 round completed......................... Accurecy: 0.65625
# 34/250 round completed......................... Accurecy: 0.65625
# 35/250 round completed......................... Accurecy: 0.6875
# 36/250 round completed......................... Accurecy: 0.65625
# 37/250 round completed......................... Accurecy: 0.65625
# 38/250 round completed......................... Accurecy: 0.65625
# 39/250 round completed......................... Accurecy: 0.65625
# 40/250 round completed......................... Accurecy: 0.65625
# 41/250 round completed......................... Accurecy: 0.65625
# 42/250 round completed......................... Accurecy: 0.65625
# 43/250 round completed......................... Accurecy: 0.65625
# 44/250 round completed......................... Accurecy: 0.65625
# 45/250 round completed......................... Accurecy: 0.65625
# 46/250 round completed......................... Accurecy: 0.65625
# 47/250 round completed......................... Accurecy: 0.625
# 48/250 round completed......................... Accurecy: 0.625
# 49/250 round completed......................... Accurecy: 0.625
# 50/250 round completed......................... Accurecy: 0.625
# 51/250 round completed......................... Accurecy: 0.625
# 52/250 round completed......................... Accurecy: 0.625
# 53/250 round completed......................... Accurecy: 0.625
# 54/250 round completed......................... Accurecy: 0.625
# 55/250 round completed......................... Accurecy: 0.625
# 56/250 round completed......................... Accurecy: 0.625
# 57/250 round completed......................... Accurecy: 0.625
# 58/250 round completed......................... Accurecy: 0.625
# 59/250 round completed......................... Accurecy: 0.625
# 60/250 round completed......................... Accurecy: 0.625
# 61/250 round completed......................... Accurecy: 0.625
# 62/250 round completed......................... Accurecy: 0.625
# 63/250 round completed......................... Accurecy: 0.625
# 64/250 round completed......................... Accurecy: 0.625
# 65/250 round completed......................... Accurecy: 0.625
# 66/250 round completed......................... Accurecy: 0.625
# 67/250 round completed......................... Accurecy: 0.625
# 68/250 round completed......................... Accurecy: 0.625
# 69/250 round completed......................... Accurecy: 0.625
# 70/250 round completed......................... Accurecy: 0.625
# 71/250 round completed......................... Accurecy: 0.625
# 72/250 round completed......................... Accurecy: 0.59375
# 73/250 round completed......................... Accurecy: 0.625
# 74/250 round completed......................... Accurecy: 0.625
# 75/250 round completed......................... Accurecy: 0.59375
# 76/250 round completed......................... Accurecy: 0.59375
# 77/250 round completed......................... Accurecy: 0.59375
# 78/250 round completed......................... Accurecy: 0.59375
# 79/250 round completed......................... Accurecy: 0.59375
# 80/250 round completed......................... Accurecy: 0.59375
# 81/250 round completed......................... Accurecy: 0.59375
# 82/250 round completed......................... Accurecy: 0.59375
# 83/250 round completed......................... Accurecy: 0.59375
# 84/250 round completed......................... Accurecy: 0.59375
# 85/250 round completed......................... Accurecy: 0.59375
# 86/250 round completed......................... Accurecy: 0.59375
# 87/250 round completed......................... Accurecy: 0.59375
# 88/250 round completed......................... Accurecy: 0.59375
# 89/250 round completed......................... Accurecy: 0.59375
# 90/250 round completed......................... Accurecy: 0.59375
# 91/250 round completed......................... Accurecy: 0.59375
# 92/250 round completed......................... Accurecy: 0.59375
# 93/250 round completed......................... Accurecy: 0.59375
# 94/250 round completed......................... Accurecy: 0.59375
# 95/250 round completed......................... Accurecy: 0.59375
# 96/250 round completed......................... Accurecy: 0.59375
# 97/250 round completed......................... Accurecy: 0.59375
# 98/250 round completed......................... Accurecy: 0.59375
# 99/250 round completed......................... Accurecy: 0.59375
# 100/250 round completed......................... Accurecy: 0.59375
# 101/250 round completed......................... Accurecy: 0.59375
# 102/250 round completed......................... Accurecy: 0.59375
# 103/250 round completed......................... Accurecy: 0.59375
# 104/250 round completed......................... Accurecy: 0.59375
# 105/250 round completed......................... Accurecy: 0.59375
# 106/250 round completed......................... Accurecy: 0.59375
# 107/250 round completed......................... Accurecy: 0.59375
# 108/250 round completed......................... Accurecy: 0.59375
# 109/250 round completed......................... Accurecy: 0.59375
# 110/250 round completed......................... Accurecy: 0.59375
# 111/250 round completed......................... Accurecy: 0.59375
# 112/250 round completed......................... Accurecy: 0.59375
# 113/250 round completed......................... Accurecy: 0.59375
# 114/250 round completed......................... Accurecy: 0.59375
# 115/250 round completed......................... Accurecy: 0.59375
# 116/250 round completed......................... Accurecy: 0.59375
# 117/250 round completed......................... Accurecy: 0.59375
# 118/250 round completed......................... Accurecy: 0.59375
# 119/250 round completed......................... Accurecy: 0.59375
# 120/250 round completed......................... Accurecy: 0.59375
# 121/250 round completed......................... Accurecy: 0.59375
# 122/250 round completed......................... Accurecy: 0.59375
# 123/250 round completed......................... Accurecy: 0.59375
# 124/250 round completed......................... Accurecy: 0.59375
# 125/250 round completed......................... Accurecy: 0.59375
# 126/250 round completed......................... Accurecy: 0.59375
# 127/250 round completed......................... Accurecy: 0.59375
# 128/250 round completed......................... Accurecy: 0.59375
# 129/250 round completed......................... Accurecy: 0.59375
# 130/250 round completed......................... Accurecy: 0.59375
# 131/250 round completed......................... Accurecy: 0.59375
# 132/250 round completed......................... Accurecy: 0.59375
# 133/250 round completed......................... Accurecy: 0.59375
# 134/250 round completed......................... Accurecy: 0.59375
# 135/250 round completed......................... Accurecy: 0.59375
# 136/250 round completed......................... Accurecy: 0.59375
# 137/250 round completed......................... Accurecy: 0.59375
# 138/250 round completed......................... Accurecy: 0.59375
# 139/250 round completed......................... Accurecy: 0.59375
# 140/250 round completed......................... Accurecy: 0.59375
# 141/250 round completed......................... Accurecy: 0.59375
# 142/250 round completed......................... Accurecy: 0.59375
# 143/250 round completed......................... Accurecy: 0.59375
# 144/250 round completed......................... Accurecy: 0.59375
# 145/250 round completed......................... Accurecy: 0.59375
# 146/250 round completed......................... Accurecy: 0.59375
# 147/250 round completed......................... Accurecy: 0.59375
# 148/250 round completed......................... Accurecy: 0.59375
# 149/250 round completed......................... Accurecy: 0.59375
# 150/250 round completed......................... Accurecy: 0.59375
# 151/250 round completed......................... Accurecy: 0.59375
# 152/250 round completed......................... Accurecy: 0.59375
# 153/250 round completed......................... Accurecy: 0.59375
# 154/250 round completed......................... Accurecy: 0.59375
# 155/250 round completed......................... Accurecy: 0.59375
# 156/250 round completed......................... Accurecy: 0.59375
# 157/250 round completed......................... Accurecy: 0.59375
# 158/250 round completed......................... Accurecy: 0.59375
# 159/250 round completed......................... Accurecy: 0.59375
# 160/250 round completed......................... Accurecy: 0.59375
# 161/250 round completed......................... Accurecy: 0.59375
# 162/250 round completed......................... Accurecy: 0.59375
# 163/250 round completed......................... Accurecy: 0.59375
# 164/250 round completed......................... Accurecy: 0.59375
# 165/250 round completed......................... Accurecy: 0.59375
# 166/250 round completed......................... Accurecy: 0.59375
# 167/250 round completed......................... Accurecy: 0.59375
# 168/250 round completed......................... Accurecy: 0.59375
# 169/250 round completed......................... Accurecy: 0.59375
# 170/250 round completed......................... Accurecy: 0.59375
# 171/250 round completed......................... Accurecy: 0.59375
# 172/250 round completed......................... Accurecy: 0.59375
# 173/250 round completed......................... Accurecy: 0.59375
# 174/250 round completed......................... Accurecy: 0.59375
# 175/250 round completed......................... Accurecy: 0.59375
# 176/250 round completed......................... Accurecy: 0.59375
# 177/250 round completed......................... Accurecy: 0.59375
# 178/250 round completed......................... Accurecy: 0.59375
# 179/250 round completed......................... Accurecy: 0.59375
# 180/250 round completed......................... Accurecy: 0.59375
# 181/250 round completed......................... Accurecy: 0.59375
# 182/250 round completed......................... Accurecy: 0.59375
# 183/250 round completed......................... Accurecy: 0.59375
# 184/250 round completed......................... Accurecy: 0.59375
# 185/250 round completed......................... Accurecy: 0.59375
# 186/250 round completed......................... Accurecy: 0.59375
# 187/250 round completed......................... Accurecy: 0.59375
# 188/250 round completed......................... Accurecy: 0.59375
# 189/250 round completed......................... Accurecy: 0.59375
# 190/250 round completed......................... Accurecy: 0.59375
# 191/250 round completed......................... Accurecy: 0.59375
# 192/250 round completed......................... Accurecy: 0.59375
# 193/250 round completed......................... Accurecy: 0.59375
# 194/250 round completed......................... Accurecy: 0.59375
# 195/250 round completed......................... Accurecy: 0.59375
# 196/250 round completed......................... Accurecy: 0.59375
# 197/250 round completed......................... Accurecy: 0.59375
# 198/250 round completed......................... Accurecy: 0.59375
# 199/250 round completed......................... Accurecy: 0.59375
# 200/250 round completed......................... Accurecy: 0.59375
# 201/250 round completed......................... Accurecy: 0.59375
# 202/250 round completed......................... Accurecy: 0.59375
# 203/250 round completed......................... Accurecy: 0.59375
# 204/250 round completed......................... Accurecy: 0.59375
# 205/250 round completed......................... Accurecy: 0.59375
# 206/250 round completed......................... Accurecy: 0.59375
# 207/250 round completed......................... Accurecy: 0.59375
# 208/250 round completed......................... Accurecy: 0.59375
# 209/250 round completed......................... Accurecy: 0.59375
# 210/250 round completed......................... Accurecy: 0.59375
# 211/250 round completed......................... Accurecy: 0.59375
# 212/250 round completed......................... Accurecy: 0.625
# 213/250 round completed......................... Accurecy: 0.625
# 214/250 round completed......................... Accurecy: 0.625
# 215/250 round completed......................... Accurecy: 0.625
# 216/250 round completed......................... Accurecy: 0.625
# 217/250 round completed......................... Accurecy: 0.625
# 218/250 round completed......................... Accurecy: 0.625
# 219/250 round completed......................... Accurecy: 0.59375
# 220/250 round completed......................... Accurecy: 0.59375
# 221/250 round completed......................... Accurecy: 0.625
# 222/250 round completed......................... Accurecy: 0.625
# 223/250 round completed......................... Accurecy: 0.625
# 224/250 round completed......................... Accurecy: 0.625
# 225/250 round completed......................... Accurecy: 0.625
# 226/250 round completed......................... Accurecy: 0.625
# 227/250 round completed......................... Accurecy: 0.625
# 228/250 round completed......................... Accurecy: 0.625
# 229/250 round completed......................... Accurecy: 0.625
# 230/250 round completed......................... Accurecy: 0.625
# 231/250 round completed......................... Accurecy: 0.625
# 232/250 round completed......................... Accurecy: 0.625
# 233/250 round completed......................... Accurecy: 0.625
# 234/250 round completed......................... Accurecy: 0.625
# 235/250 round completed......................... Accurecy: 0.625
# 236/250 round completed......................... Accurecy: 0.625
# 237/250 round completed......................... Accurecy: 0.625
# 238/250 round completed......................... Accurecy: 0.625
# 239/250 round completed......................... Accurecy: 0.625
# 240/250 round completed......................... Accurecy: 0.625
# 241/250 round completed......................... Accurecy: 0.625
# 242/250 round completed......................... Accurecy: 0.625
# 243/250 round completed......................... Accurecy: 0.625
# 244/250 round completed......................... Accurecy: 0.625
# 245/250 round completed......................... Accurecy: 0.625
# 246/250 round completed......................... Accurecy: 0.625
# 247/250 round completed......................... Accurecy: 0.625
# 248/250 round completed......................... Accurecy: 0.625
# 249/250 round completed......................... Accurecy: 0.625
# 250/250 round completed......................... Accurecy: 0.625
# The best n_estimators:
# 18

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score
N=250
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  xgb_classifier = xgb.XGBClassifier(max_depth=k,random_state=0)
  xgb_classifier.fit(X_train, y_train)
  y_pred=xgb_classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/250 round completed......................... Accurecy: 0.59375
# 2/250 round completed......................... Accurecy: 0.625
# 3/250 round completed......................... Accurecy: 0.59375
# 4/250 round completed......................... Accurecy: 0.625
# 5/250 round completed......................... Accurecy: 0.59375
# 6/250 round completed......................... Accurecy: 0.5625
# 7/250 round completed......................... Accurecy: 0.5625
# 8/250 round completed......................... Accurecy: 0.5625
# 9/250 round completed......................... Accurecy: 0.5625
# 10/250 round completed......................... Accurecy: 0.5625
# 11/250 round completed......................... Accurecy: 0.5625
# 12/250 round completed......................... Accurecy: 0.5625
# 13/250 round completed......................... Accurecy: 0.5625
# 14/250 round completed......................... Accurecy: 0.5625
# 15/250 round completed......................... Accurecy: 0.5625
# 16/250 round completed......................... Accurecy: 0.5625
# 17/250 round completed......................... Accurecy: 0.5625
# 18/250 round completed......................... Accurecy: 0.5625
# 19/250 round completed......................... Accurecy: 0.5625
# 20/250 round completed......................... Accurecy: 0.5625
# 21/250 round completed......................... Accurecy: 0.5625
# 22/250 round completed......................... Accurecy: 0.5625
# 23/250 round completed......................... Accurecy: 0.5625
# 24/250 round completed......................... Accurecy: 0.5625
# 25/250 round completed......................... Accurecy: 0.5625
# 26/250 round completed......................... Accurecy: 0.5625
# 27/250 round completed......................... Accurecy: 0.5625
# 28/250 round completed......................... Accurecy: 0.5625
# 29/250 round completed......................... Accurecy: 0.5625
# 30/250 round completed......................... Accurecy: 0.5625
# 31/250 round completed......................... Accurecy: 0.5625
# 32/250 round completed......................... Accurecy: 0.5625
# 33/250 round completed......................... Accurecy: 0.5625
# 34/250 round completed......................... Accurecy: 0.5625
# 35/250 round completed......................... Accurecy: 0.5625
# 36/250 round completed......................... Accurecy: 0.5625
# 37/250 round completed......................... Accurecy: 0.5625
# 38/250 round completed......................... Accurecy: 0.5625
# 39/250 round completed......................... Accurecy: 0.5625
# 40/250 round completed......................... Accurecy: 0.5625
# 41/250 round completed......................... Accurecy: 0.5625
# 42/250 round completed......................... Accurecy: 0.5625
# 43/250 round completed......................... Accurecy: 0.5625
# 44/250 round completed......................... Accurecy: 0.5625
# 45/250 round completed......................... Accurecy: 0.5625
# 46/250 round completed......................... Accurecy: 0.5625
# 47/250 round completed......................... Accurecy: 0.5625
# 48/250 round completed......................... Accurecy: 0.5625
# 49/250 round completed......................... Accurecy: 0.5625
# 50/250 round completed......................... Accurecy: 0.5625
# 51/250 round completed......................... Accurecy: 0.5625
# 52/250 round completed......................... Accurecy: 0.5625
# 53/250 round completed......................... Accurecy: 0.5625
# 54/250 round completed......................... Accurecy: 0.5625
# 55/250 round completed......................... Accurecy: 0.5625
# 56/250 round completed......................... Accurecy: 0.5625
# 57/250 round completed......................... Accurecy: 0.5625
# 58/250 round completed......................... Accurecy: 0.5625
# 59/250 round completed......................... Accurecy: 0.5625
# 60/250 round completed......................... Accurecy: 0.5625
# 61/250 round completed......................... Accurecy: 0.5625
# 62/250 round completed......................... Accurecy: 0.5625
# 63/250 round completed......................... Accurecy: 0.5625
# 64/250 round completed......................... Accurecy: 0.5625
# 65/250 round completed......................... Accurecy: 0.5625
# 66/250 round completed......................... Accurecy: 0.5625
# 67/250 round completed......................... Accurecy: 0.5625
# 68/250 round completed......................... Accurecy: 0.5625
# 69/250 round completed......................... Accurecy: 0.5625
# 70/250 round completed......................... Accurecy: 0.5625
# 71/250 round completed......................... Accurecy: 0.5625
# 72/250 round completed......................... Accurecy: 0.5625
# 73/250 round completed......................... Accurecy: 0.5625
# 74/250 round completed......................... Accurecy: 0.5625
# 75/250 round completed......................... Accurecy: 0.5625
# 76/250 round completed......................... Accurecy: 0.5625
# 77/250 round completed......................... Accurecy: 0.5625
# 78/250 round completed......................... Accurecy: 0.5625
# 79/250 round completed......................... Accurecy: 0.5625
# 80/250 round completed......................... Accurecy: 0.5625
# 81/250 round completed......................... Accurecy: 0.5625
# 82/250 round completed......................... Accurecy: 0.5625
# 83/250 round completed......................... Accurecy: 0.5625
# 84/250 round completed......................... Accurecy: 0.5625
# 85/250 round completed......................... Accurecy: 0.5625
# 86/250 round completed......................... Accurecy: 0.5625
# 87/250 round completed......................... Accurecy: 0.5625
# 88/250 round completed......................... Accurecy: 0.5625
# 89/250 round completed......................... Accurecy: 0.5625
# 90/250 round completed......................... Accurecy: 0.5625
# 91/250 round completed......................... Accurecy: 0.5625
# 92/250 round completed......................... Accurecy: 0.5625
# 93/250 round completed......................... Accurecy: 0.5625
# 94/250 round completed......................... Accurecy: 0.5625
# 95/250 round completed......................... Accurecy: 0.5625
# 96/250 round completed......................... Accurecy: 0.5625
# 97/250 round completed......................... Accurecy: 0.5625
# 98/250 round completed......................... Accurecy: 0.5625
# 99/250 round completed......................... Accurecy: 0.5625
# 100/250 round completed......................... Accurecy: 0.5625
# 101/250 round completed......................... Accurecy: 0.5625
# 102/250 round completed......................... Accurecy: 0.5625
# 103/250 round completed......................... Accurecy: 0.5625
# 104/250 round completed......................... Accurecy: 0.5625
# 105/250 round completed......................... Accurecy: 0.5625
# 106/250 round completed......................... Accurecy: 0.5625
# 107/250 round completed......................... Accurecy: 0.5625
# 108/250 round completed......................... Accurecy: 0.5625
# 109/250 round completed......................... Accurecy: 0.5625
# 110/250 round completed......................... Accurecy: 0.5625
# 111/250 round completed......................... Accurecy: 0.5625
# 112/250 round completed......................... Accurecy: 0.5625
# 113/250 round completed......................... Accurecy: 0.5625
# 114/250 round completed......................... Accurecy: 0.5625
# 115/250 round completed......................... Accurecy: 0.5625
# 116/250 round completed......................... Accurecy: 0.5625
# 117/250 round completed......................... Accurecy: 0.5625
# 118/250 round completed......................... Accurecy: 0.5625
# 119/250 round completed......................... Accurecy: 0.5625
# 120/250 round completed......................... Accurecy: 0.5625
# 121/250 round completed......................... Accurecy: 0.5625
# 122/250 round completed......................... Accurecy: 0.5625
# 123/250 round completed......................... Accurecy: 0.5625
# 124/250 round completed......................... Accurecy: 0.5625
# 125/250 round completed......................... Accurecy: 0.5625
# 126/250 round completed......................... Accurecy: 0.5625
# 127/250 round completed......................... Accurecy: 0.5625
# 128/250 round completed......................... Accurecy: 0.5625
# 129/250 round completed......................... Accurecy: 0.5625
# 130/250 round completed......................... Accurecy: 0.5625
# 131/250 round completed......................... Accurecy: 0.5625
# 132/250 round completed......................... Accurecy: 0.5625
# 133/250 round completed......................... Accurecy: 0.5625
# 134/250 round completed......................... Accurecy: 0.5625
# 135/250 round completed......................... Accurecy: 0.5625
# 136/250 round completed......................... Accurecy: 0.5625
# 137/250 round completed......................... Accurecy: 0.5625
# 138/250 round completed......................... Accurecy: 0.5625
# 139/250 round completed......................... Accurecy: 0.5625
# 140/250 round completed......................... Accurecy: 0.5625
# 141/250 round completed......................... Accurecy: 0.5625
# 142/250 round completed......................... Accurecy: 0.5625
# 143/250 round completed......................... Accurecy: 0.5625
# 144/250 round completed......................... Accurecy: 0.5625
# 145/250 round completed......................... Accurecy: 0.5625
# 146/250 round completed......................... Accurecy: 0.5625
# 147/250 round completed......................... Accurecy: 0.5625
# 148/250 round completed......................... Accurecy: 0.5625
# 149/250 round completed......................... Accurecy: 0.5625
# 150/250 round completed......................... Accurecy: 0.5625
# 151/250 round completed......................... Accurecy: 0.5625
# 152/250 round completed......................... Accurecy: 0.5625
# 153/250 round completed......................... Accurecy: 0.5625
# 154/250 round completed......................... Accurecy: 0.5625
# 155/250 round completed......................... Accurecy: 0.5625
# 156/250 round completed......................... Accurecy: 0.5625
# 157/250 round completed......................... Accurecy: 0.5625
# 158/250 round completed......................... Accurecy: 0.5625
# 159/250 round completed......................... Accurecy: 0.5625
# 160/250 round completed......................... Accurecy: 0.5625
# 161/250 round completed......................... Accurecy: 0.5625
# 162/250 round completed......................... Accurecy: 0.5625
# 163/250 round completed......................... Accurecy: 0.5625
# 164/250 round completed......................... Accurecy: 0.5625
# 165/250 round completed......................... Accurecy: 0.5625
# 166/250 round completed......................... Accurecy: 0.5625
# 167/250 round completed......................... Accurecy: 0.5625
# 168/250 round completed......................... Accurecy: 0.5625
# 169/250 round completed......................... Accurecy: 0.5625
# 170/250 round completed......................... Accurecy: 0.5625
# 171/250 round completed......................... Accurecy: 0.5625
# 172/250 round completed......................... Accurecy: 0.5625
# 173/250 round completed......................... Accurecy: 0.5625
# 174/250 round completed......................... Accurecy: 0.5625
# 175/250 round completed......................... Accurecy: 0.5625
# 176/250 round completed......................... Accurecy: 0.5625
# 177/250 round completed......................... Accurecy: 0.5625
# 178/250 round completed......................... Accurecy: 0.5625
# 179/250 round completed......................... Accurecy: 0.5625
# 180/250 round completed......................... Accurecy: 0.5625
# 181/250 round completed......................... Accurecy: 0.5625
# 182/250 round completed......................... Accurecy: 0.5625
# 183/250 round completed......................... Accurecy: 0.5625
# 184/250 round completed......................... Accurecy: 0.5625
# 185/250 round completed......................... Accurecy: 0.5625
# 186/250 round completed......................... Accurecy: 0.5625
# 187/250 round completed......................... Accurecy: 0.5625
# 188/250 round completed......................... Accurecy: 0.5625
# 189/250 round completed......................... Accurecy: 0.5625
# 190/250 round completed......................... Accurecy: 0.5625
# 191/250 round completed......................... Accurecy: 0.5625
# 192/250 round completed......................... Accurecy: 0.5625
# 193/250 round completed......................... Accurecy: 0.5625
# 194/250 round completed......................... Accurecy: 0.5625
# 195/250 round completed......................... Accurecy: 0.5625
# 196/250 round completed......................... Accurecy: 0.5625
# 197/250 round completed......................... Accurecy: 0.5625
# 198/250 round completed......................... Accurecy: 0.5625
# 199/250 round completed......................... Accurecy: 0.5625
# 200/250 round completed......................... Accurecy: 0.5625
# 201/250 round completed......................... Accurecy: 0.5625
# 202/250 round completed......................... Accurecy: 0.5625
# 203/250 round completed......................... Accurecy: 0.5625
# 204/250 round completed......................... Accurecy: 0.5625
# 205/250 round completed......................... Accurecy: 0.5625
# 206/250 round completed......................... Accurecy: 0.5625
# 207/250 round completed......................... Accurecy: 0.5625
# 208/250 round completed......................... Accurecy: 0.5625
# 209/250 round completed......................... Accurecy: 0.5625
# 210/250 round completed......................... Accurecy: 0.5625
# 211/250 round completed......................... Accurecy: 0.5625
# 212/250 round completed......................... Accurecy: 0.5625
# 213/250 round completed......................... Accurecy: 0.5625
# 214/250 round completed......................... Accurecy: 0.5625
# 215/250 round completed......................... Accurecy: 0.5625
# 216/250 round completed......................... Accurecy: 0.5625
# 217/250 round completed......................... Accurecy: 0.5625
# 218/250 round completed......................... Accurecy: 0.5625
# 219/250 round completed......................... Accurecy: 0.5625
# 220/250 round completed......................... Accurecy: 0.5625
# 221/250 round completed......................... Accurecy: 0.5625
# 222/250 round completed......................... Accurecy: 0.5625
# 223/250 round completed......................... Accurecy: 0.5625
# 224/250 round completed......................... Accurecy: 0.5625
# 225/250 round completed......................... Accurecy: 0.5625
# 226/250 round completed......................... Accurecy: 0.5625
# 227/250 round completed......................... Accurecy: 0.5625
# 228/250 round completed......................... Accurecy: 0.5625
# 229/250 round completed......................... Accurecy: 0.5625
# 230/250 round completed......................... Accurecy: 0.5625
# 231/250 round completed......................... Accurecy: 0.5625
# 232/250 round completed......................... Accurecy: 0.5625
# 233/250 round completed......................... Accurecy: 0.5625
# 234/250 round completed......................... Accurecy: 0.5625
# 235/250 round completed......................... Accurecy: 0.5625
# 236/250 round completed......................... Accurecy: 0.5625
# 237/250 round completed......................... Accurecy: 0.5625
# 238/250 round completed......................... Accurecy: 0.5625
# 239/250 round completed......................... Accurecy: 0.5625
# 240/250 round completed......................... Accurecy: 0.5625
# 241/250 round completed......................... Accurecy: 0.5625
# 242/250 round completed......................... Accurecy: 0.5625
# 243/250 round completed......................... Accurecy: 0.5625
# 244/250 round completed......................... Accurecy: 0.5625
# 245/250 round completed......................... Accurecy: 0.5625
# 246/250 round completed......................... Accurecy: 0.5625
# 247/250 round completed......................... Accurecy: 0.5625
# 248/250 round completed......................... Accurecy: 0.5625
# 249/250 round completed......................... Accurecy: 0.5625
# 250/250 round completed......................... Accurecy: 0.5625
# The best depth:
# 2

# %%
import xgboost as xgb
xgb_depth = xgb.XGBClassifier(max_depth=best_depth,random_state=0)
xgb_depth.fit(X_train,y_train)
y_pred = xgb_depth.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_depth,4,'xgboost')]=accuracy_score(y_test, y_pred)
print(xgb_depth)
# Out:
# [[12  5]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67        17
#            1       0.62      0.53      0.57        15
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       0.62      0.62      0.62        32
#
# Accurecy:  0.625
# XGBClassifier(max_depth=2)

# %%
import xgboost as xgb
xgb_estimator = xgb.XGBClassifier(n_estimators=best_estimator,random_state=0)
xgb_estimator.fit(X_train,y_train)
y_pred = xgb_estimator.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_estimator,4,'xgboost')]=accuracy_score(y_test, y_pred)
print(xgb_estimator)
# Out:
# [[13  4]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72        17
#            1       0.69      0.60      0.64        15
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.68      0.68        32
# weighted avg       0.69      0.69      0.69        32
#
# Accurecy:  0.6875
# XGBClassifier(n_estimators=18)

# %%
import xgboost as xgb
xgb_all = xgb.XGBClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
xgb_all.fit(X_train,y_train)
y_pred = xgb_all.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_all,4,'xgboost')]=accuracy_score(y_test, y_pred)
# Out:
# [[13  4]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70        17
#            1       0.67      0.53      0.59        15
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.65      0.65        32
# weighted avg       0.66      0.66      0.65        32
#
# Accurecy:  0.65625

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_default = KNeighborsClassifier()
knn_default.fit(X_train, y_train)
y_pred=knn_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(knn_default,5,'KNeighborsClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[ 6 11]
#  [ 9  6]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.35      0.38        17
#            1       0.35      0.40      0.38        15
#
#     accuracy                           0.38        32
#    macro avg       0.38      0.38      0.38        32
# weighted avg       0.38      0.38      0.38        32
#
# Accurecy:  0.375

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
Neighbors=105
k_range = range (1,Neighbors+1)
scores={}
scores_list = []
for k in k_range:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred=knn.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(Neighbors)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best=list(scores.keys())[scores_list.index(max(scores_list))]
print(best)
# Out:
# 1/105 round completed......................... Accurecy: 0.5625
# 2/105 round completed......................... Accurecy: 0.46875
# 3/105 round completed......................... Accurecy: 0.4375
# 4/105 round completed......................... Accurecy: 0.375
# 5/105 round completed......................... Accurecy: 0.375
# 6/105 round completed......................... Accurecy: 0.34375
# 7/105 round completed......................... Accurecy: 0.3125
# 8/105 round completed......................... Accurecy: 0.375
# 9/105 round completed......................... Accurecy: 0.375
# 10/105 round completed......................... Accurecy: 0.4375
# 11/105 round completed......................... Accurecy: 0.40625
# 12/105 round completed......................... Accurecy: 0.4375
# 13/105 round completed......................... Accurecy: 0.4375
# 14/105 round completed......................... Accurecy: 0.375
# 15/105 round completed......................... Accurecy: 0.375
# 16/105 round completed......................... Accurecy: 0.40625
# 17/105 round completed......................... Accurecy: 0.4375
# 18/105 round completed......................... Accurecy: 0.46875
# 19/105 round completed......................... Accurecy: 0.46875
# 20/105 round completed......................... Accurecy: 0.53125
# 21/105 round completed......................... Accurecy: 0.53125
# 22/105 round completed......................... Accurecy: 0.53125
# 23/105 round completed......................... Accurecy: 0.5625
# 24/105 round completed......................... Accurecy: 0.59375
# 25/105 round completed......................... Accurecy: 0.53125
# 26/105 round completed......................... Accurecy: 0.53125
# 27/105 round completed......................... Accurecy: 0.53125
# 28/105 round completed......................... Accurecy: 0.625
# 29/105 round completed......................... Accurecy: 0.53125
# 30/105 round completed......................... Accurecy: 0.59375
# 31/105 round completed......................... Accurecy: 0.53125
# 32/105 round completed......................... Accurecy: 0.5625
# 33/105 round completed......................... Accurecy: 0.5625
# 34/105 round completed......................... Accurecy: 0.5625
# 35/105 round completed......................... Accurecy: 0.53125
# 36/105 round completed......................... Accurecy: 0.5625
# 37/105 round completed......................... Accurecy: 0.53125
# 38/105 round completed......................... Accurecy: 0.53125
# 39/105 round completed......................... Accurecy: 0.5625
# 40/105 round completed......................... Accurecy: 0.625
# 41/105 round completed......................... Accurecy: 0.5625
# 42/105 round completed......................... Accurecy: 0.53125
# 43/105 round completed......................... Accurecy: 0.5625
# 44/105 round completed......................... Accurecy: 0.5
# 45/105 round completed......................... Accurecy: 0.5
# 46/105 round completed......................... Accurecy: 0.5
# 47/105 round completed......................... Accurecy: 0.5625
# 48/105 round completed......................... Accurecy: 0.53125
# 49/105 round completed......................... Accurecy: 0.5625
# 50/105 round completed......................... Accurecy: 0.53125
# 51/105 round completed......................... Accurecy: 0.53125
# 52/105 round completed......................... Accurecy: 0.53125
# 53/105 round completed......................... Accurecy: 0.5
# 54/105 round completed......................... Accurecy: 0.5625
# 55/105 round completed......................... Accurecy: 0.53125
# 56/105 round completed......................... Accurecy: 0.625
# 57/105 round completed......................... Accurecy: 0.65625
# 58/105 round completed......................... Accurecy: 0.71875
# 59/105 round completed......................... Accurecy: 0.75
# 60/105 round completed......................... Accurecy: 0.75
# 61/105 round completed......................... Accurecy: 0.71875
# 62/105 round completed......................... Accurecy: 0.65625
# 63/105 round completed......................... Accurecy: 0.71875
# 64/105 round completed......................... Accurecy: 0.6875
# 65/105 round completed......................... Accurecy: 0.71875
# 66/105 round completed......................... Accurecy: 0.6875
# 67/105 round completed......................... Accurecy: 0.75
# 68/105 round completed......................... Accurecy: 0.6875
# 69/105 round completed......................... Accurecy: 0.6875
# 70/105 round completed......................... Accurecy: 0.6875
# 71/105 round completed......................... Accurecy: 0.75
# 72/105 round completed......................... Accurecy: 0.6875
# 73/105 round completed......................... Accurecy: 0.71875
# 74/105 round completed......................... Accurecy: 0.65625
# 75/105 round completed......................... Accurecy: 0.71875
# 76/105 round completed......................... Accurecy: 0.65625
# 77/105 round completed......................... Accurecy: 0.6875
# 78/105 round completed......................... Accurecy: 0.71875
# 79/105 round completed......................... Accurecy: 0.78125
# 80/105 round completed......................... Accurecy: 0.71875
# 81/105 round completed......................... Accurecy: 0.75
# 82/105 round completed......................... Accurecy: 0.71875
# 83/105 round completed......................... Accurecy: 0.71875
# 84/105 round completed......................... Accurecy: 0.71875
# 85/105 round completed......................... Accurecy: 0.65625
# 86/105 round completed......................... Accurecy: 0.65625
# 87/105 round completed......................... Accurecy: 0.6875
# 88/105 round completed......................... Accurecy: 0.65625
# 89/105 round completed......................... Accurecy: 0.625
# 90/105 round completed......................... Accurecy: 0.65625
# 91/105 round completed......................... Accurecy: 0.625
# 92/105 round completed......................... Accurecy: 0.71875
# 93/105 round completed......................... Accurecy: 0.6875
# 94/105 round completed......................... Accurecy: 0.6875
# 95/105 round completed......................... Accurecy: 0.78125
# 96/105 round completed......................... Accurecy: 0.65625
# 97/105 round completed......................... Accurecy: 0.6875
# 98/105 round completed......................... Accurecy: 0.65625
# 99/105 round completed......................... Accurecy: 0.65625
# 100/105 round completed......................... Accurecy: 0.6875
# 101/105 round completed......................... Accurecy: 0.65625
# 102/105 round completed......................... Accurecy: 0.6875
# 103/105 round completed......................... Accurecy: 0.71875
# 104/105 round completed......................... Accurecy: 0.71875
# 105/105 round completed......................... Accurecy: 0.59375
# The best Depth:
# 79

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_neighbors = KNeighborsClassifier(n_neighbors=best)
knn_neighbors.fit(X_train, y_train)
y_pred=knn_neighbors.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(knn_neighbors,5,'KNeighborsClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  2]
#  [ 5 10]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81        17
#            1       0.83      0.67      0.74        15
#
#     accuracy                           0.78        32
#    macro avg       0.79      0.77      0.78        32
# weighted avg       0.79      0.78      0.78        32
#
# Accurecy:  0.78125

# %% [markdown]
# #NB

# %%
from sklearn.naive_bayes import GaussianNB

nb_deafult = GaussianNB()
nb_deafult.fit(X_train, y_train)
y_pred = nb_deafult.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(nb_deafult,6,'GaussianNB')]=accuracy_score(y_test, y_pred)
# Out:
# [[11  6]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63        17
#            1       0.57      0.53      0.55        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
# Accurecy:  0.59375

# %% [markdown]
# #Histogram-Based Gradient Boosting

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hisgradBoost_default = HistGradientBoostingClassifier(random_state=0)
hisgradBoost_default.fit(X_train, y_train)
y_pred = hisgradBoost_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_default,7,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[11  6]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63        17
#            1       0.57      0.53      0.55        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
# Accurecy:  0.59375

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=1000
k_range = range (100,N+1,100)
scores={}
scores_list = []
for k in k_range:
  hisgradBoost_cls = HistGradientBoostingClassifier(max_iter=k,random_state=0)
  hisgradBoost_cls.fit(X_train, y_train)
  y_pred=hisgradBoost_cls.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best max_iter:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 100/1000 round completed......................... Accurecy: 0.59375
# 200/1000 round completed......................... Accurecy: 0.625
# 300/1000 round completed......................... Accurecy: 0.625
# 400/1000 round completed......................... Accurecy: 0.625
# 500/1000 round completed......................... Accurecy: 0.625
# 600/1000 round completed......................... Accurecy: 0.625
# 700/1000 round completed......................... Accurecy: 0.625
# 800/1000 round completed......................... Accurecy: 0.59375
# 900/1000 round completed......................... Accurecy: 0.59375
# 1000/1000 round completed......................... Accurecy: 0.59375
# The best max_iter:
# 200

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=50
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  hisgradBoost_cls = HistGradientBoostingClassifier(max_depth=k,random_state=0)
  hisgradBoost_cls.fit(X_train, y_train)
  y_pred=hisgradBoost_cls.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best max_depth:")
max_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(max_depth)
# Out:
# 1/50 round completed......................... Accurecy: 0.59375
# 2/50 round completed......................... Accurecy: 0.65625
# 3/50 round completed......................... Accurecy: 0.625
# 4/50 round completed......................... Accurecy: 0.65625
# 5/50 round completed......................... Accurecy: 0.59375
# 6/50 round completed......................... Accurecy: 0.59375
# 7/50 round completed......................... Accurecy: 0.59375
# 8/50 round completed......................... Accurecy: 0.59375
# 9/50 round completed......................... Accurecy: 0.59375
# 10/50 round completed......................... Accurecy: 0.59375
# 11/50 round completed......................... Accurecy: 0.59375
# 12/50 round completed......................... Accurecy: 0.59375
# 13/50 round completed......................... Accurecy: 0.59375
# 14/50 round completed......................... Accurecy: 0.59375
# 15/50 round completed......................... Accurecy: 0.59375
# 16/50 round completed......................... Accurecy: 0.59375
# 17/50 round completed......................... Accurecy: 0.59375
# 18/50 round completed......................... Accurecy: 0.59375
# 19/50 round completed......................... Accurecy: 0.59375
# 20/50 round completed......................... Accurecy: 0.59375
# 21/50 round completed......................... Accurecy: 0.59375
# 22/50 round completed......................... Accurecy: 0.59375
# 23/50 round completed......................... Accurecy: 0.59375
# 24/50 round completed......................... Accurecy: 0.59375
# 25/50 round completed......................... Accurecy: 0.59375
# 26/50 round completed......................... Accurecy: 0.59375
# 27/50 round completed......................... Accurecy: 0.59375
# 28/50 round completed......................... Accurecy: 0.59375
# 29/50 round completed......................... Accurecy: 0.59375
# 30/50 round completed......................... Accurecy: 0.59375
# 31/50 round completed......................... Accurecy: 0.59375
# 32/50 round completed......................... Accurecy: 0.59375
# 33/50 round completed......................... Accurecy: 0.59375
# 34/50 round completed......................... Accurecy: 0.59375
# 35/50 round completed......................... Accurecy: 0.59375
# 36/50 round completed......................... Accurecy: 0.59375
# 37/50 round completed......................... Accurecy: 0.59375
# 38/50 round completed......................... Accurecy: 0.59375
# 39/50 round completed......................... Accurecy: 0.59375
# 40/50 round completed......................... Accurecy: 0.59375
# 41/50 round completed......................... Accurecy: 0.59375
# 42/50 round completed......................... Accurecy: 0.59375
# 43/50 round completed......................... Accurecy: 0.59375
# 44/50 round completed......................... Accurecy: 0.59375
# 45/50 round completed......................... Accurecy: 0.59375
# 46/50 round completed......................... Accurecy: 0.59375
# 47/50 round completed......................... Accurecy: 0.59375
# 48/50 round completed......................... Accurecy: 0.59375
# 49/50 round completed......................... Accurecy: 0.59375
# 50/50 round completed......................... Accurecy: 0.59375
# The best max_depth:
# 2

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hisgradBoost_max_iter = HistGradientBoostingClassifier(max_iter=best_estimator,random_state=0)
hisgradBoost_max_iter.fit(X_train, y_train)
y_pred = hisgradBoost_max_iter.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_max_iter,8,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[12  5]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67        17
#            1       0.62      0.53      0.57        15
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       0.62      0.62      0.62        32
#
# Accurecy:  0.625

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hisgradBoost_max_depth = HistGradientBoostingClassifier(max_depth=max_depth,random_state=0)
hisgradBoost_max_depth.fit(X_train, y_train)
y_pred = hisgradBoost_max_depth.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_max_depth,9,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[13  4]
#  [ 7  8]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70        17
#            1       0.67      0.53      0.59        15
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.65      0.65        32
# weighted avg       0.66      0.66      0.65        32
#
# Accurecy:  0.65625

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hisgradBoost_all = HistGradientBoostingClassifier(max_iter=best_estimator,max_depth=max_depth,random_state=0)
hisgradBoost_all.fit(X_train, y_train)
y_pred = hisgradBoost_all.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_all,10,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[12  5]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69        17
#            1       0.64      0.60      0.62        15
#
#     accuracy                           0.66        32
#    macro avg       0.65      0.65      0.65        32
# weighted avg       0.66      0.66      0.66        32
#
# Accurecy:  0.65625

# %% [markdown]
# #Result

# %%
models=[]

for i in result:
  models.append(i[0])
  print(i[0],i[1]," : ",result[i])
  print("---------------------------------------------------------------")
  print()
# Out:
# AdaBoostClassifier(random_state=0) 1  :  0.59375
# ---------------------------------------------------------------
#
# AdaBoostClassifier(n_estimators=6, random_state=0) 1  :  0.6875
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(random_state=0) 2  :  0.6875
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(n_estimators=48, random_state=0) 2  :  0.71875
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(random_state=0) 2  :  0.6875
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(n_estimators=48, random_state=0) 2  :  0.71875
# ---------------------------------------------------------------
#
# RandomForestClassifier(random_state=0) 3  :  0.5625
# ---------------------------------------------------------------
#
# RandomForestClassifier(n_estimators=5, random_state=0) 3  :  0.6875
# ---------------------------------------------------------------
#
# RandomForestClassifier(max_depth=1, random_state=0) 3  :  0.6875
# ---------------------------------------------------------------
#
# RandomForestClassifier(max_depth=1, n_estimators=5, random_state=0) 3  :  0.4375
# ---------------------------------------------------------------
#
# XGBClassifier() 4  :  0.59375
# ---------------------------------------------------------------
#
# XGBClassifier(max_depth=2) 4  :  0.625
# ---------------------------------------------------------------
#
# XGBClassifier(n_estimators=18) 4  :  0.6875
# ---------------------------------------------------------------
#
# XGBClassifier(max_depth=2, n_estimators=18) 4  :  0.65625
# ---------------------------------------------------------------
#
# KNeighborsClassifier() 5  :  0.375
# ---------------------------------------------------------------
#
# KNeighborsClassifier(n_neighbors=79) 5  :  0.78125
# ---------------------------------------------------------------
#
# GaussianNB() 6  :  0.59375
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(random_state=0) 7  :  0.59375
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(max_iter=200, random_state=0) 8  :  0.625
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(max_depth=2, random_state=0) 9  :  0.65625
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(max_depth=2, max_iter=200, random_state=0) 10  :  0.65625
# ---------------------------------------------------------------

# %%
sorted_list=[]
sorted_list = sorted(result, key=result.get,reverse=True)

for i in sorted_list:
  print(i,"  : ",result[i])
  print("-------------------------------------------------------------------------------------------------")

print(sorted_list)


flage=[]
best_models=[]
it=0

for i in sorted_list:
  if it==4:
    break

  if i[1] not in flage:
    best_models.append((i[0],i[2]))
    flage.append(i[1])
    it+=1
# Out:
# (AdaBoostClassifier(n_estimators=11, random_state=0), 1, 'AdaBoostClassifier')   :  0.8484848484848485
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(n_neighbors=1), 5, 'KNeighborsClassifier')   :  0.8484848484848485
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(n_estimators=30, random_state=0), 3, 'RandomForestClassifier')   :  0.8181818181818182
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(n_estimators=83), 4, 'xgboost')   :  0.8181818181818182
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(n_estimators=1, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7878787878787878
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=5, random_state=0), 3, 'RandomForestClassifier')   :  0.7878787878787878
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=5, n_estimators=30, random_state=0), 3, 'RandomForestClassifier')   :  0.7878787878787878
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=1, random_state=0), 9, 'HistGradientBoostingClassifier')   :  0.7878787878787878
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=1, random_state=0), 10, 'HistGradientBoostingClassifier')   :  0.7878787878787878
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(n_estimators=83, random_state=0), 1, 'AdaBoostClassifier')   :  0.78125
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier')   :  0.7575757575757576
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(), 4, 'xgboost')   :  0.7575757575757576
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(max_depth=1), 4, 'xgboost')   :  0.7575757575757576
# -------------------------------------------------------------------------------------------------
# ('cat_default', 11, 'CatBoostClassifier')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=1, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=1, n_estimators=1, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(max_depth=1, n_estimators=83), 4, 'xgboost')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (GaussianNB(), 6, 'GaussianNB')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier')   :  0.7272727272727273
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(n_neighbors=4), 5, 'KNeighborsClassifier')   :  0.71875
# -------------------------------------------------------------------------------------------------
# (GaussianNB(), 6, 'GaussianNB')   :  0.71875
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier')   :  0.696969696969697
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(), 5, 'KNeighborsClassifier')   :  0.696969696969697
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0), 2, 'GradientBoostingClassifier')   :  0.6875
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(n_estimators=25, random_state=0), 3, 'RandomForestClassifier')   :  0.6875
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier')   :  0.6666666666666666
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier')   :  0.6666666666666666
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=2, random_state=0), 9, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=2, random_state=0), 10, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(n_estimators=124, random_state=0), 2, 'GradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=2, random_state=0), 2, 'GradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=3, random_state=0), 3, 'RandomForestClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0), 3, 'RandomForestClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(n_estimators=3), 4, 'xgboost')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(n_estimators=3), 4, 'xgboost')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=2, random_state=0), 9, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=2, random_state=0), 10, 'HistGradientBoostingClassifier')   :  0.65625
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier')   :  0.625
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(), 4, 'xgboost')   :  0.625
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(), 4, 'xgboost')   :  0.625
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(), 5, 'KNeighborsClassifier')   :  0.625
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier')   :  0.5625
# -------------------------------------------------------------------------------------------------
# [(AdaBoostClassifier(n_estimators=11, random_state=0), 1, 'AdaBoostClassifier'), (KNeighborsClassifier(n_neighbors=1), 5, 'KNeighborsClassifier'), (RandomForestClassifier(n_estimators=30, random_state=0), 3, 'RandomForestClassifier'), (XGBClassifier(n_estimators=83), 4, 'xgboost'), (GradientBoostingClassifier(n_estimators=1, random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(max_depth=5, random_state=0), 3, 'RandomForestClassifier'), (RandomForestClassifier(max_depth=5, n_estimators=30, random_state=0), 3, 'RandomForestClassifier'), (HistGradientBoostingClassifier(max_depth=1, random_state=0), 9, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=1, random_state=0), 10, 'HistGradientBoostingClassifier'), (AdaBoostClassifier(n_estimators=83, random_state=0), 1, 'AdaBoostClassifier'), (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier'), (XGBClassifier(), 4, 'xgboost'), (XGBClassifier(max_depth=1), 4, 'xgboost'), ('cat_default', 11, 'CatBoostClassifier'), (GradientBoostingClassifier(max_depth=1, random_state=0), 2, 'GradientBoostingClassifier'), (GradientBoostingClassifier(max_depth=1, n_estimators=1, random_state=0), 2, 'GradientBoostingClassifier'), (XGBClassifier(max_depth=1, n_estimators=83), 4, 'xgboost'), (GaussianNB(), 6, 'GaussianNB'), (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier'), (KNeighborsClassifier(n_neighbors=4), 5, 'KNeighborsClassifier'), (GaussianNB(), 6, 'GaussianNB'), (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier'), (KNeighborsClassifier(), 5, 'KNeighborsClassifier'), (GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(n_estimators=25, random_state=0), 3, 'RandomForestClassifier'), (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier'), (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier'), (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=2, random_state=0), 9, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=2, random_state=0), 10, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier'), (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier'), (GradientBoostingClassifier(n_estimators=124, random_state=0), 2, 'GradientBoostingClassifier'), (GradientBoostingClassifier(max_depth=2, random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(max_depth=3, random_state=0), 3, 'RandomForestClassifier'), (RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0), 3, 'RandomForestClassifier'), (XGBClassifier(n_estimators=3), 4, 'xgboost'), (XGBClassifier(n_estimators=3), 4, 'xgboost'), (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=2, random_state=0), 9, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=2, random_state=0), 10, 'HistGradientBoostingClassifier'), (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier'), (XGBClassifier(), 4, 'xgboost'), (XGBClassifier(), 4, 'xgboost'), (KNeighborsClassifier(), 5, 'KNeighborsClassifier'), (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier')]

# %%
print("best_models:")
for i in best_models:
  print(i)
# Out:
# best_models:
# (AdaBoostClassifier(n_estimators=11, random_state=0), 'AdaBoostClassifier')
# (KNeighborsClassifier(n_neighbors=1), 'KNeighborsClassifier')
# (RandomForestClassifier(n_estimators=30, random_state=0), 'RandomForestClassifier')
# (XGBClassifier(n_estimators=83), 'xgboost')

# %%
len(best_models)
# Out:
# 4

# %% [markdown]
# #Testing Accuracy For Best 4 Models

# %%
for i in best_models:
  print("--------------------------------------------------")
  print(i[0])
  y_pred=i[0].predict(X_test)
  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test,y_pred))
  print("Accurecy: ",accuracy_score(y_test, y_pred))
# Out:
# --------------------------------------------------
# AdaBoostClassifier(n_estimators=83, random_state=0)
# [[13  4]
#  [ 3 12]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79        17
#            1       0.75      0.80      0.77        15
#
#     accuracy                           0.78        32
#    macro avg       0.78      0.78      0.78        32
# weighted avg       0.78      0.78      0.78        32
#
# Accurecy:  0.78125
# --------------------------------------------------
# KNeighborsClassifier(n_neighbors=4)
# [[14  3]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76        17
#            1       0.75      0.60      0.67        15
#
#     accuracy                           0.72        32
#    macro avg       0.72      0.71      0.71        32
# weighted avg       0.72      0.72      0.71        32
#
# Accurecy:  0.71875
# --------------------------------------------------
# GaussianNB()
# [[14  3]
#  [ 6  9]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76        17
#            1       0.75      0.60      0.67        15
#
#     accuracy                           0.72        32
#    macro avg       0.72      0.71      0.71        32
# weighted avg       0.72      0.72      0.71        32
#
# Accurecy:  0.71875
# --------------------------------------------------
# GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)
# [[12  5]
#  [ 5 10]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71        17
#            1       0.67      0.67      0.67        15
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32
#
# Accurecy:  0.6875

# %% [markdown]
# #SHAP

# %%
# !pip install shap
import shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shap in /usr/local/lib/python3.8/dist-packages (0.41.0)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.8/dist-packages (from shap) (4.64.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.8/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.8/dist-packages (from shap) (23.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba->shap) (6.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba->shap) (3.12.0)

# %%
def SHAP_EXP(model,graph_feat):
  print("Models: ",model)

  explainer = shap.Explainer(model.predict, X_train)

  shap_values1 = explainer(X_train)
  features_names=list_of_feat2

  if 'Subjects' in features_names:
    features_names.pop(0)

  print("Global Explaination")
  shap.plots.bar(shap_values1,max_display=30)

  print("Global Explaination")

  shap.summary_plot(shap_values1,max_display=30)

  print("---------------------")

  print("Local Explaination")
  shap.plots.waterfall(shap_values1[graph_feat["shap_values Index"]],max_display=25)


  print("Local Explaination")

  shap.plots.bar(shap_values1[graph_feat["shap_values Index"]],max_display=25)

# %% [markdown]
# **Model Check Box Function**

# %%
def models_check_box(models):
  import ipywidgets as widgets
  from IPython.display import display
  new_keys=[]
  for i in models:
    i=widgets.Checkbox(
      value=False,
      description=str(i),
      disabled=False,
      indent=False
      )
    display(i)
    new_keys.append(i)
  return new_keys

# %%
new_keys_7=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
graph_feat={
    "max_display":30,
    "shap_values Index":10
}

for i in range(len(new_keys_7)):
  if new_keys_7[i].value ==True:
    SHAP_EXP(models[i],graph_feat)
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
# Out:
# Models:  GaussianNB()
# Global Explaination
# Global Explaination
# ---------------------
# Local Explaination
# Local Explaination
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------

# %% [markdown]
# #Confusion Matrix For Testing

# %%
new_keys_6=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
from yellowbrick.classifier import ConfusionMatrix


for i in range(len(new_keys_6)):
  if new_keys_6[i].value ==True:
    cm = ConfusionMatrix(models[i], classes=classes)

    cm.fit(X_train, y_train)
    cm.score(X_test, y_test)
    cm.show()

# %% [markdown]
# #Confusion Matrix For Training

# %%
new_keys_5=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
for i in range(len(new_keys_5)):
  if new_keys_5[i].value ==True:
    cm = ConfusionMatrix(models[i], classes=classes)

    cm.fit(X_train, y_train)
    cm.score(X_train, y_train)
    cm.show()
    print("-------------------------------")
    print("-------------------------------")

# %% [markdown]
# #Result CSV<br>
# Predicted and Actual Row will be added at the end index

# %%
def reverse_transfrom(my_list):
  for i in range(len(my_list)):
    if my_list[i] == 0:
      my_list[i] = 'Control'
    else:
      my_list[i] = 'Patient'
  return my_list

# %%
new_keys_4=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
for i in range(len(new_keys_4)):
  if new_keys_4[i].value ==True:
    temp=X_test

    prediction_cls = reverse_transfrom(list(models[i].predict(X_test[0:])))
    actual_cls = reverse_transfrom(list(y_test[0:]))

    temp["Actual"] = actual_cls
    temp["Predicted"] = prediction_cls

    temp.to_csv(str(models[i])+".csv")

# %% [markdown]
# #ROC Comparaing Machine Learning Models

# %%
def ROC(mod,X_t,y_t,graph_feat):
  r_probs = [0 for _ in range(len(y_t))]

  model_probs = []


  for i in mod:
    model_probs.append(i.predict_proba(X_t))


  model_probs2=[]

  for i in model_probs:
    model_probs2.append(i[:,1])


  from sklearn.metrics import roc_curve, roc_auc_score

  model_auc=[]
  r_auc = roc_auc_score(y_t, r_probs)

  for i in model_probs2:
    model_auc.append(roc_auc_score(y_t,i))


  fpr_tpr=[]
  r_fpr, r_tpr, _ = roc_curve(y_t, r_probs)

  for i in model_probs2:
    fpr, tpr, _ = roc_curve(y_t, i)
    fpr_tpr.append((fpr,tpr))

  import matplotlib.pyplot as plt
  plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)

  for i in range(len(model_auc)):
    plt.plot(fpr_tpr[i][0], fpr_tpr[i][1], marker='.', label=str(mod[i])+' (AUROC = %0.3f)' % model_auc[i])

  # Title
  plt.title('ROC Plot Testing',fontsize= graph_feat["Title Size"], fontweight=graph_feat["Title Fontweight"])
  plt.xlabel('False Positive Rate',fontweight=graph_feat["X axis Label Fontweight"],fontsize=graph_feat["X axis Label Font Size"])
  plt.ylabel('True Positive Rate',fontweight=graph_feat["Y axis Label Fontweight"],fontsize=graph_feat["Y axis Label Font Size"])
  
  plt.legend( 
           prop = {'size' : graph_feat["legend Font Size"]}, 
           loc = graph_feat["legend Position"])
  
  fig = plt.gcf()
  fig.set_size_inches(graph_feat["Fig Width (inches)"], graph_feat["Fig Height (inches)"])
  fig.savefig(graph_feat["Fig Saving Name"], dpi=graph_feat["dpi"])
  plt.show()

# %% [markdown]
# ***Training ROC***<br>
# Chosse the Models

# %%
new_keys_2=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %% [markdown]
# Change  the given dictionary of graph feature for desire graph.

# %%
graph_feat={
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_training.png",
    "dpi":100

}

mod=[]
for i in range(len(new_keys_2)):
  if new_keys_2[i].value ==True:
    mod.append(models[i])

ROC(mod,X_train,y_train,graph_feat)

# %% [markdown]
# ---

# %% [markdown]
# ***Testing ROC***<br>
# Chosse the Models

# %%
new_keys_3=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %% [markdown]
# Change  the given dictionary of graph feature for desire graph.

# %%
graph_feat={
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}

mod=[]
for i in range(len(new_keys_3)):
  if new_keys_3[i].value ==True:
    mod.append(models[i])

ROC(mod,X_test,y_test,graph_feat)

# %% [markdown]
# #Cross_val_score function

# %%
from sklearn.model_selection import cross_val_score

k=5
for i in result:
  print(i[0]," -> Accuracy: ",result[i])
  l=list(cross_val_score(i[0],X_new.iloc[:,1:], y_new,cv=k))
  avg=sum(l)/k
  print(i[0]," -> AVG Accurecy After CV: "+str(avg)+ " (For "+str(k)+" Fold)")
  print("--------------------------------------------------------------------------")
# Out:
# AdaBoostClassifier(random_state=0)  -> Accuracy:  0.65625
# AdaBoostClassifier(random_state=0)  -> AVG Accurecy After CV: 0.6242424242424243 (For 5 Fold)
# --------------------------------------------------------------------------
# AdaBoostClassifier(n_estimators=83, random_state=0)  -> Accuracy:  0.78125
# AdaBoostClassifier(n_estimators=83, random_state=0)  -> AVG Accurecy After CV: 0.6727272727272727 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(random_state=0)  -> Accuracy:  0.625
# GradientBoostingClassifier(random_state=0)  -> AVG Accurecy After CV: 0.6424242424242425 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(n_estimators=124, random_state=0)  -> Accuracy:  0.65625
# GradientBoostingClassifier(n_estimators=124, random_state=0)  -> AVG Accurecy After CV: 0.6484848484848486 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(max_depth=2, random_state=0)  -> Accuracy:  0.65625
# GradientBoostingClassifier(max_depth=2, random_state=0)  -> AVG Accurecy After CV: 0.7151515151515152 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)  -> Accuracy:  0.6875
# GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)  -> AVG Accurecy After CV: 0.6848484848484849 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(random_state=0)  -> Accuracy:  0.5625
# RandomForestClassifier(random_state=0)  -> AVG Accurecy After CV: 0.703030303030303 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(n_estimators=25, random_state=0)  -> Accuracy:  0.6875
# RandomForestClassifier(n_estimators=25, random_state=0)  -> AVG Accurecy After CV: 0.6848484848484848 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(max_depth=3, random_state=0)  -> Accuracy:  0.65625
# RandomForestClassifier(max_depth=3, random_state=0)  -> AVG Accurecy After CV: 0.6787878787878788 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)  -> Accuracy:  0.65625
# RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)  -> AVG Accurecy After CV: 0.6484848484848486 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier()  -> Accuracy:  0.625
# XGBClassifier()  -> AVG Accurecy After CV: 0.6666666666666667 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier()  -> Accuracy:  0.625
# XGBClassifier()  -> AVG Accurecy After CV: 0.6666666666666667 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier(n_estimators=3)  -> Accuracy:  0.65625
# XGBClassifier(n_estimators=3)  -> AVG Accurecy After CV: 0.6787878787878788 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier(n_estimators=3)  -> Accuracy:  0.65625
# XGBClassifier(n_estimators=3)  -> AVG Accurecy After CV: 0.6787878787878788 (For 5 Fold)
# --------------------------------------------------------------------------
# KNeighborsClassifier()  -> Accuracy:  0.625
# KNeighborsClassifier()  -> AVG Accurecy After CV: 0.6727272727272727 (For 5 Fold)
# --------------------------------------------------------------------------
# KNeighborsClassifier(n_neighbors=4)  -> Accuracy:  0.71875
# KNeighborsClassifier(n_neighbors=4)  -> AVG Accurecy After CV: 0.6666666666666666 (For 5 Fold)
# --------------------------------------------------------------------------
# GaussianNB()  -> Accuracy:  0.71875
# GaussianNB()  -> AVG Accurecy After CV: 0.7030303030303031 (For 5 Fold)
# --------------------------------------------------------------------------

# %%
def CV_ROC(model,folds,graph_feat):
  import matplotlib.pyplot as plt

  from sklearn import svm
  from sklearn.metrics import auc,roc_curve
  from sklearn.metrics import RocCurveDisplay
  from sklearn.model_selection import StratifiedKFold


  cv = StratifiedKFold(n_splits=folds)



  tprs = []
  aucs = []
  mean_fpr = np.linspace(0,1,100)
  i = 1
  for train,test in cv.split(X_new.iloc[:,1:], y_new.values):
      prediction = model.fit(X_new.iloc[:,1:].values[train], y_new.values[train]).predict_proba(X_new.iloc[:,1:].values[test])
      fpr, tpr, t = roc_curve(y_new.values[test], prediction[:, 1])
      tprs.append(np.interp(mean_fpr, fpr, tpr))
      roc_auc = auc(fpr, tpr)
      aucs.append(roc_auc)
      plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
      i= i+1

  plt.plot([0,1],[0,1],linestyle = '--',lw = 2,color = 'black')
  mean_tpr = np.mean(tprs, axis=0)
  mean_auc = auc(mean_fpr, mean_tpr)
  plt.plot(mean_fpr, mean_tpr, color='blue',
          label=r'Mean ROC (AUC = %0.2f )' % (mean_auc),lw=2, alpha=1)

  plt.title('CV-ROC-> '+str(model),fontsize= graph_feat["Title Size"], fontweight=graph_feat["Title Fontweight"])
  plt.xlabel('False Positive Rate',fontweight=graph_feat["X axis Label Fontweight"],fontsize=graph_feat["X axis Label Font Size"])
  plt.ylabel('True Positive Rate',fontweight=graph_feat["Y axis Label Fontweight"],fontsize=graph_feat["Y axis Label Font Size"])
  plt.legend( 
           prop = {'size' : graph_feat["legend Font Size"]}, 
           loc = graph_feat["legend Position"])
  
  fig = plt.gcf()
  fig.set_size_inches(graph_feat["Fig Width (inches)"], graph_feat["Fig Height (inches)"])
  fig.savefig(graph_feat["Fig Saving Name"], dpi=graph_feat["dpi"])
  plt.show()

# %%
new_keys=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=83, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=124, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=2, n_estimators=124, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=25, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=3, n_estimators=25, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=3)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %% [markdown]
# <font color="apple green">Just mark the above cell to select the Multiple Algorithms for ROC CV graph. <font color="sky blue"><b>Then run the cell below after selecting.</b></font> You do not need to run above cell everytime...</font><font color='red'><b>Do not run above cell after selecting</b></font>

# %%
# run this cell after selecting

graph_feat={
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}





k_fold=5

for i in range(len(new_keys)):
  if new_keys[i].value ==True:
    CV_ROC(models[i],5,graph_feat)
    print("-----------------------------------------------------------------")
    print("-----------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------
# -----------------------------------------------------------------

# %% [markdown]
# #ANN Classification
