# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/PreTraining_Tunning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Function

# %%
# !pip install imbalanced-learn
# !pip install ipywidgets

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
import ipywidgets as widgets
from joblib import Parallel, delayed
from google.colab import files
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


def dataset_balance(X_temp, y_temp):
  smote = SMOTE()
  X_temp, y_temp= smote.fit_resample(X_temp, y_temp)
  return pd.concat([pd.DataFrame(X_temp), pd.DataFrame(y_temp)], axis=1)


def Xy_balance(X_temp, y_temp):
  smote = SMOTE()
  return smote.fit_resample(X_temp, y_temp)


def save_model(model,model_name):
 joblib.dump(model, model_name)
  

def load_model(model_name):
  return joblib.load(model_name)


def Search_Null(dataset):
  dic={}
  for col in list(dataset.columns):
    rows = []
    flage = 0
    for row in range(dataset.shape[0]):
      if str(dataset[col][row]) == "nan":
        rows.append(row)
        flage = 1
    if flage ==1:
      dic[col] = rows
  return dic



def divide_dataset(dataset,percentage,random_state = 0):
  rows,cols = dataset.shape
  if random_state == 0:
    return dataset.iloc[:int(rows*(percentage)),:]
  else:
    import random
    l_r = random.sample(range(0, rows), int(rows*(percentage)))
    return dataset.iloc[l_r,:]



def StandardScaleData(data):
  scaler = StandardScaler()
  scaler.fit(data)
  return  scaler.transform(data)



def MinMaxScaleData(data):
  scaler = MinMaxScaler()
  scaler.fit(data)
  return scaler.transform(data)


def tune_report_csv(model,dic,feat_selection_method,number_of_feat):

  tunning_type = []
  accuracy = []
  scaled_accuracy = []
  model_name = []
  feature_selection_method = []
  number_of_features = []

  li = ["Smote : NO    ; Scaling : Train(Standard)",
      "Smote : NO    ; Scaling : Train(MinMax)",
      "Smote : Train ; Scaling : Train(Standard)",
      "Smote : Train ; Scaling : Train(MinMax)",
      "Smote : All   ; Scaling : Train(Standard)",
      "Smote : All   ; Scaling : Train(MinMax)"]

  for i in list(dic.keys()):
    X_train, X_test, y_train, y_test = dic[i]
    
    if i in li and str(model[:3]) == "xgb":
      model.fit(X_train,y_train.values)
      y_pred = model.predict(X_test.values)
    else:
      model.fit(X_train,y_train)
      y_pred = model.predict(X_test)

    accu =accuracy_score(y_test, y_pred)
    scaled_accu =  float("{:.2f}".format(accu))
    print(i)
    print("Accurecy: ",scaled_accu)
    tunning_type.append(i)
    accuracy.append(accu)
    scaled_accuracy.append(scaled_accu)
    model_name.append(model)
    feature_selection_method.append(feat_selection_method)
    number_of_features.append(number_of_feat)
    
    print("------------------------------------------------------------------------------")
    print("------------------------------------------------------------------------------")

  csv_dic={
      "model_name"  : model_name,
      "tunning_type" : tunning_type,
      "accurecy"    : accuracy, 
      "scaled_accuracy" :scaled_accuracy,
      "feature_selection_method" : feature_selection_method,
      "number_of_features" : number_of_features
  }


  df = pd.DataFrame.from_dict(csv_dic)
  df.to_csv(feat_selection_method+"_"+str(number_of_feat)+"_"+str(model)+".csv")
  return "Tunning Data Report is Secured for this phase!!!"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (7.7.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.6.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (5.7.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.1)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.11.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.1.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.15.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.6.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.11.0)

# %% [markdown]
# #Starting

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Sleep Stage 5 class/EEG_HMC_FeatureExtraction_2023.01.19.csv")
print(dataset.shape)
dataset.dropna(axis = 0,how='any', inplace = True)
dataset = dataset.reset_index(drop = True)
"""df.to_csv("New_EEG_NullValueRemoved_HMC.csv",index = False)
dataset = pd.read_csv("New_EEG_NullValueRemoved_HMC.csv")"""
target = "Sleep Stage"
result = {}
print(dataset.shape)

#Encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset[target]=encoder.fit_transform(dataset[target])

dataset = divide_dataset(dataset,0.02)
print(dataset.shape)
# Out:
# (108920, 52)
# (108450, 52)
# (2169, 52)

# %% [markdown]
# ###Spliting into X and y

# %%
X =  dataset.loc[:,dataset.columns != target]  # removing Sleep Stage
X =  X.loc[:,X.columns != "Subject"]            # removing Status
X =  X.loc[:,X.columns != "Epoch"]             # removing Epoch
y = dataset[target]

# %% [markdown]
# #Feature Selection

# %%
number_of_feat = 15

# %% [markdown]
# ###ANOVA with f classifciation

# %%
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import pandas as pd



fs = SelectKBest(score_func=f_classif, k=5)
fit = fs.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_ANOVA'] 

lyst = featureScores.nlargest(number_of_feat,'Score_ANOVA')

#lyst.to_csv('Filter_Method_ANOVA_with_f_classif.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "ANOVA"

# %% [markdown]
# ###Embedded Method

# %%
from sklearn.linear_model import LassoCV
reg = LassoCV()
reg.fit(X, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,y))
coef = pd.Series(reg.coef_, index = X.columns)

print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")

imp_coef = coef.sort_values()

list_of_feat=[]


for i in range(coef.shape[0]):
  if coef[i]!=0:
    list_of_feat.append(dataset.iloc[:0,i+3].name)
    
df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Embedded_Method.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]
selection_method = "Embedded"

# %% [markdown]
# ###Pearson's with f regression

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
import pandas as pd


fs = SelectKBest(score_func=f_regression, k=5)
fit = fs.fit(X,y)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(dataset.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_pearsons'] 


lyst = featureScores.nlargest(number_of_feat,'Score_pearsons')

#lyst.to_csv('Filter_Method_Pearson’s_with_f_regression.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "Pearson"

# %% [markdown]
# ###Sequential Feature Selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
sfs = SequentialFeatureSelector(knn, n_features_to_select=number_of_feat)
sfs.fit(X, y)
list_of_feat=[]
list_of_feat=list(sfs.get_feature_names_out(X.columns))

df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Filter_Method_Sequential_feat_Selection_KNN.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]

selection_method = "Sequential"

# %% [markdown]
# #Feature list

# %%
X=dataset[list_of_feat]
y=dataset[target]
print(X.shape)
# Out:
# (2169, 15)

# %% [markdown]
# #Tunning for Scalling and Data Balancing

# %% [markdown]
# ##Smote : NO
# ##Scaling : NO

# %%
def tune_1():
  X_new = X
  y_new = y
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : All Data (Standard)

# %%
def tune_2():
  X_new = StandardScaleData(X)
  y_new = y
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : All Data (MinMax)

# %%
def tune_3():
  X_new = MinMaxScaleData(X)
  y_new = y
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : Train (Stadard)

# %%
def tune_4():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : NO
# ##Scaling : Train (MinMax)

# %%
def tune_5():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : ALL
# ##Scaling : NO

# %%
def tune_6():
  X_new,y_new = Xy_balance(X,y)
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : Train
# ##Scaling : NO

# %%
def tune_7():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train,y_train = Xy_balance(X_train,y_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : Train
# ##Scaling : Train (Standard)

# %%
def tune_8():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train,y_train = Xy_balance(X_train,y_train)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : Train
# ##Scaling : Train (MixMax)

# %%
def tune_9():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train,y_train = Xy_balance(X_train,y_train)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : Train (Standard)

# %%
def tune_10():
  X_new,y_new = Xy_balance(X,y)
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : Train (MixMax)

# %%
def tune_11():
  X_new,y_new = Xy_balance(X,y)
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : All (Standard)

# %%
def tune_12():
  X_new,y_new = Xy_balance(X,y)
  X_new = StandardScaleData(X_new)
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : All
# ##Scaling : ALL (MinMax)

# %%
def tune_13():
  X_new,y_new = Xy_balance(X,y)
  X_new = MinMaxScaleData(X_new)
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Tunn Dictionary

# %%
tune_dic={
  "Smote : NO    ; Scaling : NO"                  : tune_1(),
  "Smote : NO    ; Scaling : All Data(Standard)"  : tune_2(),
  "Smote : NO    ; Scaling : All Data(MinMax)"    : tune_3(),
  #"Smote : NO    ; Scaling : Train(Standard)"     : tune_4(),
  #"Smote : NO    ; Scaling : Train(MinMax)"       : tune_5(),
  "Smote : ALL   ; Scaling : NO"                  : tune_6(),
  "Smote : Train ; Scaling : NO"                  : tune_7(),
  #"Smote : Train ; Scaling : Train(Standard)"     : tune_8(),
  #"Smote : Train ; Scaling : Train(MinMax)"       : tune_9(),
  #"Smote : All   ; Scaling : Train(Standard)"     : tune_10(),
  #"Smote : All   ; Scaling : Train(MinMax)"       : tune_11(),
  "Smote : All   ; Scaling : All(Standard)"       : tune_12(),
  "Smote : All   ; Scaling : All(MinMax)"        : tune_13()
}

# %% [markdown]
# ---

# %% [markdown]
# # **Training**

# %% [markdown]
# ##ADABOOST

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
ada_defult = AdaBoostClassifier(random_state=0)
tune_report_csv(ada_defult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.47
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.47
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.47
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.51
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.53
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.52
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.58
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 1.77 s, sys: 0 ns, total: 1.77 s
# Wall time: 1.77 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##Graddient Boosting

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
gradBoost_default = GradientBoostingClassifier(random_state=0)

tune_report_csv(gradBoost_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.84
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.79
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.84
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.85
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 32.6 s, sys: 0 ns, total: 32.6 s
# Wall time: 32.5 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ###Histogram-Based Gradient Boosting

# %%
# %%time
from sklearn.ensemble import HistGradientBoostingClassifier

hisgradBoost_default = HistGradientBoostingClassifier(random_state=0)

tune_report_csv(hisgradBoost_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.87
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.89
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.9
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 22.3 s, sys: 806 ms, total: 23.1 s
# Wall time: 12 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##Random Forest

# %%
# %%time
RanFor={}

from sklearn.ensemble import RandomForestClassifier
rf_default = RandomForestClassifier(random_state=0,n_jobs=-1)

tune_report_csv(rf_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.79
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.79
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.79
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.88
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.88
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.89
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 4.4 s, sys: 231 ms, total: 4.63 s
# Wall time: 2.87 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##XGB

# %%
# %%time
import xgboost as xgb
xgb_deafult = xgb.XGBClassifier(random_state=0,n_jobs=-1)

tune_report_csv(xgb_deafult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.84
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.78
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.84
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.84
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 9.68 s, sys: 53.9 ms, total: 9.73 s
# Wall time: 5.09 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
knn_default = KNeighborsClassifier(n_jobs = -1)

tune_report_csv(knn_default,tune_dic,selection_method,number_of_feat)

# %% [markdown]
# ##NB

# %%
# %%time
from sklearn.naive_bayes import GaussianNB

nb_deafult = GaussianNB()

tune_report_csv(nb_deafult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.63
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.58
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.61
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 42.5 ms, sys: 2.09 ms, total: 44.6 ms
# Wall time: 60.5 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##Tree algorithms

# %% [markdown]
# ###DecisionTreeRegressor

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
tune_report_csv(dtc,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.69
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.7
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.81
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.7
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.82
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.81
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 247 ms, sys: 4.66 ms, total: 251 ms
# Wall time: 245 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %%
# !pip install catboost

from catboost import CatBoostClassifier
#cat = CatBoostClassifier(task_type="GPU")
cat=CatBoostClassifier()

tune_report_csv(cat,tune_dic,selection_method,number_of_feat)
# Out:
# Streaming output truncated to the last 5000 lines.
# 24:	learn: 0.7334933	total: 348ms	remaining: 13.6s
# 25:	learn: 0.7215576	total: 360ms	remaining: 13.5s
# 26:	learn: 0.7119744	total: 384ms	remaining: 13.8s
# 27:	learn: 0.7031771	total: 395ms	remaining: 13.7s
# 28:	learn: 0.6951561	total: 407ms	remaining: 13.6s
# 29:	learn: 0.6864816	total: 419ms	remaining: 13.6s
# 30:	learn: 0.6781042	total: 434ms	remaining: 13.6s
# 31:	learn: 0.6695554	total: 453ms	remaining: 13.7s
# 32:	learn: 0.6626420	total: 468ms	remaining: 13.7s
# 33:	learn: 0.6555510	total: 480ms	remaining: 13.6s
# 34:	learn: 0.6496669	total: 492ms	remaining: 13.6s
# 35:	learn: 0.6438255	total: 505ms	remaining: 13.5s
# 36:	learn: 0.6376865	total: 516ms	remaining: 13.4s
# 37:	learn: 0.6300449	total: 528ms	remaining: 13.4s
# 38:	learn: 0.6239610	total: 540ms	remaining: 13.3s
# 39:	learn: 0.6195682	total: 553ms	remaining: 13.3s
# 40:	learn: 0.6146199	total: 566ms	remaining: 13.2s
# 41:	learn: 0.6083040	total: 579ms	remaining: 13.2s
# 42:	learn: 0.6023617	total: 594ms	remaining: 13.2s
# 43:	learn: 0.5977940	total: 607ms	remaining: 13.2s
# 44:	learn: 0.5917108	total: 619ms	remaining: 13.1s
# 45:	learn: 0.5876000	total: 631ms	remaining: 13.1s
# 46:	learn: 0.5826056	total: 643ms	remaining: 13s
# 47:	learn: 0.5780457	total: 660ms	remaining: 13.1s
# 48:	learn: 0.5737935	total: 672ms	remaining: 13s
# 49:	learn: 0.5699458	total: 683ms	remaining: 13s
# 50:	learn: 0.5651392	total: 703ms	remaining: 13.1s
# 51:	learn: 0.5610689	total: 715ms	remaining: 13s
# 52:	learn: 0.5576558	total: 726ms	remaining: 13s
# 53:	learn: 0.5538603	total: 739ms	remaining: 12.9s
# 54:	learn: 0.5505693	total: 752ms	remaining: 12.9s
# 55:	learn: 0.5487470	total: 765ms	remaining: 12.9s
# 56:	learn: 0.5462488	total: 781ms	remaining: 12.9s
# 57:	learn: 0.5426314	total: 793ms	remaining: 12.9s
# 58:	learn: 0.5396762	total: 805ms	remaining: 12.8s
# 59:	learn: 0.5375703	total: 816ms	remaining: 12.8s
# 60:	learn: 0.5348085	total: 828ms	remaining: 12.7s
# 61:	learn: 0.5321383	total: 842ms	remaining: 12.7s
# 62:	learn: 0.5290684	total: 853ms	remaining: 12.7s
# 63:	learn: 0.5255102	total: 871ms	remaining: 12.7s
# 64:	learn: 0.5225423	total: 882ms	remaining: 12.7s
# 65:	learn: 0.5199607	total: 892ms	remaining: 12.6s
# 66:	learn: 0.5175486	total: 904ms	remaining: 12.6s
# 67:	learn: 0.5136121	total: 917ms	remaining: 12.6s
# 68:	learn: 0.5115069	total: 928ms	remaining: 12.5s
# 69:	learn: 0.5091872	total: 939ms	remaining: 12.5s
# 70:	learn: 0.5065683	total: 956ms	remaining: 12.5s
# 71:	learn: 0.5044499	total: 973ms	remaining: 12.5s
# 72:	learn: 0.5018624	total: 984ms	remaining: 12.5s
# 73:	learn: 0.4997658	total: 995ms	remaining: 12.5s
# 74:	learn: 0.4974461	total: 1s	remaining: 12.4s
# 75:	learn: 0.4951217	total: 1.02s	remaining: 12.4s
# 76:	learn: 0.4934194	total: 1.03s	remaining: 12.3s
# 77:	learn: 0.4914385	total: 1.04s	remaining: 12.3s
# 78:	learn: 0.4901294	total: 1.05s	remaining: 12.3s
# 79:	learn: 0.4879797	total: 1.06s	remaining: 12.2s
# 80:	learn: 0.4854946	total: 1.08s	remaining: 12.3s
# 81:	learn: 0.4824120	total: 1.09s	remaining: 12.2s
# 82:	learn: 0.4797899	total: 1.1s	remaining: 12.2s
# 83:	learn: 0.4784031	total: 1.11s	remaining: 12.2s
# 84:	learn: 0.4770708	total: 1.13s	remaining: 12.1s
# 85:	learn: 0.4747046	total: 1.14s	remaining: 12.1s
# 86:	learn: 0.4728983	total: 1.15s	remaining: 12.1s
# 87:	learn: 0.4714523	total: 1.17s	remaining: 12.1s
# 88:	learn: 0.4700668	total: 1.18s	remaining: 12.1s
# 89:	learn: 0.4681819	total: 1.19s	remaining: 12s
# 90:	learn: 0.4662431	total: 1.2s	remaining: 12s
# 91:	learn: 0.4648601	total: 1.21s	remaining: 12s
# 92:	learn: 0.4629858	total: 1.22s	remaining: 11.9s
# 93:	learn: 0.4614086	total: 1.25s	remaining: 12s
# 94:	learn: 0.4598176	total: 1.26s	remaining: 12s
# 95:	learn: 0.4587045	total: 1.27s	remaining: 12s
# 96:	learn: 0.4576140	total: 1.29s	remaining: 12s
# 97:	learn: 0.4563201	total: 1.3s	remaining: 12s
# 98:	learn: 0.4541429	total: 1.31s	remaining: 12s
# 99:	learn: 0.4530482	total: 1.32s	remaining: 11.9s
# 100:	learn: 0.4522760	total: 1.34s	remaining: 11.9s
# 101:	learn: 0.4506287	total: 1.35s	remaining: 11.9s
# 102:	learn: 0.4486950	total: 1.36s	remaining: 11.9s
# 103:	learn: 0.4480057	total: 1.38s	remaining: 11.9s
# 104:	learn: 0.4467583	total: 1.39s	remaining: 11.9s
# 105:	learn: 0.4448755	total: 1.4s	remaining: 11.8s
# 106:	learn: 0.4428685	total: 1.42s	remaining: 11.8s
# 107:	learn: 0.4422031	total: 1.43s	remaining: 11.8s
# 108:	learn: 0.4406329	total: 1.44s	remaining: 11.8s
# 109:	learn: 0.4385608	total: 1.45s	remaining: 11.7s
# 110:	learn: 0.4366262	total: 1.46s	remaining: 11.7s
# 111:	learn: 0.4351480	total: 1.47s	remaining: 11.7s
# 112:	learn: 0.4330534	total: 1.49s	remaining: 11.7s
# 113:	learn: 0.4321968	total: 1.5s	remaining: 11.7s
# 114:	learn: 0.4304590	total: 1.51s	remaining: 11.7s
# 115:	learn: 0.4300732	total: 1.52s	remaining: 11.6s
# 116:	learn: 0.4289439	total: 1.54s	remaining: 11.6s
# 117:	learn: 0.4283473	total: 1.55s	remaining: 11.6s
# 118:	learn: 0.4275402	total: 1.56s	remaining: 11.6s
# 119:	learn: 0.4261036	total: 1.58s	remaining: 11.6s
# 120:	learn: 0.4249199	total: 1.59s	remaining: 11.6s
# 121:	learn: 0.4232945	total: 1.6s	remaining: 11.5s
# 122:	learn: 0.4211194	total: 1.61s	remaining: 11.5s
# 123:	learn: 0.4194845	total: 1.63s	remaining: 11.5s
# 124:	learn: 0.4179132	total: 1.64s	remaining: 11.5s
# 125:	learn: 0.4162647	total: 1.65s	remaining: 11.4s
# 126:	learn: 0.4150099	total: 1.66s	remaining: 11.4s
# 127:	learn: 0.4138396	total: 1.67s	remaining: 11.4s
# 128:	learn: 0.4119685	total: 1.69s	remaining: 11.4s
# 129:	learn: 0.4111206	total: 1.7s	remaining: 11.4s
# 130:	learn: 0.4099002	total: 1.71s	remaining: 11.4s
# 131:	learn: 0.4086219	total: 1.73s	remaining: 11.3s
# 132:	learn: 0.4074689	total: 1.74s	remaining: 11.3s
# 133:	learn: 0.4064225	total: 1.75s	remaining: 11.3s
# 134:	learn: 0.4050743	total: 1.76s	remaining: 11.3s
# 135:	learn: 0.4032569	total: 1.77s	remaining: 11.2s
# 136:	learn: 0.4028592	total: 1.78s	remaining: 11.2s
# 137:	learn: 0.4018063	total: 1.8s	remaining: 11.2s
# 138:	learn: 0.4001824	total: 1.82s	remaining: 11.3s
# 139:	learn: 0.3979354	total: 1.83s	remaining: 11.2s
# 140:	learn: 0.3968707	total: 1.84s	remaining: 11.2s
# 141:	learn: 0.3947598	total: 1.85s	remaining: 11.2s
# 142:	learn: 0.3939640	total: 1.86s	remaining: 11.2s
# 143:	learn: 0.3935551	total: 1.88s	remaining: 11.1s
# 144:	learn: 0.3920086	total: 1.89s	remaining: 11.1s
# 145:	learn: 0.3916151	total: 1.9s	remaining: 11.1s
# 146:	learn: 0.3906519	total: 1.92s	remaining: 11.1s
# 147:	learn: 0.3892685	total: 1.93s	remaining: 11.1s
# 148:	learn: 0.3883904	total: 1.95s	remaining: 11.1s
# 149:	learn: 0.3873321	total: 1.96s	remaining: 11.1s
# 150:	learn: 0.3860085	total: 1.98s	remaining: 11.1s
# 151:	learn: 0.3850534	total: 1.99s	remaining: 11.1s
# 152:	learn: 0.3832705	total: 2s	remaining: 11.1s
# 153:	learn: 0.3822789	total: 2.02s	remaining: 11.1s
# 154:	learn: 0.3811946	total: 2.03s	remaining: 11.1s
# 155:	learn: 0.3800273	total: 2.04s	remaining: 11.1s
# 156:	learn: 0.3792894	total: 2.06s	remaining: 11s
# 157:	learn: 0.3786761	total: 2.07s	remaining: 11s
# 158:	learn: 0.3777933	total: 2.08s	remaining: 11s
# 159:	learn: 0.3775246	total: 2.1s	remaining: 11s
# 160:	learn: 0.3764209	total: 2.11s	remaining: 11s
# 161:	learn: 0.3751137	total: 2.13s	remaining: 11s
# 162:	learn: 0.3735916	total: 2.14s	remaining: 11s
# 163:	learn: 0.3718068	total: 2.15s	remaining: 11s
# 164:	learn: 0.3704866	total: 2.16s	remaining: 10.9s
# 165:	learn: 0.3694419	total: 2.17s	remaining: 10.9s
# 166:	learn: 0.3681856	total: 2.18s	remaining: 10.9s
# 167:	learn: 0.3672162	total: 2.19s	remaining: 10.9s
# 168:	learn: 0.3668046	total: 2.21s	remaining: 10.9s
# 169:	learn: 0.3661495	total: 2.22s	remaining: 10.8s
# 170:	learn: 0.3655041	total: 2.23s	remaining: 10.8s
# 171:	learn: 0.3635668	total: 2.24s	remaining: 10.8s
# 172:	learn: 0.3622391	total: 2.25s	remaining: 10.8s
# 173:	learn: 0.3615006	total: 2.27s	remaining: 10.8s
# 174:	learn: 0.3606674	total: 2.28s	remaining: 10.7s
# 175:	learn: 0.3596984	total: 2.29s	remaining: 10.7s
# 176:	learn: 0.3584979	total: 2.31s	remaining: 10.7s
# 177:	learn: 0.3572105	total: 2.32s	remaining: 10.7s
# 178:	learn: 0.3564973	total: 2.33s	remaining: 10.7s
# 179:	learn: 0.3551164	total: 2.35s	remaining: 10.7s
# 180:	learn: 0.3539981	total: 2.37s	remaining: 10.7s
# 181:	learn: 0.3536632	total: 2.38s	remaining: 10.7s
# 182:	learn: 0.3532960	total: 2.4s	remaining: 10.7s
# 183:	learn: 0.3523996	total: 2.41s	remaining: 10.7s
# 184:	learn: 0.3515387	total: 2.42s	remaining: 10.7s
# 185:	learn: 0.3510985	total: 2.43s	remaining: 10.6s
# 186:	learn: 0.3497492	total: 2.44s	remaining: 10.6s
# 187:	learn: 0.3491600	total: 2.46s	remaining: 10.6s
# 188:	learn: 0.3485555	total: 2.47s	remaining: 10.6s
# 189:	learn: 0.3478094	total: 2.49s	remaining: 10.6s
# 190:	learn: 0.3462912	total: 2.5s	remaining: 10.6s
# 191:	learn: 0.3457866	total: 2.52s	remaining: 10.6s
# 192:	learn: 0.3453778	total: 2.53s	remaining: 10.6s
# 193:	learn: 0.3450885	total: 2.54s	remaining: 10.6s
# 194:	learn: 0.3437969	total: 2.56s	remaining: 10.6s
# 195:	learn: 0.3426977	total: 2.57s	remaining: 10.5s
# 196:	learn: 0.3422888	total: 2.58s	remaining: 10.5s
# 197:	learn: 0.3409401	total: 2.59s	remaining: 10.5s
# 198:	learn: 0.3391758	total: 2.6s	remaining: 10.5s
# 199:	learn: 0.3378228	total: 2.62s	remaining: 10.5s
# 200:	learn: 0.3373745	total: 2.63s	remaining: 10.4s
# 201:	learn: 0.3359233	total: 2.64s	remaining: 10.4s
# 202:	learn: 0.3355216	total: 2.65s	remaining: 10.4s
# 203:	learn: 0.3347428	total: 2.66s	remaining: 10.4s
# 204:	learn: 0.3334992	total: 2.67s	remaining: 10.4s
# 205:	learn: 0.3325288	total: 2.68s	remaining: 10.3s
# 206:	learn: 0.3318186	total: 2.69s	remaining: 10.3s
# 207:	learn: 0.3308790	total: 2.7s	remaining: 10.3s
# 208:	learn: 0.3302405	total: 2.71s	remaining: 10.3s
# 209:	learn: 0.3291342	total: 2.73s	remaining: 10.3s
# 210:	learn: 0.3285642	total: 2.75s	remaining: 10.3s
# 211:	learn: 0.3278440	total: 2.76s	remaining: 10.2s
# 212:	learn: 0.3271634	total: 2.77s	remaining: 10.2s
# 213:	learn: 0.3258679	total: 2.78s	remaining: 10.2s
# 214:	learn: 0.3248955	total: 2.79s	remaining: 10.2s
# 215:	learn: 0.3240636	total: 2.8s	remaining: 10.2s
# 216:	learn: 0.3238776	total: 2.81s	remaining: 10.2s
# 217:	learn: 0.3232489	total: 2.83s	remaining: 10.1s
# 218:	learn: 0.3226557	total: 2.84s	remaining: 10.1s
# 219:	learn: 0.3219128	total: 2.85s	remaining: 10.1s
# 220:	learn: 0.3215224	total: 2.87s	remaining: 10.1s
# 221:	learn: 0.3207716	total: 2.88s	remaining: 10.1s
# 222:	learn: 0.3201216	total: 2.89s	remaining: 10.1s
# 223:	learn: 0.3194815	total: 2.9s	remaining: 10.1s
# 224:	learn: 0.3192663	total: 2.92s	remaining: 10.1s
# 225:	learn: 0.3186826	total: 2.93s	remaining: 10s
# 226:	learn: 0.3181185	total: 2.94s	remaining: 10s
# 227:	learn: 0.3173508	total: 2.96s	remaining: 10s
# 228:	learn: 0.3160546	total: 2.97s	remaining: 9.99s
# 229:	learn: 0.3151295	total: 2.98s	remaining: 9.97s
# 230:	learn: 0.3139304	total: 2.99s	remaining: 9.95s
# 231:	learn: 0.3135181	total: 3s	remaining: 9.93s
# 232:	learn: 0.3126933	total: 3.01s	remaining: 9.91s
# 233:	learn: 0.3123207	total: 3.02s	remaining: 9.89s
# 234:	learn: 0.3109962	total: 3.04s	remaining: 9.88s
# 235:	learn: 0.3100643	total: 3.05s	remaining: 9.87s
# 236:	learn: 0.3096546	total: 3.06s	remaining: 9.86s
# 237:	learn: 0.3091814	total: 3.07s	remaining: 9.84s
# 238:	learn: 0.3086118	total: 3.08s	remaining: 9.82s
# 239:	learn: 0.3080544	total: 3.1s	remaining: 9.81s
# 240:	learn: 0.3072406	total: 3.11s	remaining: 9.79s
# 241:	learn: 0.3066349	total: 3.12s	remaining: 9.77s
# 242:	learn: 0.3051861	total: 3.13s	remaining: 9.77s
# 243:	learn: 0.3043439	total: 3.15s	remaining: 9.75s
# 244:	learn: 0.3040927	total: 3.16s	remaining: 9.73s
# 245:	learn: 0.3030649	total: 3.17s	remaining: 9.72s
# 246:	learn: 0.3022557	total: 3.18s	remaining: 9.7s
# 247:	learn: 0.3016453	total: 3.19s	remaining: 9.68s
# 248:	learn: 0.3011986	total: 3.2s	remaining: 9.66s
# 249:	learn: 0.3005379	total: 3.21s	remaining: 9.64s
# 250:	learn: 0.2993979	total: 3.23s	remaining: 9.63s
# 251:	learn: 0.2987633	total: 3.24s	remaining: 9.61s
# 252:	learn: 0.2979378	total: 3.25s	remaining: 9.6s
# 253:	learn: 0.2971010	total: 3.26s	remaining: 9.58s
# 254:	learn: 0.2965297	total: 3.27s	remaining: 9.56s
# 255:	learn: 0.2959043	total: 3.28s	remaining: 9.54s
# 256:	learn: 0.2952880	total: 3.29s	remaining: 9.53s
# 257:	learn: 0.2948237	total: 3.31s	remaining: 9.51s
# 258:	learn: 0.2945826	total: 3.32s	remaining: 9.49s
# 259:	learn: 0.2940661	total: 3.33s	remaining: 9.47s
# 260:	learn: 0.2937614	total: 3.35s	remaining: 9.47s
# 261:	learn: 0.2932945	total: 3.36s	remaining: 9.46s
# 262:	learn: 0.2925951	total: 3.37s	remaining: 9.44s
# 263:	learn: 0.2925028	total: 3.38s	remaining: 9.42s
# 264:	learn: 0.2916820	total: 3.39s	remaining: 9.4s
# 265:	learn: 0.2911740	total: 3.4s	remaining: 9.38s
# 266:	learn: 0.2907086	total: 3.41s	remaining: 9.37s
# 267:	learn: 0.2896642	total: 3.42s	remaining: 9.35s
# 268:	learn: 0.2894353	total: 3.43s	remaining: 9.33s
# 269:	learn: 0.2889174	total: 3.44s	remaining: 9.31s
# 270:	learn: 0.2882801	total: 3.46s	remaining: 9.3s
# 271:	learn: 0.2871937	total: 3.47s	remaining: 9.28s
# 272:	learn: 0.2865409	total: 3.48s	remaining: 9.26s
# 273:	learn: 0.2860747	total: 3.49s	remaining: 9.24s
# 274:	learn: 0.2856298	total: 3.5s	remaining: 9.22s
# 275:	learn: 0.2849050	total: 3.51s	remaining: 9.21s
# 276:	learn: 0.2842862	total: 3.52s	remaining: 9.19s
# 277:	learn: 0.2839688	total: 3.53s	remaining: 9.17s
# 278:	learn: 0.2830934	total: 3.55s	remaining: 9.17s
# 279:	learn: 0.2828891	total: 3.56s	remaining: 9.15s
# 280:	learn: 0.2822415	total: 3.57s	remaining: 9.13s
# 281:	learn: 0.2820299	total: 3.58s	remaining: 9.11s
# 282:	learn: 0.2814131	total: 3.59s	remaining: 9.1s
# 283:	learn: 0.2811285	total: 3.6s	remaining: 9.08s
# 284:	learn: 0.2801748	total: 3.61s	remaining: 9.06s
# 285:	learn: 0.2799630	total: 3.62s	remaining: 9.04s
# 286:	learn: 0.2793455	total: 3.63s	remaining: 9.03s
# 287:	learn: 0.2787103	total: 3.65s	remaining: 9.01s
# 288:	learn: 0.2779576	total: 3.66s	remaining: 9s
# 289:	learn: 0.2775321	total: 3.67s	remaining: 8.98s
# 290:	learn: 0.2770773	total: 3.68s	remaining: 8.96s
# 291:	learn: 0.2761671	total: 3.69s	remaining: 8.94s
# 292:	learn: 0.2755480	total: 3.7s	remaining: 8.93s
# 293:	learn: 0.2751716	total: 3.71s	remaining: 8.91s
# 294:	learn: 0.2746279	total: 3.72s	remaining: 8.89s
# 295:	learn: 0.2742471	total: 3.73s	remaining: 8.88s
# 296:	learn: 0.2740522	total: 3.74s	remaining: 8.86s
# 297:	learn: 0.2733636	total: 3.76s	remaining: 8.86s
# 298:	learn: 0.2729634	total: 3.77s	remaining: 8.84s
# 299:	learn: 0.2723526	total: 3.78s	remaining: 8.82s
# 300:	learn: 0.2715376	total: 3.79s	remaining: 8.8s
# 301:	learn: 0.2714125	total: 3.8s	remaining: 8.79s
# 302:	learn: 0.2709075	total: 3.81s	remaining: 8.77s
# 303:	learn: 0.2705150	total: 3.82s	remaining: 8.76s
# 304:	learn: 0.2702484	total: 3.84s	remaining: 8.74s
# 305:	learn: 0.2697890	total: 3.85s	remaining: 8.73s
# 306:	learn: 0.2691127	total: 3.87s	remaining: 8.73s
# 307:	learn: 0.2684492	total: 3.88s	remaining: 8.72s
# 308:	learn: 0.2680596	total: 3.89s	remaining: 8.7s
# 309:	learn: 0.2678517	total: 3.91s	remaining: 8.7s
# 310:	learn: 0.2673862	total: 3.92s	remaining: 8.68s
# 311:	learn: 0.2670282	total: 3.93s	remaining: 8.66s
# 312:	learn: 0.2661240	total: 3.94s	remaining: 8.65s
# 313:	learn: 0.2655172	total: 3.95s	remaining: 8.63s
# 314:	learn: 0.2647217	total: 3.97s	remaining: 8.63s
# 315:	learn: 0.2642752	total: 3.98s	remaining: 8.61s
# 316:	learn: 0.2641222	total: 3.99s	remaining: 8.59s
# 317:	learn: 0.2637078	total: 4s	remaining: 8.57s
# 318:	learn: 0.2635227	total: 4.01s	remaining: 8.56s
# 319:	learn: 0.2629148	total: 4.02s	remaining: 8.55s
# 320:	learn: 0.2622497	total: 4.03s	remaining: 8.53s
# 321:	learn: 0.2616684	total: 4.05s	remaining: 8.52s
# 322:	learn: 0.2609667	total: 4.06s	remaining: 8.51s
# 323:	learn: 0.2607926	total: 4.07s	remaining: 8.49s
# 324:	learn: 0.2603230	total: 4.08s	remaining: 8.48s
# 325:	learn: 0.2597897	total: 4.09s	remaining: 8.46s
# 326:	learn: 0.2593618	total: 4.1s	remaining: 8.45s
# 327:	learn: 0.2588256	total: 4.12s	remaining: 8.43s
# 328:	learn: 0.2580083	total: 4.13s	remaining: 8.42s
# 329:	learn: 0.2571518	total: 4.14s	remaining: 8.4s
# 330:	learn: 0.2569944	total: 4.15s	remaining: 8.38s
# 331:	learn: 0.2566141	total: 4.16s	remaining: 8.37s
# 332:	learn: 0.2557335	total: 4.18s	remaining: 8.38s
# 333:	learn: 0.2552734	total: 4.19s	remaining: 8.36s
# 334:	learn: 0.2544926	total: 4.2s	remaining: 8.34s
# 335:	learn: 0.2541023	total: 4.21s	remaining: 8.33s
# 336:	learn: 0.2535651	total: 4.22s	remaining: 8.31s
# 337:	learn: 0.2528552	total: 4.24s	remaining: 8.3s
# 338:	learn: 0.2521793	total: 4.25s	remaining: 8.28s
# 339:	learn: 0.2519849	total: 4.26s	remaining: 8.26s
# 340:	learn: 0.2513297	total: 4.27s	remaining: 8.25s
# 341:	learn: 0.2509439	total: 4.28s	remaining: 8.23s
# 342:	learn: 0.2501425	total: 4.29s	remaining: 8.21s
# 343:	learn: 0.2498343	total: 4.3s	remaining: 8.2s
# 344:	learn: 0.2490705	total: 4.31s	remaining: 8.18s
# 345:	learn: 0.2485714	total: 4.32s	remaining: 8.17s
# 346:	learn: 0.2481888	total: 4.34s	remaining: 8.16s
# 347:	learn: 0.2479524	total: 4.35s	remaining: 8.15s
# 348:	learn: 0.2475936	total: 4.36s	remaining: 8.14s
# 349:	learn: 0.2471624	total: 4.37s	remaining: 8.12s
# 350:	learn: 0.2464694	total: 4.39s	remaining: 8.12s
# 351:	learn: 0.2462836	total: 4.4s	remaining: 8.1s
# 352:	learn: 0.2457004	total: 4.41s	remaining: 8.08s
# 353:	learn: 0.2453087	total: 4.42s	remaining: 8.07s
# 354:	learn: 0.2446089	total: 4.43s	remaining: 8.05s
# 355:	learn: 0.2437264	total: 4.44s	remaining: 8.04s
# 356:	learn: 0.2433877	total: 4.46s	remaining: 8.02s
# 357:	learn: 0.2429616	total: 4.47s	remaining: 8.01s
# 358:	learn: 0.2419805	total: 4.48s	remaining: 8s
# 359:	learn: 0.2414363	total: 4.49s	remaining: 7.98s
# 360:	learn: 0.2411659	total: 4.5s	remaining: 7.97s
# 361:	learn: 0.2407325	total: 4.51s	remaining: 7.96s
# 362:	learn: 0.2404036	total: 4.53s	remaining: 7.94s
# 363:	learn: 0.2398981	total: 4.54s	remaining: 7.93s
# 364:	learn: 0.2396357	total: 4.55s	remaining: 7.92s
# 365:	learn: 0.2388497	total: 4.57s	remaining: 7.91s
# 366:	learn: 0.2385163	total: 4.58s	remaining: 7.89s
# 367:	learn: 0.2381762	total: 4.6s	remaining: 7.89s
# 368:	learn: 0.2376318	total: 4.61s	remaining: 7.88s
# 369:	learn: 0.2374518	total: 4.62s	remaining: 7.87s
# 370:	learn: 0.2372817	total: 4.63s	remaining: 7.86s
# 371:	learn: 0.2367407	total: 4.65s	remaining: 7.85s
# 372:	learn: 0.2363800	total: 4.66s	remaining: 7.84s
# 373:	learn: 0.2359689	total: 4.68s	remaining: 7.83s
# 374:	learn: 0.2356268	total: 4.69s	remaining: 7.82s
# 375:	learn: 0.2350156	total: 4.7s	remaining: 7.8s
# 376:	learn: 0.2346333	total: 4.71s	remaining: 7.79s
# 377:	learn: 0.2343852	total: 4.73s	remaining: 7.78s
# 378:	learn: 0.2340199	total: 4.74s	remaining: 7.77s
# 379:	learn: 0.2337657	total: 4.75s	remaining: 7.75s
# 380:	learn: 0.2332901	total: 4.77s	remaining: 7.75s
# 381:	learn: 0.2327545	total: 4.78s	remaining: 7.74s
# 382:	learn: 0.2323613	total: 4.8s	remaining: 7.73s
# 383:	learn: 0.2318244	total: 4.81s	remaining: 7.72s
# 384:	learn: 0.2313644	total: 4.83s	remaining: 7.71s
# 385:	learn: 0.2310079	total: 4.84s	remaining: 7.7s
# 386:	learn: 0.2307282	total: 4.85s	remaining: 7.68s
# 387:	learn: 0.2304029	total: 4.86s	remaining: 7.67s
# 388:	learn: 0.2300602	total: 4.87s	remaining: 7.65s
# 389:	learn: 0.2297249	total: 4.89s	remaining: 7.65s
# 390:	learn: 0.2296156	total: 4.9s	remaining: 7.63s
# 391:	learn: 0.2292832	total: 4.91s	remaining: 7.62s
# 392:	learn: 0.2287975	total: 4.92s	remaining: 7.6s
# 393:	learn: 0.2283522	total: 4.94s	remaining: 7.6s
# 394:	learn: 0.2279552	total: 4.95s	remaining: 7.58s
# 395:	learn: 0.2277118	total: 4.97s	remaining: 7.58s
# 396:	learn: 0.2272823	total: 4.98s	remaining: 7.57s
# 397:	learn: 0.2268808	total: 5s	remaining: 7.55s
# 398:	learn: 0.2264773	total: 5.01s	remaining: 7.55s
# 399:	learn: 0.2257644	total: 5.03s	remaining: 7.55s
# 400:	learn: 0.2255397	total: 5.04s	remaining: 7.54s
# 401:	learn: 0.2253062	total: 5.06s	remaining: 7.52s
# 402:	learn: 0.2248422	total: 5.07s	remaining: 7.51s
# 403:	learn: 0.2242058	total: 5.08s	remaining: 7.5s
# 404:	learn: 0.2239321	total: 5.09s	remaining: 7.48s
# 405:	learn: 0.2235947	total: 5.11s	remaining: 7.47s
# 406:	learn: 0.2233625	total: 5.12s	remaining: 7.46s
# 407:	learn: 0.2231519	total: 5.13s	remaining: 7.44s
# 408:	learn: 0.2229715	total: 5.14s	remaining: 7.42s
# 409:	learn: 0.2226424	total: 5.16s	remaining: 7.42s
# 410:	learn: 0.2225665	total: 5.17s	remaining: 7.41s
# 411:	learn: 0.2223224	total: 5.18s	remaining: 7.39s
# 412:	learn: 0.2219434	total: 5.2s	remaining: 7.39s
# 413:	learn: 0.2215756	total: 5.22s	remaining: 7.38s
# 414:	learn: 0.2211825	total: 5.23s	remaining: 7.37s
# 415:	learn: 0.2207479	total: 5.24s	remaining: 7.36s
# 416:	learn: 0.2206020	total: 5.25s	remaining: 7.34s
# 417:	learn: 0.2204094	total: 5.26s	remaining: 7.33s
# 418:	learn: 0.2202034	total: 5.28s	remaining: 7.32s
# 419:	learn: 0.2200193	total: 5.29s	remaining: 7.3s
# 420:	learn: 0.2197769	total: 5.3s	remaining: 7.29s
# 421:	learn: 0.2194707	total: 5.31s	remaining: 7.27s
# 422:	learn: 0.2192025	total: 5.33s	remaining: 7.27s
# 423:	learn: 0.2185509	total: 5.34s	remaining: 7.26s
# 424:	learn: 0.2182247	total: 5.35s	remaining: 7.24s
# 425:	learn: 0.2176108	total: 5.37s	remaining: 7.23s
# 426:	learn: 0.2169719	total: 5.38s	remaining: 7.22s
# 427:	learn: 0.2166356	total: 5.39s	remaining: 7.21s
# 428:	learn: 0.2164749	total: 5.41s	remaining: 7.2s
# 429:	learn: 0.2162064	total: 5.42s	remaining: 7.19s
# 430:	learn: 0.2158626	total: 5.43s	remaining: 7.17s
# 431:	learn: 0.2152332	total: 5.45s	remaining: 7.16s
# 432:	learn: 0.2146978	total: 5.46s	remaining: 7.15s
# 433:	learn: 0.2142864	total: 5.47s	remaining: 7.14s
# 434:	learn: 0.2137899	total: 5.49s	remaining: 7.13s
# 435:	learn: 0.2133203	total: 5.5s	remaining: 7.11s
# 436:	learn: 0.2129260	total: 5.51s	remaining: 7.1s
# 437:	learn: 0.2124998	total: 5.52s	remaining: 7.09s
# 438:	learn: 0.2122010	total: 5.53s	remaining: 7.07s
# 439:	learn: 0.2118531	total: 5.55s	remaining: 7.06s
# 440:	learn: 0.2115370	total: 5.56s	remaining: 7.04s
# 441:	learn: 0.2111469	total: 5.57s	remaining: 7.03s
# 442:	learn: 0.2110455	total: 5.58s	remaining: 7.02s
# 443:	learn: 0.2107933	total: 5.59s	remaining: 7s
# 444:	learn: 0.2107403	total: 5.6s	remaining: 6.99s
# 445:	learn: 0.2106476	total: 5.62s	remaining: 6.98s
# 446:	learn: 0.2101370	total: 5.63s	remaining: 6.97s
# 447:	learn: 0.2097608	total: 5.65s	remaining: 6.96s
# 448:	learn: 0.2096093	total: 5.66s	remaining: 6.94s
# 449:	learn: 0.2091079	total: 5.67s	remaining: 6.93s
# 450:	learn: 0.2089994	total: 5.68s	remaining: 6.92s
# 451:	learn: 0.2087752	total: 5.69s	remaining: 6.9s
# 452:	learn: 0.2082094	total: 5.71s	remaining: 6.89s
# 453:	learn: 0.2076298	total: 5.72s	remaining: 6.88s
# 454:	learn: 0.2075342	total: 5.73s	remaining: 6.86s
# 455:	learn: 0.2071696	total: 5.74s	remaining: 6.85s
# 456:	learn: 0.2067862	total: 5.75s	remaining: 6.84s
# 457:	learn: 0.2065040	total: 5.77s	remaining: 6.82s
# 458:	learn: 0.2061606	total: 5.78s	remaining: 6.81s
# 459:	learn: 0.2058172	total: 5.79s	remaining: 6.8s
# 460:	learn: 0.2056917	total: 5.81s	remaining: 6.79s
# 461:	learn: 0.2052100	total: 5.83s	remaining: 6.79s
# 462:	learn: 0.2050808	total: 5.84s	remaining: 6.77s
# 463:	learn: 0.2048682	total: 5.85s	remaining: 6.76s
# 464:	learn: 0.2044711	total: 5.87s	remaining: 6.76s
# 465:	learn: 0.2041690	total: 5.89s	remaining: 6.75s
# 466:	learn: 0.2039258	total: 5.9s	remaining: 6.74s
# 467:	learn: 0.2035082	total: 5.91s	remaining: 6.72s
# 468:	learn: 0.2030346	total: 5.92s	remaining: 6.71s
# 469:	learn: 0.2026167	total: 5.94s	remaining: 6.69s
# 470:	learn: 0.2022924	total: 5.95s	remaining: 6.68s
# 471:	learn: 0.2020001	total: 5.96s	remaining: 6.67s
# 472:	learn: 0.2017107	total: 5.97s	remaining: 6.66s
# 473:	learn: 0.2011164	total: 5.99s	remaining: 6.64s
# 474:	learn: 0.2008615	total: 6s	remaining: 6.63s
# 475:	learn: 0.2006868	total: 6.01s	remaining: 6.62s
# 476:	learn: 0.2002804	total: 6.02s	remaining: 6.6s
# 477:	learn: 0.1998880	total: 6.04s	remaining: 6.59s
# 478:	learn: 0.1997105	total: 6.05s	remaining: 6.58s
# 479:	learn: 0.1996232	total: 6.07s	remaining: 6.57s
# 480:	learn: 0.1991823	total: 6.08s	remaining: 6.56s
# 481:	learn: 0.1988829	total: 6.09s	remaining: 6.55s
# 482:	learn: 0.1985810	total: 6.1s	remaining: 6.53s
# 483:	learn: 0.1984300	total: 6.11s	remaining: 6.52s
# 484:	learn: 0.1981078	total: 6.13s	remaining: 6.5s
# 485:	learn: 0.1976863	total: 6.14s	remaining: 6.5s
# 486:	learn: 0.1975319	total: 6.17s	remaining: 6.5s
# 487:	learn: 0.1972481	total: 6.19s	remaining: 6.5s
# 488:	learn: 0.1969338	total: 6.21s	remaining: 6.49s
# 489:	learn: 0.1965545	total: 6.22s	remaining: 6.48s
# 490:	learn: 0.1963987	total: 6.24s	remaining: 6.47s
# 491:	learn: 0.1963075	total: 6.25s	remaining: 6.46s
# 492:	learn: 0.1958612	total: 6.26s	remaining: 6.44s
# 493:	learn: 0.1955922	total: 6.28s	remaining: 6.43s
# 494:	learn: 0.1952558	total: 6.29s	remaining: 6.42s
# 495:	learn: 0.1947891	total: 6.31s	remaining: 6.41s
# 496:	learn: 0.1944880	total: 6.33s	remaining: 6.4s
# 497:	learn: 0.1940209	total: 6.34s	remaining: 6.39s
# 498:	learn: 0.1937237	total: 6.35s	remaining: 6.38s
# 499:	learn: 0.1934123	total: 6.36s	remaining: 6.36s
# 500:	learn: 0.1931624	total: 6.38s	remaining: 6.35s
# 501:	learn: 0.1930858	total: 6.39s	remaining: 6.34s
# 502:	learn: 0.1927469	total: 6.4s	remaining: 6.33s
# 503:	learn: 0.1922908	total: 6.42s	remaining: 6.31s
# 504:	learn: 0.1919561	total: 6.43s	remaining: 6.3s
# 505:	learn: 0.1918376	total: 6.44s	remaining: 6.29s
# 506:	learn: 0.1916016	total: 6.46s	remaining: 6.28s
# 507:	learn: 0.1912478	total: 6.47s	remaining: 6.26s
# 508:	learn: 0.1910829	total: 6.48s	remaining: 6.25s
# 509:	learn: 0.1907855	total: 6.49s	remaining: 6.23s
# 510:	learn: 0.1905014	total: 6.5s	remaining: 6.22s
# 511:	learn: 0.1901559	total: 6.52s	remaining: 6.21s
# 512:	learn: 0.1900701	total: 6.53s	remaining: 6.2s
# 513:	learn: 0.1896210	total: 6.54s	remaining: 6.18s
# 514:	learn: 0.1891245	total: 6.55s	remaining: 6.17s
# 515:	learn: 0.1890486	total: 6.57s	remaining: 6.16s
# 516:	learn: 0.1886403	total: 6.58s	remaining: 6.14s
# 517:	learn: 0.1883334	total: 6.59s	remaining: 6.13s
# 518:	learn: 0.1880896	total: 6.6s	remaining: 6.12s
# 519:	learn: 0.1876516	total: 6.62s	remaining: 6.11s
# 520:	learn: 0.1874084	total: 6.64s	remaining: 6.1s
# 521:	learn: 0.1870297	total: 6.65s	remaining: 6.09s
# 522:	learn: 0.1868313	total: 6.66s	remaining: 6.08s
# 523:	learn: 0.1864524	total: 6.68s	remaining: 6.07s
# 524:	learn: 0.1861488	total: 6.69s	remaining: 6.05s
# 525:	learn: 0.1858264	total: 6.7s	remaining: 6.04s
# 526:	learn: 0.1854531	total: 6.72s	remaining: 6.03s
# 527:	learn: 0.1850027	total: 6.73s	remaining: 6.02s
# 528:	learn: 0.1847140	total: 6.74s	remaining: 6s
# 529:	learn: 0.1844811	total: 6.75s	remaining: 5.99s
# 530:	learn: 0.1842184	total: 6.77s	remaining: 5.98s
# 531:	learn: 0.1841010	total: 6.78s	remaining: 5.96s
# 532:	learn: 0.1837895	total: 6.79s	remaining: 5.95s
# 533:	learn: 0.1836183	total: 6.8s	remaining: 5.94s
# 534:	learn: 0.1832950	total: 6.82s	remaining: 5.92s
# 535:	learn: 0.1829696	total: 6.84s	remaining: 5.92s
# 536:	learn: 0.1826388	total: 6.85s	remaining: 5.91s
# 537:	learn: 0.1824148	total: 6.87s	remaining: 5.9s
# 538:	learn: 0.1821718	total: 6.88s	remaining: 5.88s
# 539:	learn: 0.1819601	total: 6.89s	remaining: 5.87s
# 540:	learn: 0.1817085	total: 6.9s	remaining: 5.86s
# 541:	learn: 0.1813881	total: 6.92s	remaining: 5.84s
# 542:	learn: 0.1810080	total: 6.93s	remaining: 5.83s
# 543:	learn: 0.1807612	total: 6.94s	remaining: 5.82s
# 544:	learn: 0.1804422	total: 6.95s	remaining: 5.8s
# 545:	learn: 0.1800899	total: 6.97s	remaining: 5.79s
# 546:	learn: 0.1795990	total: 6.98s	remaining: 5.78s
# 547:	learn: 0.1795343	total: 6.99s	remaining: 5.76s
# 548:	learn: 0.1792047	total: 7s	remaining: 5.75s
# 549:	learn: 0.1788175	total: 7.01s	remaining: 5.74s
# 550:	learn: 0.1785950	total: 7.03s	remaining: 5.72s
# 551:	learn: 0.1784083	total: 7.04s	remaining: 5.72s
# 552:	learn: 0.1782171	total: 7.05s	remaining: 5.7s
# 553:	learn: 0.1780854	total: 7.07s	remaining: 5.69s
# 554:	learn: 0.1776033	total: 7.08s	remaining: 5.67s
# 555:	learn: 0.1771277	total: 7.09s	remaining: 5.66s
# 556:	learn: 0.1770213	total: 7.1s	remaining: 5.65s
# 557:	learn: 0.1767881	total: 7.11s	remaining: 5.63s
# 558:	learn: 0.1764865	total: 7.13s	remaining: 5.62s
# 559:	learn: 0.1761008	total: 7.14s	remaining: 5.61s
# 560:	learn: 0.1758640	total: 7.15s	remaining: 5.59s
# 561:	learn: 0.1757012	total: 7.16s	remaining: 5.58s
# 562:	learn: 0.1754261	total: 7.17s	remaining: 5.57s
# 563:	learn: 0.1751823	total: 7.18s	remaining: 5.55s
# 564:	learn: 0.1748126	total: 7.2s	remaining: 5.54s
# 565:	learn: 0.1745015	total: 7.21s	remaining: 5.53s
# 566:	learn: 0.1742613	total: 7.22s	remaining: 5.51s
# 567:	learn: 0.1739719	total: 7.23s	remaining: 5.5s
# 568:	learn: 0.1736958	total: 7.25s	remaining: 5.49s
# 569:	learn: 0.1733670	total: 7.26s	remaining: 5.48s
# 570:	learn: 0.1732294	total: 7.28s	remaining: 5.47s
# 571:	learn: 0.1728399	total: 7.29s	remaining: 5.46s
# 572:	learn: 0.1727173	total: 7.31s	remaining: 5.45s
# 573:	learn: 0.1725757	total: 7.32s	remaining: 5.43s
# 574:	learn: 0.1721251	total: 7.33s	remaining: 5.42s
# 575:	learn: 0.1718510	total: 7.34s	remaining: 5.41s
# 576:	learn: 0.1716521	total: 7.36s	remaining: 5.39s
# 577:	learn: 0.1713481	total: 7.37s	remaining: 5.38s
# 578:	learn: 0.1710006	total: 7.38s	remaining: 5.37s
# 579:	learn: 0.1707274	total: 7.4s	remaining: 5.36s
# 580:	learn: 0.1706210	total: 7.41s	remaining: 5.34s
# 581:	learn: 0.1703959	total: 7.42s	remaining: 5.33s
# 582:	learn: 0.1702783	total: 7.43s	remaining: 5.32s
# 583:	learn: 0.1697842	total: 7.45s	remaining: 5.31s
# 584:	learn: 0.1694812	total: 7.47s	remaining: 5.3s
# 585:	learn: 0.1692751	total: 7.48s	remaining: 5.29s
# 586:	learn: 0.1689816	total: 7.5s	remaining: 5.27s
# 587:	learn: 0.1688947	total: 7.51s	remaining: 5.26s
# 588:	learn: 0.1686096	total: 7.52s	remaining: 5.25s
# 589:	learn: 0.1685250	total: 7.53s	remaining: 5.23s
# 590:	learn: 0.1683785	total: 7.54s	remaining: 5.22s
# 591:	learn: 0.1679794	total: 7.55s	remaining: 5.21s
# 592:	learn: 0.1675635	total: 7.57s	remaining: 5.19s
# 593:	learn: 0.1673510	total: 7.58s	remaining: 5.18s
# 594:	learn: 0.1671686	total: 7.59s	remaining: 5.17s
# 595:	learn: 0.1670436	total: 7.6s	remaining: 5.15s
# 596:	learn: 0.1668040	total: 7.61s	remaining: 5.14s
# 597:	learn: 0.1666944	total: 7.63s	remaining: 5.13s
# 598:	learn: 0.1662870	total: 7.64s	remaining: 5.12s
# 599:	learn: 0.1661022	total: 7.66s	remaining: 5.11s
# 600:	learn: 0.1659296	total: 7.67s	remaining: 5.09s
# 601:	learn: 0.1658630	total: 7.68s	remaining: 5.08s
# 602:	learn: 0.1656542	total: 7.7s	remaining: 5.07s
# 603:	learn: 0.1653873	total: 7.71s	remaining: 5.05s
# 604:	learn: 0.1649699	total: 7.72s	remaining: 5.04s
# 605:	learn: 0.1647134	total: 7.73s	remaining: 5.03s
# 606:	learn: 0.1644291	total: 7.75s	remaining: 5.01s
# 607:	learn: 0.1643654	total: 7.76s	remaining: 5s
# 608:	learn: 0.1641674	total: 7.77s	remaining: 4.99s
# 609:	learn: 0.1638496	total: 7.78s	remaining: 4.97s
# 610:	learn: 0.1635385	total: 7.79s	remaining: 4.96s
# 611:	learn: 0.1633275	total: 7.8s	remaining: 4.95s
# 612:	learn: 0.1632058	total: 7.82s	remaining: 4.94s
# 613:	learn: 0.1630608	total: 7.83s	remaining: 4.92s
# 614:	learn: 0.1628518	total: 7.85s	remaining: 4.91s
# 615:	learn: 0.1626729	total: 7.86s	remaining: 4.9s
# 616:	learn: 0.1624103	total: 7.88s	remaining: 4.89s
# 617:	learn: 0.1622150	total: 7.89s	remaining: 4.88s
# 618:	learn: 0.1620203	total: 7.9s	remaining: 4.86s
# 619:	learn: 0.1616017	total: 7.91s	remaining: 4.85s
# 620:	learn: 0.1613826	total: 7.92s	remaining: 4.83s
# 621:	learn: 0.1611908	total: 7.93s	remaining: 4.82s
# 622:	learn: 0.1609118	total: 7.95s	remaining: 4.81s
# 623:	learn: 0.1608249	total: 7.96s	remaining: 4.8s
# 624:	learn: 0.1606044	total: 7.97s	remaining: 4.78s
# 625:	learn: 0.1602596	total: 7.98s	remaining: 4.77s
# 626:	learn: 0.1600554	total: 8s	remaining: 4.76s
# 627:	learn: 0.1598689	total: 8.01s	remaining: 4.74s
# 628:	learn: 0.1594152	total: 8.02s	remaining: 4.73s
# 629:	learn: 0.1589339	total: 8.03s	remaining: 4.72s
# 630:	learn: 0.1587697	total: 8.04s	remaining: 4.7s
# 631:	learn: 0.1585928	total: 8.05s	remaining: 4.69s
# 632:	learn: 0.1582231	total: 8.07s	remaining: 4.68s
# 633:	learn: 0.1581019	total: 8.09s	remaining: 4.67s
# 634:	learn: 0.1578953	total: 8.1s	remaining: 4.66s
# 635:	learn: 0.1577774	total: 8.11s	remaining: 4.64s
# 636:	learn: 0.1574873	total: 8.13s	remaining: 4.63s
# 637:	learn: 0.1571230	total: 8.14s	remaining: 4.62s
# 638:	learn: 0.1569104	total: 8.15s	remaining: 4.61s
# 639:	learn: 0.1565527	total: 8.17s	remaining: 4.59s
# 640:	learn: 0.1562467	total: 8.18s	remaining: 4.58s
# 641:	learn: 0.1559112	total: 8.19s	remaining: 4.57s
# 642:	learn: 0.1557569	total: 8.2s	remaining: 4.55s
# 643:	learn: 0.1556015	total: 8.21s	remaining: 4.54s
# 644:	learn: 0.1554131	total: 8.23s	remaining: 4.53s
# 645:	learn: 0.1553477	total: 8.24s	remaining: 4.51s
# 646:	learn: 0.1551441	total: 8.26s	remaining: 4.5s
# 647:	learn: 0.1549363	total: 8.27s	remaining: 4.49s
# 648:	learn: 0.1544663	total: 8.29s	remaining: 4.49s
# 649:	learn: 0.1540087	total: 8.31s	remaining: 4.47s
# 650:	learn: 0.1539367	total: 8.32s	remaining: 4.46s
# 651:	learn: 0.1537836	total: 8.33s	remaining: 4.45s
# 652:	learn: 0.1534865	total: 8.34s	remaining: 4.43s
# 653:	learn: 0.1533498	total: 8.36s	remaining: 4.42s
# 654:	learn: 0.1530756	total: 8.37s	remaining: 4.41s
# 655:	learn: 0.1527574	total: 8.38s	remaining: 4.39s
# 656:	learn: 0.1523972	total: 8.39s	remaining: 4.38s
# 657:	learn: 0.1523143	total: 8.4s	remaining: 4.37s
# 658:	learn: 0.1520604	total: 8.42s	remaining: 4.36s
# 659:	learn: 0.1519086	total: 8.43s	remaining: 4.34s
# 660:	learn: 0.1517222	total: 8.44s	remaining: 4.33s
# 661:	learn: 0.1515619	total: 8.45s	remaining: 4.32s
# 662:	learn: 0.1512797	total: 8.46s	remaining: 4.3s
# 663:	learn: 0.1511694	total: 8.48s	remaining: 4.29s
# 664:	learn: 0.1508954	total: 8.49s	remaining: 4.28s
# 665:	learn: 0.1506190	total: 8.51s	remaining: 4.27s
# 666:	learn: 0.1504855	total: 8.52s	remaining: 4.25s
# 667:	learn: 0.1502839	total: 8.53s	remaining: 4.24s
# 668:	learn: 0.1500618	total: 8.55s	remaining: 4.23s
# 669:	learn: 0.1498489	total: 8.56s	remaining: 4.22s
# 670:	learn: 0.1496561	total: 8.57s	remaining: 4.2s
# 671:	learn: 0.1495227	total: 8.58s	remaining: 4.19s
# 672:	learn: 0.1493218	total: 8.59s	remaining: 4.17s
# 673:	learn: 0.1492677	total: 8.61s	remaining: 4.16s
# 674:	learn: 0.1490174	total: 8.62s	remaining: 4.15s
# 675:	learn: 0.1488794	total: 8.63s	remaining: 4.14s
# 676:	learn: 0.1487307	total: 8.64s	remaining: 4.12s
# 677:	learn: 0.1486546	total: 8.65s	remaining: 4.11s
# 678:	learn: 0.1484233	total: 8.66s	remaining: 4.1s
# 679:	learn: 0.1481411	total: 8.68s	remaining: 4.08s
# 680:	learn: 0.1479065	total: 8.7s	remaining: 4.07s
# 681:	learn: 0.1475407	total: 8.71s	remaining: 4.06s
# 682:	learn: 0.1473775	total: 8.72s	remaining: 4.05s
# 683:	learn: 0.1471795	total: 8.73s	remaining: 4.03s
# 684:	learn: 0.1471142	total: 8.74s	remaining: 4.02s
# 685:	learn: 0.1469125	total: 8.75s	remaining: 4s
# 686:	learn: 0.1466204	total: 8.76s	remaining: 3.99s
# 687:	learn: 0.1463644	total: 8.77s	remaining: 3.98s
# 688:	learn: 0.1460743	total: 8.78s	remaining: 3.96s
# 689:	learn: 0.1459878	total: 8.79s	remaining: 3.95s
# 690:	learn: 0.1458412	total: 8.81s	remaining: 3.94s
# 691:	learn: 0.1456707	total: 8.82s	remaining: 3.92s
# 692:	learn: 0.1455187	total: 8.83s	remaining: 3.91s
# 693:	learn: 0.1454385	total: 8.84s	remaining: 3.9s
# 694:	learn: 0.1450672	total: 8.85s	remaining: 3.88s
# 695:	learn: 0.1449381	total: 8.86s	remaining: 3.87s
# 696:	learn: 0.1446962	total: 8.87s	remaining: 3.86s
# 697:	learn: 0.1444023	total: 8.88s	remaining: 3.84s
# 698:	learn: 0.1443138	total: 8.9s	remaining: 3.83s
# 699:	learn: 0.1441068	total: 8.91s	remaining: 3.82s
# 700:	learn: 0.1438054	total: 8.92s	remaining: 3.8s
# 701:	learn: 0.1433685	total: 8.93s	remaining: 3.79s
# 702:	learn: 0.1431526	total: 8.94s	remaining: 3.78s
# 703:	learn: 0.1429996	total: 8.95s	remaining: 3.76s
# 704:	learn: 0.1428510	total: 8.96s	remaining: 3.75s
# 705:	learn: 0.1424417	total: 8.98s	remaining: 3.74s
# 706:	learn: 0.1422485	total: 8.99s	remaining: 3.72s
# 707:	learn: 0.1421636	total: 9s	remaining: 3.71s
# 708:	learn: 0.1419065	total: 9.01s	remaining: 3.7s
# 709:	learn: 0.1417669	total: 9.02s	remaining: 3.68s
# 710:	learn: 0.1414760	total: 9.03s	remaining: 3.67s
# 711:	learn: 0.1413092	total: 9.04s	remaining: 3.66s
# 712:	learn: 0.1411277	total: 9.05s	remaining: 3.64s
# 713:	learn: 0.1408822	total: 9.06s	remaining: 3.63s
# 714:	learn: 0.1408354	total: 9.07s	remaining: 3.62s
# 715:	learn: 0.1406035	total: 9.09s	remaining: 3.6s
# 716:	learn: 0.1403703	total: 9.1s	remaining: 3.59s
# 717:	learn: 0.1401572	total: 9.11s	remaining: 3.58s
# 718:	learn: 0.1400468	total: 9.12s	remaining: 3.57s
# 719:	learn: 0.1398775	total: 9.13s	remaining: 3.55s
# 720:	learn: 0.1397849	total: 9.14s	remaining: 3.54s
# 721:	learn: 0.1396568	total: 9.15s	remaining: 3.52s
# 722:	learn: 0.1394998	total: 9.17s	remaining: 3.51s
# 723:	learn: 0.1391740	total: 9.18s	remaining: 3.5s
# 724:	learn: 0.1390530	total: 9.19s	remaining: 3.49s
# 725:	learn: 0.1388417	total: 9.2s	remaining: 3.47s
# 726:	learn: 0.1387016	total: 9.21s	remaining: 3.46s
# 727:	learn: 0.1385611	total: 9.22s	remaining: 3.45s
# 728:	learn: 0.1385001	total: 9.23s	remaining: 3.43s
# 729:	learn: 0.1383257	total: 9.24s	remaining: 3.42s
# 730:	learn: 0.1381322	total: 9.26s	remaining: 3.41s
# 731:	learn: 0.1379484	total: 9.27s	remaining: 3.39s
# 732:	learn: 0.1378052	total: 9.28s	remaining: 3.38s
# 733:	learn: 0.1375929	total: 9.3s	remaining: 3.37s
# 734:	learn: 0.1373129	total: 9.31s	remaining: 3.36s
# 735:	learn: 0.1371217	total: 9.32s	remaining: 3.34s
# 736:	learn: 0.1367859	total: 9.34s	remaining: 3.33s
# 737:	learn: 0.1365656	total: 9.35s	remaining: 3.32s
# 738:	learn: 0.1363338	total: 9.36s	remaining: 3.3s
# 739:	learn: 0.1361483	total: 9.37s	remaining: 3.29s
# 740:	learn: 0.1360708	total: 9.38s	remaining: 3.28s
# 741:	learn: 0.1358322	total: 9.39s	remaining: 3.26s
# 742:	learn: 0.1357332	total: 9.4s	remaining: 3.25s
# 743:	learn: 0.1356846	total: 9.41s	remaining: 3.24s
# 744:	learn: 0.1355940	total: 9.42s	remaining: 3.22s
# 745:	learn: 0.1354633	total: 9.43s	remaining: 3.21s
# 746:	learn: 0.1351691	total: 9.44s	remaining: 3.2s
# 747:	learn: 0.1350956	total: 9.45s	remaining: 3.18s
# 748:	learn: 0.1349067	total: 9.46s	remaining: 3.17s
# 749:	learn: 0.1347285	total: 9.47s	remaining: 3.16s
# 750:	learn: 0.1343680	total: 9.48s	remaining: 3.14s
# 751:	learn: 0.1341954	total: 9.49s	remaining: 3.13s
# 752:	learn: 0.1339040	total: 9.51s	remaining: 3.12s
# 753:	learn: 0.1337456	total: 9.52s	remaining: 3.11s
# 754:	learn: 0.1336435	total: 9.53s	remaining: 3.09s
# 755:	learn: 0.1335689	total: 9.54s	remaining: 3.08s
# 756:	learn: 0.1334084	total: 9.56s	remaining: 3.07s
# 757:	learn: 0.1332244	total: 9.57s	remaining: 3.06s
# 758:	learn: 0.1331869	total: 9.59s	remaining: 3.04s
# 759:	learn: 0.1330548	total: 9.6s	remaining: 3.03s
# 760:	learn: 0.1329127	total: 9.61s	remaining: 3.02s
# 761:	learn: 0.1326415	total: 9.62s	remaining: 3s
# 762:	learn: 0.1324873	total: 9.63s	remaining: 2.99s
# 763:	learn: 0.1321830	total: 9.64s	remaining: 2.98s
# 764:	learn: 0.1320600	total: 9.66s	remaining: 2.97s
# 765:	learn: 0.1319099	total: 9.67s	remaining: 2.95s
# 766:	learn: 0.1317008	total: 9.68s	remaining: 2.94s
# 767:	learn: 0.1314955	total: 9.69s	remaining: 2.93s
# 768:	learn: 0.1313069	total: 9.71s	remaining: 2.92s
# 769:	learn: 0.1311579	total: 9.72s	remaining: 2.9s
# 770:	learn: 0.1309156	total: 9.74s	remaining: 2.89s
# 771:	learn: 0.1308306	total: 9.75s	remaining: 2.88s
# 772:	learn: 0.1306153	total: 9.76s	remaining: 2.87s
# 773:	learn: 0.1305370	total: 9.77s	remaining: 2.85s
# 774:	learn: 0.1304148	total: 9.79s	remaining: 2.84s
# 775:	learn: 0.1302995	total: 9.8s	remaining: 2.83s
# 776:	learn: 0.1301325	total: 9.81s	remaining: 2.81s
# 777:	learn: 0.1297955	total: 9.82s	remaining: 2.8s
# 778:	learn: 0.1296309	total: 9.83s	remaining: 2.79s
# 779:	learn: 0.1294531	total: 9.84s	remaining: 2.78s
# 780:	learn: 0.1292824	total: 9.86s	remaining: 2.76s
# 781:	learn: 0.1291991	total: 9.88s	remaining: 2.75s
# 782:	learn: 0.1291167	total: 9.89s	remaining: 2.74s
# 783:	learn: 0.1289279	total: 9.9s	remaining: 2.73s
# 784:	learn: 0.1288643	total: 9.91s	remaining: 2.71s
# 785:	learn: 0.1286375	total: 9.93s	remaining: 2.7s
# 786:	learn: 0.1283692	total: 9.95s	remaining: 2.69s
# 787:	learn: 0.1282946	total: 9.96s	remaining: 2.68s
# 788:	learn: 0.1279265	total: 9.98s	remaining: 2.67s
# 789:	learn: 0.1277300	total: 9.99s	remaining: 2.65s
# 790:	learn: 0.1276115	total: 10s	remaining: 2.64s
# 791:	learn: 0.1274032	total: 10s	remaining: 2.63s
# 792:	learn: 0.1272635	total: 10s	remaining: 2.62s
# 793:	learn: 0.1271705	total: 10s	remaining: 2.6s
# 794:	learn: 0.1270282	total: 10s	remaining: 2.59s
# 795:	learn: 0.1268679	total: 10.1s	remaining: 2.58s
# 796:	learn: 0.1267728	total: 10.1s	remaining: 2.56s
# 797:	learn: 0.1265299	total: 10.1s	remaining: 2.55s
# 798:	learn: 0.1263768	total: 10.1s	remaining: 2.54s
# 799:	learn: 0.1260955	total: 10.1s	remaining: 2.53s
# 800:	learn: 0.1257603	total: 10.1s	remaining: 2.51s
# 801:	learn: 0.1256887	total: 10.1s	remaining: 2.5s
# 802:	learn: 0.1254679	total: 10.1s	remaining: 2.49s
# 803:	learn: 0.1253318	total: 10.2s	remaining: 2.48s
# 804:	learn: 0.1251492	total: 10.2s	remaining: 2.46s
# 805:	learn: 0.1250026	total: 10.2s	remaining: 2.45s
# 806:	learn: 0.1249055	total: 10.2s	remaining: 2.44s
# 807:	learn: 0.1247318	total: 10.2s	remaining: 2.42s
# 808:	learn: 0.1245471	total: 10.2s	remaining: 2.41s
# 809:	learn: 0.1244215	total: 10.2s	remaining: 2.4s
# 810:	learn: 0.1242547	total: 10.2s	remaining: 2.39s
# 811:	learn: 0.1239855	total: 10.3s	remaining: 2.37s
# 812:	learn: 0.1238258	total: 10.3s	remaining: 2.36s
# 813:	learn: 0.1237524	total: 10.3s	remaining: 2.35s
# 814:	learn: 0.1234803	total: 10.3s	remaining: 2.34s
# 815:	learn: 0.1233013	total: 10.3s	remaining: 2.33s
# 816:	learn: 0.1231380	total: 10.3s	remaining: 2.31s
# 817:	learn: 0.1230253	total: 10.3s	remaining: 2.3s
# 818:	learn: 0.1228679	total: 10.4s	remaining: 2.29s
# 819:	learn: 0.1226687	total: 10.4s	remaining: 2.28s
# 820:	learn: 0.1225534	total: 10.4s	remaining: 2.26s
# 821:	learn: 0.1224579	total: 10.4s	remaining: 2.25s
# 822:	learn: 0.1223520	total: 10.4s	remaining: 2.24s
# 823:	learn: 0.1222212	total: 10.4s	remaining: 2.23s
# 824:	learn: 0.1221006	total: 10.4s	remaining: 2.21s
# 825:	learn: 0.1220019	total: 10.4s	remaining: 2.2s
# 826:	learn: 0.1218935	total: 10.5s	remaining: 2.19s
# 827:	learn: 0.1217886	total: 10.5s	remaining: 2.17s
# 828:	learn: 0.1216270	total: 10.5s	remaining: 2.16s
# 829:	learn: 0.1214148	total: 10.5s	remaining: 2.15s
# 830:	learn: 0.1212727	total: 10.5s	remaining: 2.14s
# 831:	learn: 0.1211335	total: 10.5s	remaining: 2.12s
# 832:	learn: 0.1209024	total: 10.5s	remaining: 2.11s
# 833:	learn: 0.1206751	total: 10.5s	remaining: 2.1s
# 834:	learn: 0.1205998	total: 10.6s	remaining: 2.08s
# 835:	learn: 0.1204092	total: 10.6s	remaining: 2.07s
# 836:	learn: 0.1200969	total: 10.6s	remaining: 2.06s
# 837:	learn: 0.1199991	total: 10.6s	remaining: 2.05s
# 838:	learn: 0.1198594	total: 10.6s	remaining: 2.04s
# 839:	learn: 0.1196236	total: 10.6s	remaining: 2.02s
# 840:	learn: 0.1195172	total: 10.6s	remaining: 2.01s
# 841:	learn: 0.1194743	total: 10.6s	remaining: 2s
# 842:	learn: 0.1193129	total: 10.7s	remaining: 1.98s
# 843:	learn: 0.1191233	total: 10.7s	remaining: 1.97s
# 844:	learn: 0.1190157	total: 10.7s	remaining: 1.96s
# 845:	learn: 0.1188841	total: 10.7s	remaining: 1.95s
# 846:	learn: 0.1186984	total: 10.7s	remaining: 1.93s
# 847:	learn: 0.1185497	total: 10.7s	remaining: 1.92s
# 848:	learn: 0.1183522	total: 10.7s	remaining: 1.91s
# 849:	learn: 0.1181221	total: 10.7s	remaining: 1.9s
# 850:	learn: 0.1180456	total: 10.8s	remaining: 1.88s
# 851:	learn: 0.1178968	total: 10.8s	remaining: 1.87s
# 852:	learn: 0.1178273	total: 10.8s	remaining: 1.86s
# 853:	learn: 0.1176832	total: 10.8s	remaining: 1.84s
# 854:	learn: 0.1175589	total: 10.8s	remaining: 1.83s
# 855:	learn: 0.1173768	total: 10.8s	remaining: 1.82s
# 856:	learn: 0.1171282	total: 10.8s	remaining: 1.81s
# 857:	learn: 0.1170170	total: 10.8s	remaining: 1.79s
# 858:	learn: 0.1169454	total: 10.9s	remaining: 1.78s
# 859:	learn: 0.1166336	total: 10.9s	remaining: 1.77s
# 860:	learn: 0.1164687	total: 10.9s	remaining: 1.76s
# 861:	learn: 0.1163062	total: 10.9s	remaining: 1.74s
# 862:	learn: 0.1161408	total: 10.9s	remaining: 1.73s
# 863:	learn: 0.1160084	total: 10.9s	remaining: 1.72s
# 864:	learn: 0.1158462	total: 10.9s	remaining: 1.71s
# 865:	learn: 0.1156113	total: 11s	remaining: 1.69s
# 866:	learn: 0.1155419	total: 11s	remaining: 1.68s
# 867:	learn: 0.1154424	total: 11s	remaining: 1.67s
# 868:	learn: 0.1153263	total: 11s	remaining: 1.66s
# 869:	learn: 0.1151766	total: 11s	remaining: 1.64s
# 870:	learn: 0.1151453	total: 11s	remaining: 1.63s
# 871:	learn: 0.1148941	total: 11s	remaining: 1.62s
# 872:	learn: 0.1146147	total: 11s	remaining: 1.61s
# 873:	learn: 0.1144063	total: 11.1s	remaining: 1.59s
# 874:	learn: 0.1142564	total: 11.1s	remaining: 1.58s
# 875:	learn: 0.1141288	total: 11.1s	remaining: 1.57s
# 876:	learn: 0.1140021	total: 11.1s	remaining: 1.56s
# 877:	learn: 0.1138319	total: 11.1s	remaining: 1.54s
# 878:	learn: 0.1136130	total: 11.1s	remaining: 1.53s
# 879:	learn: 0.1135235	total: 11.1s	remaining: 1.52s
# 880:	learn: 0.1133911	total: 11.1s	remaining: 1.5s
# 881:	learn: 0.1131790	total: 11.2s	remaining: 1.49s
# 882:	learn: 0.1130730	total: 11.2s	remaining: 1.48s
# 883:	learn: 0.1129885	total: 11.2s	remaining: 1.47s
# 884:	learn: 0.1128566	total: 11.2s	remaining: 1.45s
# 885:	learn: 0.1126879	total: 11.2s	remaining: 1.44s
# 886:	learn: 0.1125167	total: 11.2s	remaining: 1.43s
# 887:	learn: 0.1122478	total: 11.2s	remaining: 1.42s
# 888:	learn: 0.1121102	total: 11.2s	remaining: 1.4s
# 889:	learn: 0.1120219	total: 11.3s	remaining: 1.39s
# 890:	learn: 0.1118625	total: 11.3s	remaining: 1.38s
# 891:	learn: 0.1117673	total: 11.3s	remaining: 1.37s
# 892:	learn: 0.1115684	total: 11.3s	remaining: 1.35s
# 893:	learn: 0.1114005	total: 11.3s	remaining: 1.34s
# 894:	learn: 0.1112763	total: 11.3s	remaining: 1.33s
# 895:	learn: 0.1111615	total: 11.3s	remaining: 1.31s
# 896:	learn: 0.1109633	total: 11.3s	remaining: 1.3s
# 897:	learn: 0.1107461	total: 11.4s	remaining: 1.29s
# 898:	learn: 0.1106111	total: 11.4s	remaining: 1.28s
# 899:	learn: 0.1105476	total: 11.4s	remaining: 1.26s
# 900:	learn: 0.1103393	total: 11.4s	remaining: 1.25s
# 901:	learn: 0.1102552	total: 11.4s	remaining: 1.24s
# 902:	learn: 0.1101064	total: 11.4s	remaining: 1.23s
# 903:	learn: 0.1098927	total: 11.4s	remaining: 1.21s
# 904:	learn: 0.1098051	total: 11.4s	remaining: 1.2s
# 905:	learn: 0.1097131	total: 11.5s	remaining: 1.19s
# 906:	learn: 0.1096192	total: 11.5s	remaining: 1.18s
# 907:	learn: 0.1095500	total: 11.5s	remaining: 1.16s
# 908:	learn: 0.1094176	total: 11.5s	remaining: 1.15s
# 909:	learn: 0.1093107	total: 11.5s	remaining: 1.14s
# 910:	learn: 0.1092108	total: 11.5s	remaining: 1.13s
# 911:	learn: 0.1090991	total: 11.5s	remaining: 1.11s
# 912:	learn: 0.1089483	total: 11.5s	remaining: 1.1s
# 913:	learn: 0.1088840	total: 11.5s	remaining: 1.09s
# 914:	learn: 0.1087016	total: 11.6s	remaining: 1.07s
# 915:	learn: 0.1085302	total: 11.6s	remaining: 1.06s
# 916:	learn: 0.1084634	total: 11.6s	remaining: 1.05s
# 917:	learn: 0.1083579	total: 11.6s	remaining: 1.04s
# 918:	learn: 0.1083149	total: 11.6s	remaining: 1.02s
# 919:	learn: 0.1081899	total: 11.6s	remaining: 1.01s
# 920:	learn: 0.1080526	total: 11.6s	remaining: 998ms
# 921:	learn: 0.1079342	total: 11.6s	remaining: 985ms
# 922:	learn: 0.1079033	total: 11.7s	remaining: 973ms
# 923:	learn: 0.1077954	total: 11.7s	remaining: 960ms
# 924:	learn: 0.1076691	total: 11.7s	remaining: 947ms
# 925:	learn: 0.1075767	total: 11.7s	remaining: 935ms
# 926:	learn: 0.1074027	total: 11.7s	remaining: 922ms
# 927:	learn: 0.1073211	total: 11.7s	remaining: 909ms
# 928:	learn: 0.1072366	total: 11.7s	remaining: 897ms
# 929:	learn: 0.1071190	total: 11.8s	remaining: 884ms
# 930:	learn: 0.1069540	total: 11.8s	remaining: 872ms
# 931:	learn: 0.1068622	total: 11.8s	remaining: 859ms
# 932:	learn: 0.1066313	total: 11.8s	remaining: 847ms
# 933:	learn: 0.1064335	total: 11.8s	remaining: 834ms
# 934:	learn: 0.1061955	total: 11.8s	remaining: 822ms
# 935:	learn: 0.1060987	total: 11.8s	remaining: 809ms
# 936:	learn: 0.1059299	total: 11.8s	remaining: 796ms
# 937:	learn: 0.1058663	total: 11.9s	remaining: 784ms
# 938:	learn: 0.1056800	total: 11.9s	remaining: 771ms
# 939:	learn: 0.1056532	total: 11.9s	remaining: 758ms
# 940:	learn: 0.1055417	total: 11.9s	remaining: 745ms
# 941:	learn: 0.1053533	total: 11.9s	remaining: 733ms
# 942:	learn: 0.1052430	total: 11.9s	remaining: 720ms
# 943:	learn: 0.1051237	total: 11.9s	remaining: 707ms
# 944:	learn: 0.1049514	total: 11.9s	remaining: 695ms
# 945:	learn: 0.1047966	total: 11.9s	remaining: 682ms
# 946:	learn: 0.1046778	total: 12s	remaining: 669ms
# 947:	learn: 0.1045955	total: 12s	remaining: 657ms
# 948:	learn: 0.1045201	total: 12s	remaining: 644ms
# 949:	learn: 0.1043441	total: 12s	remaining: 632ms
# 950:	learn: 0.1041843	total: 12s	remaining: 619ms
# 951:	learn: 0.1040177	total: 12s	remaining: 606ms
# ...
# 696:	learn: 0.1330569	total: 9.28s	remaining: 4.03s
# 697:	learn: 0.1328262	total: 9.29s	remaining: 4.02s
# 698:	learn: 0.1325465	total: 9.31s	remaining: 4.01s
# 699:	learn: 0.1322599	total: 9.32s	remaining: 4s
# 700:	learn: 0.1321806	total: 9.34s	remaining: 3.98s
# 701:	learn: 0.1320765	total: 9.35s	remaining: 3.97s
# 702:	learn: 0.1319367	total: 9.36s	remaining: 3.95s
# 703:	learn: 0.1317967	total: 9.38s	remaining: 3.94s
# 704:	learn: 0.1315817	total: 9.39s	remaining: 3.93s
# 705:	learn: 0.1314255	total: 9.4s	remaining: 3.92s
# 706:	learn: 0.1313040	total: 9.42s	remaining: 3.9s
# 707:	learn: 0.1309924	total: 9.43s	remaining: 3.89s
# 708:	learn: 0.1307816	total: 9.44s	remaining: 3.88s
# 709:	learn: 0.1306435	total: 9.46s	remaining: 3.86s
# 710:	learn: 0.1305353	total: 9.47s	remaining: 3.85s
# 711:	learn: 0.1302542	total: 9.49s	remaining: 3.84s
# 712:	learn: 0.1299931	total: 9.5s	remaining: 3.83s
# 713:	learn: 0.1298860	total: 9.52s	remaining: 3.81s
# 714:	learn: 0.1296930	total: 9.53s	remaining: 3.8s
# 715:	learn: 0.1294161	total: 9.54s	remaining: 3.78s
# 716:	learn: 0.1291136	total: 9.55s	remaining: 3.77s
# 717:	learn: 0.1290040	total: 9.57s	remaining: 3.76s
# 718:	learn: 0.1288080	total: 9.58s	remaining: 3.74s
# 719:	learn: 0.1286067	total: 9.59s	remaining: 3.73s
# 720:	learn: 0.1284602	total: 9.6s	remaining: 3.72s
# 721:	learn: 0.1282847	total: 9.62s	remaining: 3.7s
# 722:	learn: 0.1281116	total: 9.64s	remaining: 3.69s
# 723:	learn: 0.1279474	total: 9.65s	remaining: 3.68s
# 724:	learn: 0.1277934	total: 9.66s	remaining: 3.67s
# 725:	learn: 0.1276899	total: 9.68s	remaining: 3.65s
# 726:	learn: 0.1274976	total: 9.69s	remaining: 3.64s
# 727:	learn: 0.1274040	total: 9.71s	remaining: 3.63s
# 728:	learn: 0.1271292	total: 9.73s	remaining: 3.62s
# 729:	learn: 0.1268791	total: 9.74s	remaining: 3.6s
# 730:	learn: 0.1267307	total: 9.75s	remaining: 3.59s
# 731:	learn: 0.1264828	total: 9.76s	remaining: 3.57s
# 732:	learn: 0.1263506	total: 9.78s	remaining: 3.56s
# 733:	learn: 0.1263010	total: 9.79s	remaining: 3.55s
# 734:	learn: 0.1260279	total: 9.8s	remaining: 3.53s
# 735:	learn: 0.1258572	total: 9.81s	remaining: 3.52s
# 736:	learn: 0.1256019	total: 9.83s	remaining: 3.51s
# 737:	learn: 0.1254739	total: 9.84s	remaining: 3.49s
# 738:	learn: 0.1253361	total: 9.85s	remaining: 3.48s
# 739:	learn: 0.1251860	total: 9.87s	remaining: 3.47s
# 740:	learn: 0.1250777	total: 9.88s	remaining: 3.45s
# 741:	learn: 0.1249055	total: 9.89s	remaining: 3.44s
# 742:	learn: 0.1246820	total: 9.91s	remaining: 3.43s
# 743:	learn: 0.1245544	total: 9.92s	remaining: 3.41s
# 744:	learn: 0.1244388	total: 9.93s	remaining: 3.4s
# 745:	learn: 0.1241101	total: 9.94s	remaining: 3.39s
# 746:	learn: 0.1238943	total: 9.96s	remaining: 3.37s
# 747:	learn: 0.1237966	total: 9.97s	remaining: 3.36s
# 748:	learn: 0.1236101	total: 9.98s	remaining: 3.35s
# 749:	learn: 0.1235021	total: 10s	remaining: 3.33s
# 750:	learn: 0.1234162	total: 10s	remaining: 3.32s
# 751:	learn: 0.1232532	total: 10s	remaining: 3.3s
# 752:	learn: 0.1229925	total: 10s	remaining: 3.29s
# 753:	learn: 0.1228074	total: 10s	remaining: 3.28s
# 754:	learn: 0.1227589	total: 10.1s	remaining: 3.26s
# 755:	learn: 0.1225708	total: 10.1s	remaining: 3.25s
# 756:	learn: 0.1224529	total: 10.1s	remaining: 3.24s
# 757:	learn: 0.1223772	total: 10.1s	remaining: 3.22s
# 758:	learn: 0.1223338	total: 10.1s	remaining: 3.21s
# 759:	learn: 0.1221828	total: 10.1s	remaining: 3.2s
# 760:	learn: 0.1221050	total: 10.1s	remaining: 3.19s
# 761:	learn: 0.1218320	total: 10.2s	remaining: 3.17s
# 762:	learn: 0.1216834	total: 10.2s	remaining: 3.16s
# 763:	learn: 0.1214336	total: 10.2s	remaining: 3.15s
# 764:	learn: 0.1213138	total: 10.2s	remaining: 3.13s
# 765:	learn: 0.1209389	total: 10.2s	remaining: 3.12s
# 766:	learn: 0.1207640	total: 10.2s	remaining: 3.1s
# 767:	learn: 0.1206573	total: 10.2s	remaining: 3.09s
# 768:	learn: 0.1204619	total: 10.3s	remaining: 3.08s
# 769:	learn: 0.1203076	total: 10.3s	remaining: 3.07s
# 770:	learn: 0.1202176	total: 10.3s	remaining: 3.05s
# 771:	learn: 0.1200041	total: 10.3s	remaining: 3.04s
# 772:	learn: 0.1198876	total: 10.3s	remaining: 3.02s
# 773:	learn: 0.1196441	total: 10.3s	remaining: 3.01s
# 774:	learn: 0.1195352	total: 10.3s	remaining: 3s
# 775:	learn: 0.1193517	total: 10.3s	remaining: 2.99s
# 776:	learn: 0.1191532	total: 10.4s	remaining: 2.97s
# 777:	learn: 0.1188602	total: 10.4s	remaining: 2.96s
# 778:	learn: 0.1187179	total: 10.4s	remaining: 2.94s
# 779:	learn: 0.1186003	total: 10.4s	remaining: 2.93s
# 780:	learn: 0.1184704	total: 10.4s	remaining: 2.92s
# 781:	learn: 0.1184358	total: 10.4s	remaining: 2.91s
# 782:	learn: 0.1183903	total: 10.4s	remaining: 2.89s
# 783:	learn: 0.1181931	total: 10.4s	remaining: 2.88s
# 784:	learn: 0.1180328	total: 10.5s	remaining: 2.87s
# 785:	learn: 0.1178432	total: 10.5s	remaining: 2.85s
# 786:	learn: 0.1176281	total: 10.5s	remaining: 2.84s
# 787:	learn: 0.1175462	total: 10.5s	remaining: 2.83s
# 788:	learn: 0.1173984	total: 10.5s	remaining: 2.81s
# 789:	learn: 0.1172407	total: 10.5s	remaining: 2.8s
# 790:	learn: 0.1169807	total: 10.6s	remaining: 2.79s
# 791:	learn: 0.1168155	total: 10.6s	remaining: 2.77s
# 792:	learn: 0.1166608	total: 10.6s	remaining: 2.76s
# 793:	learn: 0.1164793	total: 10.6s	remaining: 2.75s
# 794:	learn: 0.1163776	total: 10.6s	remaining: 2.73s
# 795:	learn: 0.1162373	total: 10.6s	remaining: 2.72s
# 796:	learn: 0.1160151	total: 10.6s	remaining: 2.71s
# 797:	learn: 0.1159014	total: 10.6s	remaining: 2.69s
# 798:	learn: 0.1157294	total: 10.7s	remaining: 2.68s
# 799:	learn: 0.1155665	total: 10.7s	remaining: 2.67s
# 800:	learn: 0.1153592	total: 10.7s	remaining: 2.65s
# 801:	learn: 0.1151172	total: 10.7s	remaining: 2.64s
# 802:	learn: 0.1150822	total: 10.7s	remaining: 2.63s
# 803:	learn: 0.1149342	total: 10.7s	remaining: 2.62s
# 804:	learn: 0.1147045	total: 10.7s	remaining: 2.6s
# 805:	learn: 0.1145565	total: 10.8s	remaining: 2.59s
# 806:	learn: 0.1144972	total: 10.8s	remaining: 2.58s
# 807:	learn: 0.1143249	total: 10.8s	remaining: 2.56s
# 808:	learn: 0.1141466	total: 10.8s	remaining: 2.55s
# 809:	learn: 0.1140495	total: 10.8s	remaining: 2.54s
# 810:	learn: 0.1139710	total: 10.8s	remaining: 2.52s
# 811:	learn: 0.1138614	total: 10.8s	remaining: 2.51s
# 812:	learn: 0.1135925	total: 10.9s	remaining: 2.5s
# 813:	learn: 0.1133380	total: 10.9s	remaining: 2.48s
# 814:	learn: 0.1132364	total: 10.9s	remaining: 2.47s
# 815:	learn: 0.1130613	total: 10.9s	remaining: 2.46s
# 816:	learn: 0.1129304	total: 10.9s	remaining: 2.44s
# 817:	learn: 0.1127536	total: 10.9s	remaining: 2.43s
# 818:	learn: 0.1124816	total: 10.9s	remaining: 2.42s
# 819:	learn: 0.1123932	total: 11s	remaining: 2.4s
# 820:	learn: 0.1122856	total: 11s	remaining: 2.39s
# 821:	learn: 0.1122176	total: 11s	remaining: 2.38s
# 822:	learn: 0.1120608	total: 11s	remaining: 2.37s
# 823:	learn: 0.1119164	total: 11s	remaining: 2.35s
# 824:	learn: 0.1117958	total: 11s	remaining: 2.34s
# 825:	learn: 0.1116979	total: 11s	remaining: 2.32s
# 826:	learn: 0.1115157	total: 11s	remaining: 2.31s
# 827:	learn: 0.1113626	total: 11.1s	remaining: 2.3s
# 828:	learn: 0.1112706	total: 11.1s	remaining: 2.29s
# 829:	learn: 0.1110853	total: 11.1s	remaining: 2.27s
# 830:	learn: 0.1109317	total: 11.1s	remaining: 2.26s
# 831:	learn: 0.1107401	total: 11.1s	remaining: 2.25s
# 832:	learn: 0.1106034	total: 11.1s	remaining: 2.23s
# 833:	learn: 0.1105740	total: 11.2s	remaining: 2.22s
# 834:	learn: 0.1104356	total: 11.2s	remaining: 2.21s
# 835:	learn: 0.1103817	total: 11.2s	remaining: 2.19s
# 836:	learn: 0.1102433	total: 11.2s	remaining: 2.18s
# 837:	learn: 0.1102011	total: 11.2s	remaining: 2.17s
# 838:	learn: 0.1100602	total: 11.2s	remaining: 2.15s
# 839:	learn: 0.1100114	total: 11.2s	remaining: 2.14s
# 840:	learn: 0.1098783	total: 11.3s	remaining: 2.13s
# 841:	learn: 0.1097366	total: 11.3s	remaining: 2.11s
# 842:	learn: 0.1095818	total: 11.3s	remaining: 2.1s
# 843:	learn: 0.1093970	total: 11.3s	remaining: 2.09s
# 844:	learn: 0.1092566	total: 11.3s	remaining: 2.07s
# 845:	learn: 0.1090456	total: 11.3s	remaining: 2.06s
# 846:	learn: 0.1089208	total: 11.3s	remaining: 2.05s
# 847:	learn: 0.1088352	total: 11.3s	remaining: 2.03s
# 848:	learn: 0.1086576	total: 11.4s	remaining: 2.02s
# 849:	learn: 0.1085064	total: 11.4s	remaining: 2.01s
# 850:	learn: 0.1083279	total: 11.4s	remaining: 1.99s
# 851:	learn: 0.1082267	total: 11.4s	remaining: 1.98s
# 852:	learn: 0.1080880	total: 11.4s	remaining: 1.97s
# 853:	learn: 0.1080545	total: 11.4s	remaining: 1.96s
# 854:	learn: 0.1079930	total: 11.4s	remaining: 1.94s
# 855:	learn: 0.1077971	total: 11.5s	remaining: 1.93s
# 856:	learn: 0.1077429	total: 11.5s	remaining: 1.92s
# 857:	learn: 0.1075443	total: 11.5s	remaining: 1.9s
# 858:	learn: 0.1074573	total: 11.5s	remaining: 1.89s
# 859:	learn: 0.1072652	total: 11.5s	remaining: 1.88s
# 860:	learn: 0.1070855	total: 11.5s	remaining: 1.86s
# 861:	learn: 0.1070192	total: 11.5s	remaining: 1.85s
# 862:	learn: 0.1069367	total: 11.6s	remaining: 1.83s
# 863:	learn: 0.1068242	total: 11.6s	remaining: 1.82s
# 864:	learn: 0.1066630	total: 11.6s	remaining: 1.81s
# 865:	learn: 0.1065460	total: 11.6s	remaining: 1.8s
# 866:	learn: 0.1063252	total: 11.6s	remaining: 1.78s
# 867:	learn: 0.1062821	total: 11.6s	remaining: 1.77s
# 868:	learn: 0.1061442	total: 11.7s	remaining: 1.76s
# 869:	learn: 0.1059966	total: 11.7s	remaining: 1.74s
# 870:	learn: 0.1059346	total: 11.7s	remaining: 1.73s
# 871:	learn: 0.1057867	total: 11.7s	remaining: 1.72s
# 872:	learn: 0.1056334	total: 11.7s	remaining: 1.7s
# 873:	learn: 0.1054570	total: 11.7s	remaining: 1.69s
# 874:	learn: 0.1054044	total: 11.7s	remaining: 1.68s
# 875:	learn: 0.1052711	total: 11.8s	remaining: 1.66s
# 876:	learn: 0.1051602	total: 11.8s	remaining: 1.65s
# 877:	learn: 0.1049973	total: 11.8s	remaining: 1.64s
# 878:	learn: 0.1049377	total: 11.8s	remaining: 1.63s
# 879:	learn: 0.1048389	total: 11.8s	remaining: 1.61s
# 880:	learn: 0.1047693	total: 11.8s	remaining: 1.6s
# 881:	learn: 0.1045454	total: 11.8s	remaining: 1.58s
# 882:	learn: 0.1044110	total: 11.9s	remaining: 1.57s
# 883:	learn: 0.1043224	total: 11.9s	remaining: 1.56s
# 884:	learn: 0.1042125	total: 11.9s	remaining: 1.54s
# 885:	learn: 0.1040497	total: 11.9s	remaining: 1.53s
# 886:	learn: 0.1038679	total: 11.9s	remaining: 1.52s
# 887:	learn: 0.1036288	total: 11.9s	remaining: 1.5s
# 888:	learn: 0.1034836	total: 11.9s	remaining: 1.49s
# 889:	learn: 0.1033157	total: 12s	remaining: 1.48s
# 890:	learn: 0.1031649	total: 12s	remaining: 1.46s
# 891:	learn: 0.1029744	total: 12s	remaining: 1.45s
# 892:	learn: 0.1027302	total: 12s	remaining: 1.44s
# 893:	learn: 0.1026721	total: 12s	remaining: 1.42s
# 894:	learn: 0.1025539	total: 12s	remaining: 1.41s
# 895:	learn: 0.1023782	total: 12s	remaining: 1.4s
# 896:	learn: 0.1022551	total: 12.1s	remaining: 1.38s
# 897:	learn: 0.1020618	total: 12.1s	remaining: 1.37s
# 898:	learn: 0.1019660	total: 12.1s	remaining: 1.36s
# 899:	learn: 0.1018506	total: 12.1s	remaining: 1.34s
# 900:	learn: 0.1016600	total: 12.1s	remaining: 1.33s
# 901:	learn: 0.1015284	total: 12.1s	remaining: 1.32s
# 902:	learn: 0.1014601	total: 12.1s	remaining: 1.3s
# 903:	learn: 0.1014252	total: 12.1s	remaining: 1.29s
# 904:	learn: 0.1013211	total: 12.2s	remaining: 1.28s
# 905:	learn: 0.1011798	total: 12.2s	remaining: 1.26s
# 906:	learn: 0.1010886	total: 12.2s	remaining: 1.25s
# 907:	learn: 0.1009375	total: 12.2s	remaining: 1.24s
# 908:	learn: 0.1008146	total: 12.2s	remaining: 1.22s
# 909:	learn: 0.1007724	total: 12.2s	remaining: 1.21s
# 910:	learn: 0.1006898	total: 12.2s	remaining: 1.2s
# 911:	learn: 0.1005401	total: 12.3s	remaining: 1.18s
# 912:	learn: 0.1004890	total: 12.3s	remaining: 1.17s
# 913:	learn: 0.1004279	total: 12.3s	remaining: 1.16s
# 914:	learn: 0.1003749	total: 12.3s	remaining: 1.14s
# 915:	learn: 0.1003293	total: 12.3s	remaining: 1.13s
# 916:	learn: 0.1003017	total: 12.3s	remaining: 1.11s
# 917:	learn: 0.1002246	total: 12.3s	remaining: 1.1s
# 918:	learn: 0.1000638	total: 12.3s	remaining: 1.09s
# 919:	learn: 0.0999680	total: 12.3s	remaining: 1.07s
# 920:	learn: 0.0998684	total: 12.4s	remaining: 1.06s
# 921:	learn: 0.0998129	total: 12.4s	remaining: 1.05s
# 922:	learn: 0.0997437	total: 12.4s	remaining: 1.03s
# 923:	learn: 0.0996404	total: 12.4s	remaining: 1.02s
# 924:	learn: 0.0995160	total: 12.4s	remaining: 1.01s
# 925:	learn: 0.0993378	total: 12.4s	remaining: 993ms
# 926:	learn: 0.0992246	total: 12.4s	remaining: 980ms
# 927:	learn: 0.0992007	total: 12.5s	remaining: 966ms
# 928:	learn: 0.0990646	total: 12.5s	remaining: 953ms
# 929:	learn: 0.0989163	total: 12.5s	remaining: 939ms
# 930:	learn: 0.0988682	total: 12.5s	remaining: 926ms
# 931:	learn: 0.0987656	total: 12.5s	remaining: 913ms
# 932:	learn: 0.0985432	total: 12.5s	remaining: 899ms
# 933:	learn: 0.0983563	total: 12.5s	remaining: 886ms
# 934:	learn: 0.0982279	total: 12.5s	remaining: 872ms
# 935:	learn: 0.0981635	total: 12.6s	remaining: 859ms
# 936:	learn: 0.0980103	total: 12.6s	remaining: 846ms
# 937:	learn: 0.0979162	total: 12.6s	remaining: 832ms
# 938:	learn: 0.0978720	total: 12.6s	remaining: 819ms
# 939:	learn: 0.0978141	total: 12.6s	remaining: 806ms
# 940:	learn: 0.0977155	total: 12.6s	remaining: 793ms
# 941:	learn: 0.0975131	total: 12.7s	remaining: 779ms
# 942:	learn: 0.0974264	total: 12.7s	remaining: 766ms
# 943:	learn: 0.0973359	total: 12.7s	remaining: 752ms
# 944:	learn: 0.0972837	total: 12.7s	remaining: 739ms
# 945:	learn: 0.0971755	total: 12.7s	remaining: 727ms
# 946:	learn: 0.0970344	total: 12.7s	remaining: 713ms
# 947:	learn: 0.0968836	total: 12.8s	remaining: 700ms
# 948:	learn: 0.0967558	total: 12.8s	remaining: 686ms
# 949:	learn: 0.0966580	total: 12.8s	remaining: 673ms
# 950:	learn: 0.0964724	total: 12.8s	remaining: 659ms
# 951:	learn: 0.0963946	total: 12.8s	remaining: 646ms
# 952:	learn: 0.0963072	total: 12.8s	remaining: 632ms
# 953:	learn: 0.0962108	total: 12.8s	remaining: 619ms
# 954:	learn: 0.0959992	total: 12.8s	remaining: 606ms
# 955:	learn: 0.0958343	total: 12.9s	remaining: 592ms
# 956:	learn: 0.0956939	total: 12.9s	remaining: 579ms
# 957:	learn: 0.0955938	total: 12.9s	remaining: 565ms
# 958:	learn: 0.0953989	total: 12.9s	remaining: 552ms
# 959:	learn: 0.0953275	total: 12.9s	remaining: 539ms
# 960:	learn: 0.0952103	total: 12.9s	remaining: 525ms
# 961:	learn: 0.0950831	total: 13s	remaining: 512ms
# 962:	learn: 0.0949001	total: 13s	remaining: 498ms
# 963:	learn: 0.0948333	total: 13s	remaining: 485ms
# 964:	learn: 0.0947000	total: 13s	remaining: 471ms
# 965:	learn: 0.0946006	total: 13s	remaining: 458ms
# 966:	learn: 0.0944766	total: 13s	remaining: 445ms
# 967:	learn: 0.0943738	total: 13s	remaining: 431ms
# 968:	learn: 0.0942251	total: 13.1s	remaining: 418ms
# 969:	learn: 0.0941367	total: 13.1s	remaining: 405ms
# 970:	learn: 0.0940092	total: 13.1s	remaining: 391ms
# 971:	learn: 0.0938757	total: 13.1s	remaining: 378ms
# 972:	learn: 0.0937740	total: 13.1s	remaining: 364ms
# 973:	learn: 0.0936498	total: 13.1s	remaining: 351ms
# 974:	learn: 0.0935418	total: 13.1s	remaining: 337ms
# 975:	learn: 0.0933701	total: 13.2s	remaining: 324ms
# 976:	learn: 0.0932721	total: 13.2s	remaining: 310ms
# 977:	learn: 0.0931742	total: 13.2s	remaining: 297ms
# 978:	learn: 0.0930613	total: 13.2s	remaining: 283ms
# 979:	learn: 0.0930082	total: 13.2s	remaining: 270ms
# 980:	learn: 0.0929143	total: 13.2s	remaining: 256ms
# 981:	learn: 0.0928083	total: 13.2s	remaining: 243ms
# 982:	learn: 0.0927357	total: 13.3s	remaining: 229ms
# 983:	learn: 0.0925486	total: 13.3s	remaining: 216ms
# 984:	learn: 0.0924398	total: 13.3s	remaining: 202ms
# 985:	learn: 0.0923626	total: 13.3s	remaining: 189ms
# 986:	learn: 0.0922780	total: 13.3s	remaining: 175ms
# 987:	learn: 0.0921853	total: 13.3s	remaining: 162ms
# 988:	learn: 0.0920962	total: 13.3s	remaining: 148ms
# 989:	learn: 0.0919406	total: 13.4s	remaining: 135ms
# 990:	learn: 0.0917930	total: 13.4s	remaining: 121ms
# 991:	learn: 0.0916819	total: 13.4s	remaining: 108ms
# 992:	learn: 0.0915377	total: 13.4s	remaining: 94.4ms
# 993:	learn: 0.0914726	total: 13.4s	remaining: 81ms
# 994:	learn: 0.0913993	total: 13.4s	remaining: 67.5ms
# 995:	learn: 0.0912772	total: 13.4s	remaining: 54ms
# 996:	learn: 0.0911643	total: 13.5s	remaining: 40.5ms
# 997:	learn: 0.0909578	total: 13.5s	remaining: 27ms
# 998:	learn: 0.0908825	total: 13.5s	remaining: 13.5ms
# 999:	learn: 0.0907747	total: 13.5s	remaining: 0us
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.88
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# 'Tunning Data Report is Secured for this phase!!!'
