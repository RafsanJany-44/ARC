# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Untitled151.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyvital vitaldb vital
# !pip install neurokit2
import vitaldb
import pandas as pd
import numpy as np
from datetime import timedelta
from tqdm.notebook import tqdm

df_cases = pd.read_csv("https://api.vitaldb.net/cases")  # Load clinical data
df_trks = pd.read_csv('https://api.vitaldb.net/trks')  # Load track list
df_labs = pd.read_csv('https://api.vitaldb.net/labs')  # Load lab result
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 8.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.7/824.7 kB 54.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 39.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 64.2 MB/s eta 0:00:00
# ...

# %%
df_cases
# Out:
#       caseid  subjectid  casestart  caseend  anestart   aneend  opstart  \
# 0          1       5955          0    11542      -552  10848.0     1668
# 1          2       2487          0    15741     -1039  14921.0     1721
# 2          3       2861          0     4394      -590   4210.0     1090
# 3          4       1903          0    20990      -778  20222.0     2522
# 4          5       4416          0    21531     -1009  22391.0     2591
# ...      ...        ...        ...      ...       ...      ...      ...
# 6383    6384       5583          0    15248      -260  15640.0     2140
# 6384    6385       2278          0    20643      -544  20996.0     2396
# 6385    6386       4045          0    19451      -667  19133.0     3533
# 6386    6387       5230          0    12025      -550  12830.0     1730
# 6387    6388       1306          0    10249       -79  10121.0     2321
#
#       opend     adm      dis  ...  intraop_colloid  intraop_ppf  intraop_mdz  \
# ...

# %%
caseids = list(
    set(df_trks[df_trks['tname'] == 'Solar8000/ST_II']['caseid']) &
    set(df_trks[df_trks['tname'] == 'Solar8000/ART_MBP']['caseid']) &
     set(df_trks[df_trks['tname'] == 'Solar8000/ART_SBP']['caseid'])&
     set(df_trks[df_trks['tname'] == 'Solar8000/ART_DBP']['caseid'])&
    set(df_trks[df_trks['tname'] == 'SNUADC/ECG_II']['caseid'])
)

print('Total {} cases found'.format(len(caseids)))
# Out:
# Total 3559 cases found

# %%
vals = vitaldb.load_case(caseids[0], ['SNUADC/ECG_II','Solar8000/ST_II','Solar8000/ART_MBP','Solar8000/ART_SBP','Solar8000/ART_DBP'], 1 / 100)

# %%
time_col=[]
for i in range(len(vals)):
  time_col.append(i*(1/500))

vals = np.insert(vals, 0, time_col, axis=1)
vals = np.insert(vals, 0, time_col, axis=1)
vals = np.insert(vals, 0, time_col, axis=1)

df = pd.DataFrame(vals, columns=['Segment','Time(sec)','Time','SNUADC/ECG_II','Solar8000/ST_II','Solar8000/ART_MBP','Solar8000/ART_SBP','Solar8000/ART_DBP'])

# %%
df
# Out:
#           Segment  Time(sec)      Time  SNUADC/ECG_II  Solar8000/ST_II  \
# 0           0.000      0.000     0.000            NaN              NaN
# 1           0.002      0.002     0.002            NaN              NaN
# 2           0.004      0.004     0.004            NaN              NaN
# 3           0.006      0.006     0.006            NaN              NaN
# 4           0.008      0.008     0.008            NaN              NaN
# ...           ...        ...       ...            ...              ...
# 1154106  2308.212   2308.212  2308.212      -0.265839              NaN
# 1154107  2308.214   2308.214  2308.214       0.109395              NaN
# 1154108  2308.216   2308.216  2308.216       0.148893              NaN
# 1154109  2308.218   2308.218  2308.218      -0.325087              NaN
# 1154110  2308.220   2308.220  2308.220            NaN              NaN
#
#          Solar8000/ART_MBP  Solar8000/ART_SBP  Solar8000/ART_DBP
# ...

# %%
indx = 0

for i in tqdm(df['Time(sec)']):
  df['Time'][indx] = str(timedelta(seconds=i))
  indx+=1
# Out:
#   0%|          | 0/1154111 [00:00<?, ?it/s]

# %%
df
# Out:
#            Segment  Time(sec)            Time  SNUADC/ECG_II  Solar8000/ST_II  \
# 0        Segment_1      0.000         0:00:00            NaN             -0.3
# 1        Segment_1      0.002  0:00:00.002000            NaN             -0.3
# 2        Segment_1      0.004  0:00:00.004000            NaN             -0.3
# 3        Segment_1      0.006  0:00:00.006000            NaN             -0.3
# 4        Segment_1      0.008  0:00:00.008000            NaN             -0.3
# ...            ...        ...             ...            ...              ...
# 1154106   2308.212   2308.212  0:38:28.212000      -0.265839              NaN
# 1154107   2308.214   2308.214  0:38:28.214000       0.109395              NaN
# 1154108   2308.216   2308.216  0:38:28.216000       0.148893              NaN
# 1154109   2308.218   2308.218  0:38:28.218000      -0.325087              NaN
# 1154110    2308.22   2308.220  0:38:28.220000            NaN              NaN
#
# ...

# %%
sec_segment = 10
segment_num = 1
start_idx = 0
end_idx = int(sec_segment/(1/500) + 1)

start_idx = end_idx
end_idx = end_idx + int(sec_segment/(1/500))


start_idx,end_idx
# Out:
# (5001, 10001)

# %%
int(df.shape[0]/int(sec_segment/(1/500) + 1))
# Out:
# 230

# %%
sec_segment = 10
segment_num = 1
start_idx = 0
end_idx = int(sec_segment/(1/500) + 1)





for i in tqdm(range(int(df.shape[0]/int(sec_segment/(1/500) + 1)))):

  temp_df = df.iloc[start_idx:end_idx,:]

  mean_1 = temp_df["Solar8000/ST_II"].mean()
  mean_2 = temp_df["Solar8000/ART_MBP"].mean()
  mean_3 = temp_df["Solar8000/ART_SBP"].mean()
  mean_4 = temp_df["Solar8000/ART_DBP"].mean()


  for i in tqdm(range(start_idx,end_idx)):
    df["Segment"][i] = "Segment_"+str(segment_num)
    df["Solar8000/ST_II"][i] = mean_1
    df["Solar8000/ART_MBP"][i]= mean_2
    df["Solar8000/ART_SBP"][i] = mean_3
    df["Solar8000/ART_DBP"][i] = mean_4


  start_idx = end_idx
  end_idx = end_idx + int(sec_segment/(1/500))
  segment_num += 1
# Out:
# (-0.30000000447034836, -8.64, -7.28, -8.88)

# %%
segment_num = 1

for i in tqdm(range(start_idx,end_idx)):
  df["Segment"][i] = "Segment_"+str(segment_num)
  df["Solar8000/ST_II"][i] = mean_1
  df["Solar8000/ART_MBP"][i]= mean_2
  df["Solar8000/ART_SBP"][i] = mean_3
  df["Solar8000/ART_DBP"][i] = mean_4
# Out:
# <ipython-input-29-e9f90bd640d4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Segment"][i] = "Segment_"+str(segment_num)
# <ipython-input-29-e9f90bd640d4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Solar8000/ST_II"][i] = mean_1
# <ipython-input-29-e9f90bd640d4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Solar8000/ART_MBP"][i]= mean_2
# ...

# %%
op_st = df_cases[(df_cases['caseid'] == caseids[0])]['casestart'].values[0]
op_end = df_cases[(df_cases['caseid'] == caseids[0])]['caseend'].values[0]
op_st,op_end
# Out:
# (0, 11542)

# %%
op_st = df_cases[(df_cases['caseid'] == caseids[0])]['opstart'].values[0]
op_end = df_cases[(df_cases['caseid'] == caseids[0])]['opend'].values[0]
op_st,op_end
# Out:
# (1668, 10368)
