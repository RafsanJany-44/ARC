# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Untitled160.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("/content/Vital_ECG_MAP_features_09.30.2023_S1-S9.csv")
all_columns = list(dataset.columns)
all_sub = list(set(dataset["Case_ID"]))

# %%
sub = widgets.RadioButtons(
    options=all_sub+["ALL"],
    layout={'width': 'max-content'},
    description='All COl:',
    disabled=False
)
display(sub)
# Out:
# RadioButtons(description='All COl:', layout=Layout(width='max-content'), options=(1, 10, 4, 'ALL'), value=1)

# %%
k = widgets.RadioButtons(
    options=all_columns,
    layout={'width': 'max-content'},
    description='All COl:',
    disabled=False
)
display(k)
# Out:
# RadioButtons(description='All COl:', layout=Layout(width='max-content'), options=('Case_ID', 'Segment', 'ST_II…

# %%
s = widgets.RadioButtons(
    options=["Non-Hypotension","Hypotension"],
    layout={'width': 'max-content'},
    description='Stat: ',
    disabled=False
)
display(s)
# Out:
# RadioButtons(description='Stat: ', layout=Layout(width='max-content'), options=('Non-Hypotension', 'Hypotensio…

# %%
if sub.value=="ALL":
  df = dataset.query('Status =="'+s.value+'"')
else:
  df = dataset.query('Status =="'+s.value+'" and Case_ID=='+str(sub.value))



sns.set_theme()
sns.distplot(df[k.value], hist=True, kde=True,
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'green'},
             kde_kws={'linewidth': 2})
# Out:
# <ipython-input-89-3430231fe9f3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[k.value], hist=True, kde=True,
# <Axes: xlabel='ST_duration', ylabel='Density'>
