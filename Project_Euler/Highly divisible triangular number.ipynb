# %%
def div(n):
  talika=[]
  for i in range(1,n+1):
    if n%i==0:
      talika.append(i)
  return len(talika)
# Out:
#   File "<ipython-input-6-c1abeb840ed0>", line 1
#     def div(500000500000):
#                        ^
# SyntaxError: invalid syntax

# %%
while True:
  n=100
  sum=0
  for i in range(1,n+1):
    sum=sum+i
  print(sum)
  if div==500:
    print(sum)
    break
  n+1
# Out:
# Streaming output truncated to the last 5000 lines.
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# 5050
# ...
