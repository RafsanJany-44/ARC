# %%
def prim(n):
  flag=1
  for i in range(2,int(n/2)+1):
    if n%i==0:
      flag=0
      if n==2: flag=1
      break
  return flag

# %%
i=2
n=2000000
sum=0
while True:
  if prim(i)==1:

    sum=sum+i
  i+=1
  if i>=n:

    break
print(sum)
#142913828922
# Out:
# 142913828922
