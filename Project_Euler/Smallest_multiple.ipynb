# %%
def multi(n):
  y=0
  talika=[]
  i=2
  for j in range(1,int(n/2)+1):
    if n%i==0:
      y=n/i
      talika.append(i)
      n=y
      i=2
    else:
      i+=1
  if len(talika)==0:
    talika.append(n)
  return talika
k=[]
for i in range(1,20):
  k.append(multi(i))

print(max(k))
#232792560
# Out:
# [19]

# %%
n=1
talika=[]
y=0
i=2
for n in range(1,(21)):
  for j in range(1,int(n/2)+1):
    if n%i==0:
      y=n/i
      talika.append(i)
      print(i)
      n=y
      i=2
    else:
        i+=1
    if len(talika)==0:
      talika.append(n)
print(talika)
# Out:
# 2
# 4
# 6
# 8
# 3
# 3
# 2
# 5
# 12
# 14
# 3
# 5
# 4
# 2
# 2
# 18
# 20
# [2, 4, 6, 8, 3, 3, 2, 5, 12, 14, 3, 5, 4, 2, 2, 18, 20]
