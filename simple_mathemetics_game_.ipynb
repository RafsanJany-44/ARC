# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ACM/blob/master/simple_mathemetics_game_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r

def gen_list():             # generating unique array of 50 random numbers
  number=[]             
  for i in range(0,50):
    n = r.randint(0,10000)
    if n not in number:
      number.append(n)
  return number

def starting():     #welcome messaages and instructions
  print("______________Welcome to Python Math Game. Test your Math Skill!!!______________")
  print()
  print("***Instruction: You will be given a set of qestion. The number of question will be chosen by you.")
  print("You can chose types of your mathematics questions according to diffrent types of operators***")
  print()


def choice():       # asking user to choice question type 
  print("Chosse Your Questions Type:")
  print("Press 1 For Addition(+).")
  print("Press 2 For subtraction(-).")
  print("Press 3 For multiplication(*).")
  print("Press 4 For division(/).")
  print("Press 5 For percentage(%).")
  print("Press 6 For exponent and multiplication. (Hard)")
  print("Press 7 For floor division and multiplication.(Hard)")
  print("Press 8 For subtraction and modulo.(Hard)")
  print("Press 0 for Exit.")
  return int(input())     #taking input and return from user


def num_of_question():
  print("How many questions do you want to answer?")
  return int(input())     #taking number questions from user



def question_engine(num_list,questions,op):      #generating questions
  right=0                             # to kep track right answwer
  wrong=0                              # to keep track wrong answer
  for i in range(1,questions+1):
    
    index1=r.randint(0,len(num_list)-1)     # chossing random two number from our array
    index2=r.randint(0,len(num_list)-1)
    #Addition
    if "+" in op:
      print("-------------------------------------------------------")
      print("Q"+str(i)+". What is "+str(num_list[index1])+" + "+str(num_list[index2])+"=?")
      answer=input()
      if(answer==str(num_list[index1]+num_list[index2])):
        print("Correct Answer!!!")
        right+=1
      else:
        print("Wrong Answer!")
        print("The correct answer is: ",num_list[index1]+num_list[index2])
        wrong+=1
      print()
    #Substraction
    elif "-" in op:
      print("-------------------------------------------------------")
      print("Q"+str(i)+". What is "+str(num_list[index1])+" - "+str(num_list[index2])+"=?")
      answer=input()
      if(answer==str(num_list[index1]-num_list[index2])):
        print("Correct Answer!!!")
        right+=1
      else:
        print("Wrong Answer!")
        print("The correct answer is: ",num_list[index1]-num_list[index2])
        wrong+=1
      print()
    #Multiplication
    elif "*" in op:
      print("-------------------------------------------------------")
      print("Q"+str(i)+". What is "+str(num_list[index1])+" * "+str(num_list[index2])+"=?")
      answer=input()
      if(answer==str(num_list[index1]*num_list[index2])):
        print("Correct Answer!!!")
        right+=1
      else:
        print("Wrong Answer!")
        print("The correct answer is: ",num_list[index1]*num_list[index2])
        wrong+=1
      print()
    #devidation
    elif "/" in op:
      print("-------------------------------------------------------")
      print("Q"+str(i)+". What is "+str(num_list[index1])+" / "+str(num_list[index2])+"=? (two decimal)")
      answer=input()
      if(answer=="{:.2f}".format(num_list[index1]/num_list[index2])):
        print("Correct Answer!!!")
        right+=1
      else:
        print("Wrong Answer!")
        print("The correct answer is: "+"{:.2f}".format(num_list[index1]/num_list[index2]))
        wrong+=1
      print()
    #exponent and multiplication.
    elif "**" in op and "*" in op:
      d=r.randint(0,1)
      if d==0:          # for randomly chose exponent and multiplication
        print("-------------------------------------------------------")
        print("Q"+str(i)+". What is "+str(num_list[index1])+" ^ "+str(num_list[index2])+"=?")
        answer=input()
        if(answer==str(num_list[index1]**num_list[index2])):
          print("Correct Answer!!!")
          right+=1
        else:
          print("Wrong Answer!")
          print("The correct answer is: ",num_list[index1]**num_list[index2])
          wrong+=1
          print()
      else:
        print("-------------------------------------------------------")
        print("Q"+str(i)+". What is "+str(num_list[index1])+" * "+str(num_list[index2])+"=?")
        answer=input()
        if(answer==str(num_list[index1]*num_list[index2])):
          print("Correct Answer!!!")
          right+=1
        else:
          print("Wrong Answer!")
          print("The correct answer is: ",num_list[index1]*num_list[index2])
          wrong+=1
          print()
    #floor division and multiplication.
    elif "/" in op and "*" in op:
      d=r.randint(0,1)
      if d==0:          # for randomly chose floor division and multiplication.
        print("-------------------------------------------------------")
        print("Q"+str(i)+". What is "+str(num_list[index1])+" / "+str(num_list[index2])+"=?(two decimal)")
        answer=input()
        if(answer=="{:.2f}".format(num_list[index1]/num_list[index2])):
          print("Correct Answer!!!")
          right+=1
        else:
          print("Wrong Answer!")
          print("The correct answer is: "+"{:.2f}".format(num_list[index1]/num_list[index2]))
          wrong+=1
          print()
      else:
        print("-------------------------------------------------------")
        print("Q"+str(i)+". What is "+str(num_list[index1])+" * "+str(num_list[index2])+"=?")
        answer=input()
        if(answer==str(num_list[index1]*num_list[index2])):
          print("Correct Answer!!!")
          right+=1
        else:
          print("Wrong Answer!")
          print("The correct answer is: ",num_list[index1]*num_list[index2])
          wrong+=1
          print()
    #fsubtraction and modulo
    elif "%" in op and "-" in op:
      d=r.randint(0,1)
      if d==0:          # for randomly chose subtraction and modulo
        print("-------------------------------------------------------")
        print("Q"+str(i)+". What is "+str(num_list[index1])+" % "+str(num_list[index2])+"=?")
        answer=input()
        if(answer=="{:.2f}".format(num_list[index1]%num_list[index2])):
          print("Correct Answer!!!")
          right+=1
        else:
          print("Wrong Answer!")
          print("The correct answer is: ",num_list[index1]%num_list[index2])
          wrong+=1
          print()
      else:
        print("-------------------------------------------------------")
        print("Q"+str(i)+". What is "+str(num_list[index1])+" - "+str(num_list[index2])+"=?")
        answer=input()
        if(answer==str(num_list[index1]-num_list[index2])):
          print("Correct Answer!!!")
          right+=1
        else:
          print("Wrong Answer!")
          print("The correct answer is: ",num_list[index1]-num_list[index2])
          wrong+=1
          print()
    elif "%%" in op:
      print("-------------------------------------------------------")
      per=r.randint(1,100)          #randomly taking percentage
      print("Q"+str(i)+". What is the "+str(per)+"% of "+str(num_list[index2])+"=? (two decimal)")
      answer=input()
      if(answer=="{:.2f}".format((per/num_list[index2])*100)):
        print("Correct Answer!!!")
        right+=1
      else:
        print("Wrong Answer!")
        print("The correct answer is: "+"{:.2f}".format((per/num_list[index2])*100))
        wrong+=1
      print()
  return right,wrong

def result(questions,right,wrong):        #  result
  per=(right/questions)*100
  print("Total Number of Question: ",questions)
  print("Correct Answer          : ",right)
  print("Wrong Answer            : ",wrong)
  print("Success Rate            : "+str(per)+"%.")
  if(per<30):
    print("Need More Practice!")
  elif(30<=per<40):
    print("Not Good.")
  elif(40<=per<60):
    print("Not Bad")
  elif(60<=per<=80):
    print("Master!!")
  else:
    print("Grand Master!!!")
  print()



#starting the main phase
starting()

while(1):
  print('------------------------------------------------------------------------------')
  c=choice()
  if c==0:
    break

  #num_list=gen_list()
  num_list=[3,4,5,6,1,2,9]
  if c==1:  #for Addition
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["+"])
    result(questions,right,wrong)

  elif c==2:   #for subtraction
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["-"])
    result(questions,right,wrong)

  elif c==3: #for multiplication
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["*"])
    result(questions,right,wrong)

  elif c==4: #for division
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["/"])
    result(questions,right,wrong)

  elif c==5:  #for percentage
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["%%"])
    result(questions,right,wrong)

  elif c==6:  #for exponent and multiplication
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["**","*"])
    result(questions,right,wrong)

  elif c==7:  #for floor division and multiplication
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["/","*"])
    result(questions,right,wrong)


  elif c==8:   #for subtraction and modulo
    questions=num_of_question()
    right,wrong=question_engine(num_list,questions,["-","%"])
    result(questions,right,wrong)

  print("-------------------------------------------------------------------------------------------------")
  print("Play again? (y/n)")
  if(input()=='n'):
    break

print("_____________________Thanks For Playing. Have A Good Day_____________________")
# Out:
# ______________Welcome to Python Math Game. Test your Math Skill!!!______________
#
# ***Instruction: You will be given a set of qestion. The number of question will be chosen by you.
# You can chose types of your mathematics questions according to diffrent types of operators***
#
# ------------------------------------------------------------------------------
# Chosse Your Questions Type:
# Press 1 For Addition(+).
# Press 2 For subtraction(-).
# Press 3 For multiplication(*).
# Press 4 For division(/).
# Press 5 For percentage(%).
# Press 6 For exponent and multiplication. (Hard)
# Press 7 For floor division and multiplication.(Hard)
# Press 8 For subtraction and modulo.(Hard)
# Press 0 for Exit.
# 8
# How many questions do you want to answer?
# 5
# -------------------------------------------------------
# Q1. What is 6 - 3=?
# 3
# Correct Answer!!!
#
# -------------------------------------------------------
# Q2. What is 9 - 4=?
# 5
# Correct Answer!!!
#
# -------------------------------------------------------
# Q3. What is 6 - 4=?
# 2
# Correct Answer!!!
#
# -------------------------------------------------------
# Q4. What is 2 - 4=?
# -2
# Correct Answer!!!
#
# -------------------------------------------------------
# Q5. What is 9 - 3=?
# 6
# Correct Answer!!!
#
# Total Number of Question:  5
# Correct Answer          :  5
# Wrong Answer            :  0
# Success Rate            : 100.0%.
# Grand Master!!!
#
# -------------------------------------------------------------------------------------------------
# Play again? (y/n)
# n
# _____________________Thanks For Playing. Have A Good Day_____________________
