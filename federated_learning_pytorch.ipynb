# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/federated_learning_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing Libraries

# %%
import torch
from torchvision.datasets import MNIST
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# %% [markdown]
# ### Load Dataset

# %%
train_dataset = MNIST('/kaggle/working', train=True, download=True, transform=transforms.ToTensor())
test_dataset = MNIST('/kaggle/working', train=False, download=True, transform=transforms.ToTensor())

train_dataset, dev_dataset = random_split(train_dataset, [int(len(train_dataset) * 0.83), int(len(train_dataset) * 0.17)])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 90542201.30it/s]
# Extracting /kaggle/working/MNIST/raw/train-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 25751635.59it/s]
# Extracting /kaggle/working/MNIST/raw/train-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 27376224.73it/s]
# Extracting /kaggle/working/MNIST/raw/t10k-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 7024531.26it/s]
# Extracting /kaggle/working/MNIST/raw/t10k-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw

# %% [markdown]
# ### Define Notebook Constants

# %%
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
total_dev_size = len(dev_dataset)

classes = 10
input_dim = 784

num_clients = 8
rounds = 30
batch_size = 128
epochs_per_client = 3
learning_rate = 2e-2

# %%
total_train_size, total_dev_size, total_test_size
# Out:
# (49800, 10200, 10000)

# %% [markdown]
# ### Define utilities for GPU support

# %%
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
        def __init__(self, dl, device):
            self.dl = dl
            self.device = device

        def __iter__(self):
            for batch in self.dl:
                yield to_device(batch, self.device)

        def __len__(self):
            return len(self.dl)

device = get_device()

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Define FederatedNet class

# %%
class FederatedNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 20, 7)
        self.conv2 = torch.nn.Conv2d(20, 40, 7)
        self.maxpool = torch.nn.MaxPool2d(2, 2)
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(2560, 10)
        self.non_linearity = torch.nn.functional.relu
        self.track_layers = {'conv1': self.conv1, 'conv2': self.conv2, 'linear': self.linear}

    def forward(self, x_batch):
        out = self.conv1(x_batch)
        out = self.non_linearity(out)
        out = self.conv2(out)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.flatten(out)
        out = self.linear(out)
        return out

    def get_track_layers(self):
        return self.track_layers

    def apply_parameters(self, parameters_dict):
        with torch.no_grad():
            for layer_name in parameters_dict:
                self.track_layers[layer_name].weight.data *= 0
                self.track_layers[layer_name].bias.data *= 0
                self.track_layers[layer_name].weight.data += parameters_dict[layer_name]['weight']
                self.track_layers[layer_name].bias.data += parameters_dict[layer_name]['bias']

    def get_parameters(self):
        parameters_dict = dict()
        for layer_name in self.track_layers:
            parameters_dict[layer_name] = {
                'weight': self.track_layers[layer_name].weight.data,
                'bias': self.track_layers[layer_name].bias.data
            }
        return parameters_dict

    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))

    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)

    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history

    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# %% [markdown]
# ### Define Client class

# %%
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset

    def get_dataset_size(self):
        return len(self.dataset)

    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.apply_parameters(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        print('{}: Loss = {}, Accuracy = {}'.format(self.client_id, round(train_history[-1][0], 4), round(train_history[-1][1], 4)))
        return net.get_parameters()

# %% [markdown]
# ### Setup clients

# %%
examples_per_client = total_train_size // num_clients
client_datasets = random_split(train_dataset, [min(i + examples_per_client,
           total_train_size) - i for i in range(0, total_train_size, examples_per_client)])
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# %% [markdown]
# ### Start server

# %%
global_net = to_device(FederatedNet(), device)
history = []
for i in range(rounds):
    print('Start Round {} ...'.format(i + 1))
    curr_parameters = global_net.get_parameters()
    new_parameters = dict([(layer_name, {'weight': 0, 'bias': 0}) for layer_name in curr_parameters])
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size() / total_train_size
        for layer_name in client_parameters:
            new_parameters[layer_name]['weight'] += fraction * client_parameters[layer_name]['weight']
            new_parameters[layer_name]['bias'] += fraction * client_parameters[layer_name]['bias']
    global_net.apply_parameters(new_parameters)

    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(dev_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4),
            round(dev_loss, 4), round(dev_acc, 4)))
    history.append((train_loss, dev_loss))
# Out:
# Start Round 1 ...
# client_0: Loss = 0.5099, Accuracy = 0.8418
# client_1: Loss = 0.5108, Accuracy = 0.8447
# client_2: Loss = 0.516, Accuracy = 0.8448
# client_3: Loss = 0.5232, Accuracy = 0.8392
# client_4: Loss = 0.5032, Accuracy = 0.8518
# client_5: Loss = 0.5123, Accuracy = 0.8483
# client_6: Loss = 0.4977, Accuracy = 0.8482
# client_7: Loss = 0.4856, Accuracy = 0.8534
# After round 1, train_loss = 0.4028, dev_loss = 0.421, dev_acc = 0.8756
#
# Start Round 2 ...
# client_0: Loss = 0.3193, Accuracy = 0.907
# client_1: Loss = 0.317, Accuracy = 0.9069
# client_2: Loss = 0.3243, Accuracy = 0.9036
# client_3: Loss = 0.3126, Accuracy = 0.9094
# client_4: Loss = 0.3267, Accuracy = 0.9039
# client_5: Loss = 0.3187, Accuracy = 0.9085
# client_6: Loss = 0.3282, Accuracy = 0.9025
# client_7: Loss = 0.3093, Accuracy = 0.9099
# After round 2, train_loss = 0.2907, dev_loss = 0.3082, dev_acc = 0.9119
#
# Start Round 3 ...
# client_0: Loss = 0.2306, Accuracy = 0.9346
# client_1: Loss = 0.233, Accuracy = 0.9347
# client_2: Loss = 0.2482, Accuracy = 0.9278
# client_3: Loss = 0.2215, Accuracy = 0.9346
# client_4: Loss = 0.2444, Accuracy = 0.9319
# client_5: Loss = 0.2291, Accuracy = 0.9357
# client_6: Loss = 0.2381, Accuracy = 0.9287
# client_7: Loss = 0.2289, Accuracy = 0.9347
# After round 3, train_loss = 0.2184, dev_loss = 0.2329, dev_acc = 0.933
#
# Start Round 4 ...
# client_0: Loss = 0.1807, Accuracy = 0.9486
# client_1: Loss = 0.1788, Accuracy = 0.9518
# client_2: Loss = 0.1953, Accuracy = 0.942
# client_3: Loss = 0.169, Accuracy = 0.9484
# client_4: Loss = 0.1885, Accuracy = 0.9462
# client_5: Loss = 0.1747, Accuracy = 0.9521
# client_6: Loss = 0.1822, Accuracy = 0.9524
# client_7: Loss = 0.1756, Accuracy = 0.9533
# After round 4, train_loss = 0.1735, dev_loss = 0.188, dev_acc = 0.9457
#
# Start Round 5 ...
# client_0: Loss = 0.1512, Accuracy = 0.9553
# client_1: Loss = 0.1465, Accuracy = 0.96
# client_2: Loss = 0.1607, Accuracy = 0.9536
# client_3: Loss = 0.1349, Accuracy = 0.9617
# client_4: Loss = 0.159, Accuracy = 0.9533
# client_5: Loss = 0.1432, Accuracy = 0.9604
# client_6: Loss = 0.1477, Accuracy = 0.9602
# client_7: Loss = 0.1441, Accuracy = 0.9595
# After round 5, train_loss = 0.1435, dev_loss = 0.1586, dev_acc = 0.9538
#
# Start Round 6 ...
# client_0: Loss = 0.1289, Accuracy = 0.9615
# client_1: Loss = 0.1243, Accuracy = 0.9658
# client_2: Loss = 0.1365, Accuracy = 0.9598
# client_3: Loss = 0.1142, Accuracy = 0.9691
# client_4: Loss = 0.1355, Accuracy = 0.9591
# client_5: Loss = 0.1208, Accuracy = 0.9655
# client_6: Loss = 0.1248, Accuracy = 0.9662
# client_7: Loss = 0.1255, Accuracy = 0.9659
# After round 6, train_loss = 0.1233, dev_loss = 0.1382, dev_acc = 0.9603
#
# Start Round 7 ...
# client_0: Loss = 0.1159, Accuracy = 0.9658
# client_1: Loss = 0.1088, Accuracy = 0.9694
# client_2: Loss = 0.1212, Accuracy = 0.9624
# client_3: Loss = 0.099, Accuracy = 0.9729
# client_4: Loss = 0.1222, Accuracy = 0.9632
# client_5: Loss = 0.1074, Accuracy = 0.97
# client_6: Loss = 0.1104, Accuracy = 0.9693
# client_7: Loss = 0.1113, Accuracy = 0.9704
# After round 7, train_loss = 0.1095, dev_loss = 0.1244, dev_acc = 0.9646
#
# Start Round 8 ...
# client_0: Loss = 0.1043, Accuracy = 0.967
# client_1: Loss = 0.097, Accuracy = 0.9727
# client_2: Loss = 0.1091, Accuracy = 0.9656
# client_3: Loss = 0.0881, Accuracy = 0.9751
# client_4: Loss = 0.1081, Accuracy = 0.9683
# client_5: Loss = 0.0926, Accuracy = 0.9738
# client_6: Loss = 0.0997, Accuracy = 0.9731
# client_7: Loss = 0.1005, Accuracy = 0.9718
# After round 8, train_loss = 0.0991, dev_loss = 0.1135, dev_acc = 0.9676
#
# Start Round 9 ...
# client_0: Loss = 0.095, Accuracy = 0.9715
# client_1: Loss = 0.0895, Accuracy = 0.9763
# client_2: Loss = 0.1009, Accuracy = 0.9678
# client_3: Loss = 0.0787, Accuracy = 0.9777
# client_4: Loss = 0.097, Accuracy = 0.9702
# client_5: Loss = 0.0847, Accuracy = 0.9769
# client_6: Loss = 0.0896, Accuracy = 0.9738
# client_7: Loss = 0.0897, Accuracy = 0.9747
# After round 9, train_loss = 0.0911, dev_loss = 0.1054, dev_acc = 0.9696
#
# Start Round 10 ...
# client_0: Loss = 0.0866, Accuracy = 0.9739
# client_1: Loss = 0.0826, Accuracy = 0.9766
# client_2: Loss = 0.0908, Accuracy = 0.9723
# client_3: Loss = 0.0725, Accuracy = 0.9806
# client_4: Loss = 0.0922, Accuracy = 0.9699
# client_5: Loss = 0.0775, Accuracy = 0.9787
# client_6: Loss = 0.0843, Accuracy = 0.9763
# client_7: Loss = 0.0846, Accuracy = 0.9765
# After round 10, train_loss = 0.0853, dev_loss = 0.1004, dev_acc = 0.9704
#
# Start Round 11 ...
# client_0: Loss = 0.0797, Accuracy = 0.9766
# client_1: Loss = 0.077, Accuracy = 0.9804
# client_2: Loss = 0.0863, Accuracy = 0.9725
# client_3: Loss = 0.0688, Accuracy = 0.9797
# client_4: Loss = 0.0855, Accuracy = 0.9745
# client_5: Loss = 0.0714, Accuracy = 0.9794
# client_6: Loss = 0.0794, Accuracy = 0.9782
# client_7: Loss = 0.0784, Accuracy = 0.9797
# After round 11, train_loss = 0.0792, dev_loss = 0.094, dev_acc = 0.9732
#
# Start Round 12 ...
# client_0: Loss = 0.0778, Accuracy = 0.9769
# client_1: Loss = 0.0745, Accuracy = 0.98
# client_2: Loss = 0.0811, Accuracy = 0.9743
# client_3: Loss = 0.0628, Accuracy = 0.9836
# client_4: Loss = 0.08, Accuracy = 0.9749
# client_5: Loss = 0.068, Accuracy = 0.9797
# client_6: Loss = 0.0756, Accuracy = 0.9801
# client_7: Loss = 0.0723, Accuracy = 0.9805
# After round 12, train_loss = 0.0746, dev_loss = 0.0886, dev_acc = 0.9744
#
# Start Round 13 ...
# client_0: Loss = 0.0724, Accuracy = 0.9778
# client_1: Loss = 0.0725, Accuracy = 0.9802
# client_2: Loss = 0.0772, Accuracy = 0.9769
# client_3: Loss = 0.0609, Accuracy = 0.9821
# client_4: Loss = 0.0747, Accuracy = 0.9757
# client_5: Loss = 0.0631, Accuracy = 0.9821
# client_6: Loss = 0.0707, Accuracy = 0.9797
# client_7: Loss = 0.0691, Accuracy = 0.9809
# After round 13, train_loss = 0.071, dev_loss = 0.0856, dev_acc = 0.9755
#
# Start Round 14 ...
# client_0: Loss = 0.0686, Accuracy = 0.9791
# client_1: Loss = 0.0682, Accuracy = 0.9821
# client_2: Loss = 0.0743, Accuracy = 0.9764
# client_3: Loss = 0.0559, Accuracy = 0.9832
# client_4: Loss = 0.0701, Accuracy = 0.9785
# client_5: Loss = 0.0597, Accuracy = 0.9825
# client_6: Loss = 0.067, Accuracy = 0.9822
# client_7: Loss = 0.0661, Accuracy = 0.9803
# After round 14, train_loss = 0.0675, dev_loss = 0.082, dev_acc = 0.9765
#
# Start Round 15 ...
# client_0: Loss = 0.0648, Accuracy = 0.9818
# client_1: Loss = 0.0647, Accuracy = 0.9828
# client_2: Loss = 0.0691, Accuracy = 0.9792
# client_3: Loss = 0.0535, Accuracy = 0.9841
# client_4: Loss = 0.066, Accuracy = 0.9793
# client_5: Loss = 0.056, Accuracy = 0.9837
# client_6: Loss = 0.0642, Accuracy = 0.9828
# client_7: Loss = 0.0631, Accuracy = 0.9822
# After round 15, train_loss = 0.0646, dev_loss = 0.0794, dev_acc = 0.9772
#
# Start Round 16 ...
# client_0: Loss = 0.0632, Accuracy = 0.98
# client_1: Loss = 0.0605, Accuracy = 0.9847
# client_2: Loss = 0.0667, Accuracy = 0.9797
# client_3: Loss = 0.0501, Accuracy = 0.9866
# client_4: Loss = 0.0632, Accuracy = 0.9798
# client_5: Loss = 0.0533, Accuracy = 0.9832
# client_6: Loss = 0.0624, Accuracy = 0.9828
# client_7: Loss = 0.0613, Accuracy = 0.9825
# After round 16, train_loss = 0.062, dev_loss = 0.0773, dev_acc = 0.9776
#
# Start Round 17 ...
# client_0: Loss = 0.0602, Accuracy = 0.982
# client_1: Loss = 0.0598, Accuracy = 0.9843
# client_2: Loss = 0.0637, Accuracy = 0.98
# client_3: Loss = 0.0494, Accuracy = 0.9863
# client_4: Loss = 0.0583, Accuracy = 0.9821
# client_5: Loss = 0.0521, Accuracy = 0.9828
# client_6: Loss = 0.06, Accuracy = 0.9839
# client_7: Loss = 0.0584, Accuracy = 0.9843
# After round 17, train_loss = 0.06, dev_loss = 0.0746, dev_acc = 0.9778
#
# Start Round 18 ...
# client_0: Loss = 0.0565, Accuracy = 0.9821
# client_1: Loss = 0.0551, Accuracy = 0.9856
# client_2: Loss = 0.0619, Accuracy = 0.9796
# client_3: Loss = 0.0469, Accuracy = 0.9864
# client_4: Loss = 0.0565, Accuracy = 0.9821
# client_5: Loss = 0.0473, Accuracy = 0.9852
# client_6: Loss = 0.0573, Accuracy = 0.9834
# client_7: Loss = 0.0557, Accuracy = 0.9837
# After round 18, train_loss = 0.0575, dev_loss = 0.0728, dev_acc = 0.979
#
# Start Round 19 ...
# client_0: Loss = 0.0549, Accuracy = 0.9828
# client_1: Loss = 0.0557, Accuracy = 0.9856
# client_2: Loss = 0.0593, Accuracy = 0.9811
# client_3: Loss = 0.0454, Accuracy = 0.9877
# client_4: Loss = 0.0559, Accuracy = 0.9833
# client_5: Loss = 0.0457, Accuracy = 0.9864
# client_6: Loss = 0.0552, Accuracy = 0.9862
# client_7: Loss = 0.0543, Accuracy = 0.9842
# After round 19, train_loss = 0.0563, dev_loss = 0.072, dev_acc = 0.9783
#
# Start Round 20 ...
# client_0: Loss = 0.0532, Accuracy = 0.9841
# client_1: Loss = 0.0546, Accuracy = 0.985
# client_2: Loss = 0.0568, Accuracy = 0.983
# client_3: Loss = 0.0432, Accuracy = 0.987
# client_4: Loss = 0.051, Accuracy = 0.9844
# client_5: Loss = 0.0451, Accuracy = 0.9866
# client_6: Loss = 0.0541, Accuracy = 0.9844
# client_7: Loss = 0.0519, Accuracy = 0.9856
# After round 20, train_loss = 0.0538, dev_loss = 0.0691, dev_acc = 0.9794
#
# Start Round 21 ...
# client_0: Loss = 0.0515, Accuracy = 0.9845
# client_1: Loss = 0.0518, Accuracy = 0.986
# client_2: Loss = 0.0554, Accuracy = 0.9828
# client_3: Loss = 0.0424, Accuracy = 0.9871
# client_4: Loss = 0.051, Accuracy = 0.9842
# client_5: Loss = 0.0424, Accuracy = 0.9858
# client_6: Loss = 0.0529, Accuracy = 0.9846
# client_7: Loss = 0.0495, Accuracy = 0.9857
# After round 21, train_loss = 0.0529, dev_loss = 0.0688, dev_acc = 0.9796
#
# Start Round 22 ...
# client_0: Loss = 0.0486, Accuracy = 0.9844
# client_1: Loss = 0.05, Accuracy = 0.986
# client_2: Loss = 0.0536, Accuracy = 0.9843
# client_3: Loss = 0.0404, Accuracy = 0.9884
# client_4: Loss = 0.0483, Accuracy = 0.9852
# client_5: Loss = 0.0419, Accuracy = 0.9877
# client_6: Loss = 0.0498, Accuracy = 0.9858
# client_7: Loss = 0.0493, Accuracy = 0.9853
# After round 22, train_loss = 0.0509, dev_loss = 0.0667, dev_acc = 0.9801
#
# Start Round 23 ...
# client_0: Loss = 0.0472, Accuracy = 0.985
# client_1: Loss = 0.0502, Accuracy = 0.987
# client_2: Loss = 0.0534, Accuracy = 0.983
# client_3: Loss = 0.0395, Accuracy = 0.9879
# client_4: Loss = 0.047, Accuracy = 0.9848
# client_5: Loss = 0.0405, Accuracy = 0.9883
# client_6: Loss = 0.0488, Accuracy = 0.9854
# client_7: Loss = 0.0462, Accuracy = 0.9859
# After round 23, train_loss = 0.0496, dev_loss = 0.0661, dev_acc = 0.9811
#
# Start Round 24 ...
# client_0: Loss = 0.0465, Accuracy = 0.9856
# client_1: Loss = 0.0472, Accuracy = 0.9884
# client_2: Loss = 0.0516, Accuracy = 0.9844
# client_3: Loss = 0.0372, Accuracy = 0.9898
# client_4: Loss = 0.0445, Accuracy = 0.9863
# client_5: Loss = 0.0389, Accuracy = 0.9876
# client_6: Loss = 0.0474, Accuracy = 0.9863
# client_7: Loss = 0.044, Accuracy = 0.9887
# After round 24, train_loss = 0.0481, dev_loss = 0.0647, dev_acc = 0.9809
#
# Start Round 25 ...
# client_0: Loss = 0.0445, Accuracy = 0.9862
# client_1: Loss = 0.0463, Accuracy = 0.9872
# client_2: Loss = 0.0485, Accuracy = 0.9846
# client_3: Loss = 0.0369, Accuracy = 0.9902
# client_4: Loss = 0.044, Accuracy = 0.9857
# client_5: Loss = 0.0374, Accuracy = 0.989
# client_6: Loss = 0.0451, Accuracy = 0.9864
# client_7: Loss = 0.0449, Accuracy = 0.9865
# After round 25, train_loss = 0.047, dev_loss = 0.0629, dev_acc = 0.9819
#
# Start Round 26 ...
# client_0: Loss = 0.0435, Accuracy = 0.9864
# client_1: Loss = 0.0454, Accuracy = 0.988
# client_2: Loss = 0.0482, Accuracy = 0.9856
# client_3: Loss = 0.0356, Accuracy = 0.9887
# client_4: Loss = 0.0425, Accuracy = 0.9862
# client_5: Loss = 0.0362, Accuracy = 0.9882
# client_6: Loss = 0.0451, Accuracy = 0.9876
# client_7: Loss = 0.0431, Accuracy = 0.9867
# After round 26, train_loss = 0.0461, dev_loss = 0.0627, dev_acc = 0.9828
#
# Start Round 27 ...
# client_0: Loss = 0.0413, Accuracy = 0.9864
# client_1: Loss = 0.0448, Accuracy = 0.9875
# client_2: Loss = 0.0463, Accuracy = 0.9859
# client_3: Loss = 0.035, Accuracy = 0.9907
# client_4: Loss = 0.0395, Accuracy = 0.9879
# client_5: Loss = 0.0351, Accuracy = 0.9884
# client_6: Loss = 0.045, Accuracy = 0.9867
# client_7: Loss = 0.0431, Accuracy = 0.9884
# After round 27, train_loss = 0.0447, dev_loss = 0.0615, dev_acc = 0.9824
#
# Start Round 28 ...
# client_0: Loss = 0.0395, Accuracy = 0.9879
# client_1: Loss = 0.0433, Accuracy = 0.9884
# client_2: Loss = 0.0446, Accuracy = 0.9852
# client_3: Loss = 0.0338, Accuracy = 0.9911
# client_4: Loss = 0.0385, Accuracy = 0.988
# client_5: Loss = 0.0343, Accuracy = 0.9899
# client_6: Loss = 0.0436, Accuracy = 0.9868
# client_7: Loss = 0.0405, Accuracy = 0.9885
# After round 28, train_loss = 0.0434, dev_loss = 0.0608, dev_acc = 0.9828
#
# Start Round 29 ...
# client_0: Loss = 0.0394, Accuracy = 0.9879
# client_1: Loss = 0.0418, Accuracy = 0.9895
# client_2: Loss = 0.0439, Accuracy = 0.9874
# client_3: Loss = 0.0319, Accuracy = 0.9904
# client_4: Loss = 0.0372, Accuracy = 0.9892
# client_5: Loss = 0.0337, Accuracy = 0.9905
# client_6: Loss = 0.0422, Accuracy = 0.9872
# client_7: Loss = 0.039, Accuracy = 0.9891
# After round 29, train_loss = 0.0426, dev_loss = 0.0595, dev_acc = 0.983
#
# Start Round 30 ...
# client_0: Loss = 0.0377, Accuracy = 0.9883
# client_1: Loss = 0.0421, Accuracy = 0.988
# client_2: Loss = 0.0437, Accuracy = 0.9863
# client_3: Loss = 0.0314, Accuracy = 0.9905
# client_4: Loss = 0.0373, Accuracy = 0.9892
# client_5: Loss = 0.0325, Accuracy = 0.99
# client_6: Loss = 0.0405, Accuracy = 0.9887
# client_7: Loss = 0.0386, Accuracy = 0.988
# After round 30, train_loss = 0.0416, dev_loss = 0.0588, dev_acc = 0.9837

# %%
plt.plot([i + 1 for i in range(len(history))], [history[i][0] for i in range(len(history))], color='r', label='train loss')
plt.plot([i + 1 for i in range(len(history))], [history[i][1] for i in range(len(history))], color='b', label='dev loss')
plt.legend()
plt.title('Training history')
plt.show()
