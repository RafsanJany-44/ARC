# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/CNU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_BA = pd.read_csv("/content/CNU_Abid_Organize_data_Biomass_12.02.2023_BA.csv")
df_BH = pd.read_csv("/content/CNU_Abid_Organize_data_Biomass_12.02.2023_BH.csv")

# %%
df_BA.insert(0, 'Condition', df_BA.pop('Condition'))
df_BH.insert(0, 'Condition', df_BH.pop('Condition'))

# %%
df_BA
# Out:
#            Condition  BA_No.  BA_Species BA_Shading BA_Watering BA_Biochar  \
# 0    0.55F W1 0BC F1     217  Blue Angel        55%          W1         0%
# 1    0.55F W1 0BC F1     271  Blue Angel        55%          W1         0%
# 2    0.55F W1 0BC F1     325  Blue Angel        55%          W1         0%
# 3    0.55F W1 0BC F1     379  Blue Angel        55%          W1         0%
# 4    0.55F W1 0BC F2     218  Blue Angel        55%          W1         0%
# ..               ...     ...         ...        ...         ...        ...
# 211   0F W3 0.2BC F2     431  Blue Angel         0%          W3        20%
# 212   0F W3 0.2BC F3     270  Blue Angel         0%          W3        20%
# 213   0F W3 0.2BC F3     324  Blue Angel         0%          W3        20%
# 214   0F W3 0.2BC F3     378  Blue Angel         0%          W3        20%
# 215   0F W3 0.2BC F3     432  Blue Angel         0%          W3        20%
#
#     BA_Fertilizer  BA_Replication BA_Location  BA_Leaf(g)  BA_Stem(g)  \
# 0              F1               1         GH1      5.8790      1.7010
# 1              F1               2         GH1      6.8547      2.1654
# 2              F1               3         GH2      4.9654      1.4508
# 3              F1               4         GH2      5.3337      2.0593
# 4              F2               1         GH1      5.7005      1.8205
# ..            ...             ...         ...         ...         ...
# 211            F2               4         GH2     10.4062      3.6789
# 212            F3               1         GH1     13.7584      7.3101
# 213            F3               2         GH1     17.0534      7.5260
# 214            F3               3         GH2     10.8292      3.6068
# 215            F3               4         GH2     13.5122      5.1243
#
#      BA_Root(g)  BA_R_HT  BA_R_RCD
# 0        1.2449    22.76     31.05
# 1        4.2971    17.60     24.68
# 2        2.6785    53.25     73.54
# 3        3.6644    65.91     76.28
# 4        2.8540    73.30     36.24
# ..          ...      ...       ...
# 211      4.9903    82.61     71.17
# 212      7.7402    69.20     77.76
# 213      8.0055    75.69    107.56
# 214      3.1085    47.48    130.39
# 215      4.1623    85.71    146.50
#
# [216 rows x 14 columns]

# %%
def get(df,col):
  d_avg={'0.55F W1 0BC F1':[],
  '0.55F W1 0BC F2':[],
  '0.55F W1 0BC F3':[],
  '0.55F W1 0.2BC F1':[],
  '0.55F W1 0.2BC F2':[],
  '0.55F W1 0.2BC F3':[],
  '0.55F W2 0BC F1':[],
  '0.55F W2 0BC F2':[],
  '0.55F W2 0BC F3':[],
  '0.55F W2 0.2BC F1':[],
  '0.55F W2 0.2BC F2':[],
  '0.55F W2 0.2BC F3':[],
  '0.55F W3 0.2BC F1':[],
  '0.55F W3 0.2BC F2':[],
  '0.55F W3 0.2BC F3':[],
  '0.55F W3 0BC F1':[],
  '0.55F W3 0BC F2':[],
  '0.55F W3 0BC F3':[],
  '0.35F W1 0BC F1':[],
  '0.35F W1 0BC F2':[],
  '0.35F W1 0BC F3':[],
  '0.35F W1 0.2BC F1':[],
  '0.35F W1 0.2BC F2':[],
  '0.35F W1 0.2BC F3':[],
  '0.35F W2 0BC F1':[],
  '0.35F W2 0BC F2':[],
  '0.35F W2 0BC F3':[],
  '0.35F W2 0.2BC F1':[],
  '0.35F W2 0.2BC F2':[],
  '0.35F W2 0.2BC F3':[],
  '0.35F W3 0BC F1':[],
  '0.35F W3 0BC F2':[],
  '0.35F W3 0BC F3':[],
  '0.35F W3 0.2BC F1':[],
  '0.35F W3 0.2BC F2':[],
  '0.35F W3 0.2BC F3':[],
  '0F W1 0BC F1':[],
  '0F W1 0BC F2':[],
  '0F W1 0BC F3':[],
  '0F W1 0.2BC F1':[],
  '0F W1 0.2BC F2':[],
  '0F W1 0.2BC F3':[],
  '0F W2 0BC F1':[],
  '0F W2 0BC F2':[],
  '0F W2 0BC F3':[],
  '0F W2 0.2BC F1':[],
  '0F W2 0.2BC F2':[],
  '0F W2 0.2BC F3':[],
  '0F W3 0BC F1':[],
  '0F W3 0BC F2':[],
  '0F W3 0BC F3':[],
  '0F W3 0.2BC F1':[],
  '0F W3 0.2BC F2':[],
  '0F W3 0.2BC F3':[]}



  for i in range(df.shape[0]):
    d_avg[df["Condition"][i]].append(df[col][i])

  return pd.DataFrame(d_avg)

# %%
df_temp = get(df_BA,'BA_R_RCD')

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#sns.set_theme(style="white")


d = df_temp
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(25, 25))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.7, cbar_kws={"shrink": .5})
# Out:
# <Axes: >
