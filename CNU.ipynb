# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/CNU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_BA = pd.read_csv("/content/CNU_Abid_Organize_data_Biomass_12.02.2023_BA.csv")
df_BH = pd.read_csv("/content/CNU_Abid_Organize_data_Biomass_12.02.2023_BH.csv")

# %%
df_BA.insert(0, 'Condition', df_BA.pop('Condition'))
df_BH.insert(0, 'Condition', df_BH.pop('Condition'))

# %%
def get(df,col):
  d_avg={'0.55F W1 0BC F1':[],
  '0.55F W1 0BC F2':[],
  '0.55F W1 0BC F3':[],
  '0.55F W1 0.2BC F1':[],
  '0.55F W1 0.2BC F2':[],
  '0.55F W1 0.2BC F3':[],
  '0.55F W2 0BC F1':[],
  '0.55F W2 0BC F2':[],
  '0.55F W2 0BC F3':[],
  '0.55F W2 0.2BC F1':[],
  '0.55F W2 0.2BC F2':[],
  '0.55F W2 0.2BC F3':[],
  '0.55F W3 0.2BC F1':[],
  '0.55F W3 0.2BC F2':[],
  '0.55F W3 0.2BC F3':[],
  '0.55F W3 0BC F1':[],
  '0.55F W3 0BC F2':[],
  '0.55F W3 0BC F3':[],
  '0.35F W1 0BC F1':[],
  '0.35F W1 0BC F2':[],
  '0.35F W1 0BC F3':[],
  '0.35F W1 0.2BC F1':[],
  '0.35F W1 0.2BC F2':[],
  '0.35F W1 0.2BC F3':[],
  '0.35F W2 0BC F1':[],
  '0.35F W2 0BC F2':[],
  '0.35F W2 0BC F3':[],
  '0.35F W2 0.2BC F1':[],
  '0.35F W2 0.2BC F2':[],
  '0.35F W2 0.2BC F3':[],
  '0.35F W3 0BC F1':[],
  '0.35F W3 0BC F2':[],
  '0.35F W3 0BC F3':[],
  '0.35F W3 0.2BC F1':[],
  '0.35F W3 0.2BC F2':[],
  '0.35F W3 0.2BC F3':[],
  '0F W1 0BC F1':[],
  '0F W1 0BC F2':[],
  '0F W1 0BC F3':[],
  '0F W1 0.2BC F1':[],
  '0F W1 0.2BC F2':[],
  '0F W1 0.2BC F3':[],
  '0F W2 0BC F1':[],
  '0F W2 0BC F2':[],
  '0F W2 0BC F3':[],
  '0F W2 0.2BC F1':[],
  '0F W2 0.2BC F2':[],
  '0F W2 0.2BC F3':[],
  '0F W3 0BC F1':[],
  '0F W3 0BC F2':[],
  '0F W3 0BC F3':[],
  '0F W3 0.2BC F1':[],
  '0F W3 0.2BC F2':[],
  '0F W3 0.2BC F3':[]}



  for i in range(df.shape[0]):
    d_avg[df["Condition"][i]].append(df[col][i])

  return pd.DataFrame(d_avg)



from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



def plot(d):
  corr = d.corr()

  # Generate a mask for the upper triangle
  mask = np.triu(np.ones_like(corr, dtype=bool))

  # Set up the matplotlib figure
  f, ax = plt.subplots(figsize=(15, 15))

  # Generate a custom diverging colormap
  cmap = sns.diverging_palette(230, 20, as_cmap=True)

  # Draw the heatmap with the mask and correct aspect ratio
  sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
              square=True, linewidths=.7, cbar_kws={"shrink": .5})

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# #BA_Leaf(g)

# %%
plot(get(df_BA,'BA_Leaf(g)'))

# %% [markdown]
# #BA_Stem(g)

# %%
plot(get(df_BA,'BA_Stem(g)'))

# %% [markdown]
# #BA_Root(g)

# %%
plot(get(df_BA,'BA_Root(g)'))

# %% [markdown]
# #BA_R_HT

# %%
plot(get(df_BA,'BA_R_HT'))

# %% [markdown]
# #BA_R_RCD

# %%
plot(get(df_BA,'BA_R_RCD'))

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
#
# ---

# %% [markdown]
# #BH_Leaf(g)

# %%
plot(get(df_BA,'BA_Leaf(g)'))

# %% [markdown]
# #BH_Stem(g)

# %%
plot(get(df_BA,'BA_Stem(g)'))

# %% [markdown]
# #BH_Root(g)

# %%
plot(get(df_BA,'BA_Root(g)'))

# %% [markdown]
# #BH_R_HT

# %%
plot(get(df_BA,'BA_R_HT'))

# %% [markdown]
# #	BH_R_RCD

# %%
plot(get(df_BA,'BA_R_RCD'))
