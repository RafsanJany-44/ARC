# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Gannt_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df  = pd.read_excel("/content/CSE299.xlsx")

# %%
df.shape
# Out:
# (13, 3)

# %%
df.head
# Out:
# <bound method NDFrame.head of                                      Task                 Date  No. of days
# 0                    Program Architecture  2023-07-24 00:00:00          7.0
# 1                      Dataset Collection  2023-07-31 00:00:00         21.0
# 2                        NLP Model Design  2023-08-21 00:00:00          7.0
# 3                               UI Design  2023-08-21 00:00:00          7.0
# 4                          Model Training  2023-08-28 00:00:00         14.0
# 5                       UI Implementation  2023-08-28 00:00:00         21.0
# 6                        Model Validation  2023-09-11 00:00:00          7.0
# 7                 Benchmark Engine Design  2023-09-11 00:00:00          7.0
# 8   Model Implementation in Main Software  2023-09-18 00:00:00          7.0
# 9                                 Testing  2023-09-25 00:00:00         36.0
# 10                                    NaN                  NaN          NaN
# ...

# %%
from datetime import datetime, date, timedelta
today = '2022-09-29'


print()
# Out:
# 2022-10-01 00:00:00

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame([
    dict(Task="<b>Program Architecture</b>", Start='2023-07-24', Finish=datetime.strptime('2023-07-24', '%Y-%m-%d') + timedelta(days=7),Resource="<b>All</b>"),
    dict(Task="<b>Dataset Collection</b>", Start='2023-07-31', Finish=datetime.strptime('2023-07-31', '%Y-%m-%d') + timedelta(days=28),Resource="<b>All</b>"),
    dict(Task="<b>NLP Model Design</b>", Start='2023-08-21', Finish=datetime.strptime('2023-08-21', '%Y-%m-%d') + timedelta(days=7),Resource="<b>Fahmida</b>"),
    dict(Task="<b>UI Design</b>", Start='2023-08-21', Finish=datetime.strptime('2023-08-21', '%Y-%m-%d') + timedelta(days=14),Resource="<b>Mehrub</b>"),
    dict(Task="<b>Model Training</b>", Start='2023-08-28', Finish=datetime.strptime('2023-08-28', '%Y-%m-%d') + timedelta(days=14),Resource="<b>All</b>"),
    dict(Task="<b>UI Implementation</b>", Start='2023-08-28', Finish=datetime.strptime('2023-08-28', '%Y-%m-%d') + timedelta(days=14),Resource="<b>Saif</b>"),
    dict(Task="<b>Model Validation</b>", Start='2023-09-11', Finish=datetime.strptime('2023-09-11', '%Y-%m-%d') + timedelta(days=7),Resource="<b>Fahmida</b>"),
    dict(Task="<b>Benchmark Engine Design</b>", Start='2023-09-11', Finish=datetime.strptime('2023-09-11', '%Y-%m-%d') + timedelta(days=14),Resource="<b>Fahmida</b>"),
    dict(Task="<b>Model Implementation in Main Software</b>", Start='2023-09-18', Finish=datetime.strptime('2023-09-18', '%Y-%m-%d') + timedelta(days=14),Resource="<b>Fahmida, Saif</b>"),
    dict(Task="<b>Testing</b>", Start='2023-09-25', Finish=datetime.strptime('2023-09-25', '%Y-%m-%d') + timedelta(days=7),Resource="<b>Saif,Mehrub</b>")
])

fig = px.timeline(df, x_start="Start", x_end="Finish", y="Task",color="Resource")
fig.update_yaxes(autorange="reversed") # otherwise tasks are listed from the bottom up
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame([
    dict(Task="Job A", Start='2009-01-01', Finish='2009-02-28', Resource="Alex"),
    dict(Task="Job B", Start='2009-03-05', Finish='2009-04-15', Resource="Alex"),
    dict(Task="Job C", Start='2009-02-20', Finish='2009-05-30', Resource="Max")
])

fig = px.timeline(df, x_start="Start", x_end="Finish", y="Task", color="Resource")
fig.update_yaxes(autorange="reversed")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
