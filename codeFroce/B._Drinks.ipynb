# %%
print((2/3)*100)

print('{0:.12f}'.format((2/3)*100))
# Out:
# 66.66666666666666
# 66.666666666667

# %%
ekta_shongkha=int(input())
shongkha_gulo=list(map(int,input().split()))
jog_fol=0
for i in range(ekta_shongkha):
  jog_fol=jog_fol+shongkha_gulo[i]

print('{0:.12f}'.format((jog_fol)/ekta_shongkha))
# Out:
# 3
# 50 50 100
# 66.666666666667
