# %%
n,a,b,c=map(int,input().split())
talika=[a,b,c]
h=list(set(talika))
if sum(talika)==n:
  print(3)
elif sum(talika)<n:
  print(n)
elif h[0]==n:
  print(1)
else:
  print(2)
# Out:
# 4 4 4 4
# [4]
# 1

# %%
print(int(4000/3))
print(int(4000/4))
print(int(4000/5))
print(int(1333*30))
# Out:
# 1333
# 1000
# 800
# 39990
