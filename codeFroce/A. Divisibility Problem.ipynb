# %%
n=int(input())
list1=[]
list2=[]

for i in range(n):
  a,b=map(int,input().split())
  if a%b==0:
    list1.append(0)
  else:
    ans=(int(a/b)+1)*b-a
    list1.append(ans)
print(*list1,sep='\n')
# 10 4 13 9 100 13 123 456 92 46
# Out:
# 5
# 10 4
# 13 9
# 100 13
# 123 456
# 92 46
# 2
# 5
# 4
# 333
# 0
