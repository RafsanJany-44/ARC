# %%
bakko=input()
ditio_bakko=bakko.replace("{",'')
ditio_bakko=ditio_bakko.replace("}",'')
ditio_bakko=ditio_bakko.replace(" ",'')
ditio_bakko=ditio_bakko.replace(",","")
print(len(set(ditio_bakko)))
# Out:
# {j, u, a, c, f, w, e, w, x, t, h, p, v, n, i, l, x, n, i, b, u, c, a, a}
# 16

# %%
ba=input()
print(len(set(ba)))
# Out:
# {a, a, c, b, b, b, c, c, c, c}
# 7
