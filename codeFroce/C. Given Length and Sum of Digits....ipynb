# %%
def sum2(list1):
  sum1=0
  for i in list1:
    sum1=sum1+int(i)
  return sum1
def string(list1):
  string=''
  for i in list1:
    string=string+i
  return string
n,k=map(int,input().split())
talika=[]
flag=1
r=10**(n-1)
while True:
  s=list(str(r))
  if sum2(s)==k:
   break
  elif len(s)>n:
    flag=0
    break
  r+=1

if flag==1:
  s.sort(reverse=True)
  print(r,string(s))
else:
  print(-1,-1)
# Out:
# 5 40
# 49999 99994

# %%
n=7
k=35
#print(10**(n-1)+(k-1)) # will work for 1-10 for k
#print(10**(n-1)+(k%10)*10+9) # will work for 11-19 for k
#print(10**(n-1)+(k%10)*100+199)# this will work for 20-29
print(10**(n-1)+(k%10)*1000+2999)# for 30 to 37
# Out:
# 1007999

# %%
def sum2(list1):
  sum1=0
  for i in list1:
    sum1=sum1+int(i)
  return sum1
def string(list1):
  string=''
  for i in list1:
    string=string+i
  return string
n=2
k=1
while True:
  print("k",k)
  talika=[]
  flag=1
  r=10**(n-1)
  while True:
    s=list(str(r))
    if sum2(s)==k:
      break
    elif len(s)>n:
      flag=0
      break
    r+=1

  if flag==1:
    print("r",r)
  else:
    print(-1,-1)
    break
  k+=1
  print("-------")
# Out:
# k 1
# r 10
# -------
# k 2
# r 11
# -------
# k 3
# r 12
# -------
# k 4
# r 13
# -------
# k 5
# r 14
# -------
# k 6
# r 15
# -------
# k 7
# r 16
# -------
# k 8
# r 17
# -------
# k 9
# r 18
# -------
# k 10
# r 19
# -------
# k 11
# r 29
# -------
# k 12
# r 39
# -------
# k 13
# r 49
# -------
# k 14
# r 59
# -------
# k 15
# r 69
# -------
# k 16
# r 79
# -------
# k 17
# r 89
# -------
# k 18
# r 99
# -------
# k 19
# -1 -1
