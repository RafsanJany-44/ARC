# %%
n,t=map(int,input().split())
a=list(map(int,input().split()))
talika=[]
index=0
for i in range(n-1):
  index=a[index]+index
  talika.append(index+1)
  if index>n-2:
    break
print( "YES" if t in talika else "NO")
# Out:
# 8 5
# 1 2 1 2 1 1 1
# NO
