# %%
talika=[]
for _ in range(int(input())):
  shongkha=int(input())
  if shongkha%2==0:
    talika.append(int(shongkha/2)-1)
  else:
    talika.append(int(shongkha/2))
print(*talika,sep='\n')
# Out:
# 6
# 7
# 1
# 2
# 3
# 2000000000
# 763243547
# 3
# 0
# 0.0
# 1
# 999999999.0
# 381621773
