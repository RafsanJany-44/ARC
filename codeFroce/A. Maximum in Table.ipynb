# %%
n=int(input())
t=[]
t2=[1]
for i in range(n):
  t.append(1)

for i in range(n-1):
  for j in range(n-1):
    t2.append(t[j+1]+t2[j])
  t=t2
  t2=[1]
print(max(t))
# Out:
# 3
# [1, 2, 3]
# [1, 3, 6]
# 6

# %%
# Out:
# [4, 3, 4, 5, 6]
