# %%
def prime(n):
  flag=1
  for i in range(2,n):
    if n%i==0:
      flag=0
      break
  return flag

# %%
print(prime(7))
# Out:
# 1

# %%
n=int(input())
k=int(n/2)

while True:
  m=n-k
  if prime(m)==1 or prime(k)==1:
    k=k-1
  else:
    break

print(m,k)
# Out:
# 12
# 6 6
