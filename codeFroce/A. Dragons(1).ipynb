# %%
#2 2
#1 99
#100 0
s,n=map(int,input().split())
for i in range(n):
  d,b=map(int,input().split())
  if s>=d:
    s=s+b
  else:
    s=0    
print("NO") if s==0 else print("YES")
# Out:
# 2 2
# 1 99
# 100 0
# YES

# %%
s,n=map(int,input().split())
for i in range(n):
  d,b=map(int,input().split())
  if s>=d:
    s=s+b
  else:
    s=0
print("NO") if s==0 else print("YES")
