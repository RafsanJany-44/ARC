# %%
t=int(input())
for _ in range(t):
  a,b=map(int,input().split())
  if (a==1 and b!=1) or (a!=1 and b==1):
    print(((max(a,b))**2))
  else:
    g=((2*min(a,b))**2)
    print(g)
# Out:
# 3
# 5 7
# 70
# 3 2
# 12
# 3 2
# 12

# %%
print(max(3,3))
# Out:
# 3
