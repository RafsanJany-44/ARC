# %%
#3
#5 3 2

shongkha=int(input())
talika=list(map(int,input().split()))
jor_gonona=0
bejor_gonona=0
for i in range(shongkha):
  if talika[i]%2==0:
    jor_gonona+=1
    shuchi1=i
  else:
    bejor_gonona+=1
    shuchi2=i
if jor_gonona>bejor_gonona: 
  print(shuchi2+1) 
else: 
  print((shuchi1+1))
# Out:
# 3
# 5 3 2
# 3
