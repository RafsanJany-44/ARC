# %%
b=int(input())
b_step=sorted(list(map(int,input().split())))
g=int(input())
g_step=sorted(list(map(int,input().split())))
count=0
for i in b_step:
  for j in range(len(g_step)):
    if i==g_step[j] or abs(i-g_step[j])==1:
      count+=1
      g_step.pop(j)
      break
print(count)
# Out:
# 3
# 6 3 4
# 3
# 4 5 2
# 3

# %%
3
6 3 4
3
4 5 2     ans=3

# %%
# Out:
# -3
