# %%
#import timeit
#start=timeit.default_timer()
def samantor_dhara(i,n):
  return ((int((i+n)/2))*(int((n-i)/2)+1))
n = int(input())
if n%2==0:
    print(samantor_dhara(2,n)-samantor_dhara(1,n-1))
else:
    print(samantor_dhara(2,n-1)-samantor_dhara(1,n))

#stop=timeit.default_timer()

#print("Time : "+str(stop-start))

#4294967296
#2147483648
# Out:
# 10000000000001
# -5000000000001
