# %%
s=a+c+b+d
print(s)
# Out:
# I hate that I love it

# %%
n=int(input())
a="I hate "
b="I love "
c="that "
d="it"
y=''
for i in range(1,n+1):
    if i%2==0:
      y=y+b
    else:
      y=y+a
    if i==n:
      y=y+d
    else:
        y=y+c
print(y)
# Out:
# 100
# ...
