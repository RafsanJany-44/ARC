# %%
print(0%2)
# Out:
# 0

# %%
def raf(talika):
  even=0
  odd=0
  for i in range(n):
    if (i%2)!=(talika[i]%2):
      if (i%2)==0:
        even+=1
      else:
        odd+=1

  if even==0 and odd==0:
    return 0
  elif even>0 and odd>0:
    return min(even,odd)
  else:
    return -1

for _ in range(int(input())):
  n=int(input())
  print(raf(list(map(int,input().split()))))
# Out:
# 1
# 3
# 1 0 1
# 1

# %%
1000
1
0
1
1
2
0 0
2
1 0
2
0 1
2
1 1
3
0 0 0
3
1 0 0
3
0 1 0
3
1 1 0
3
0 0 1
3
1 0 1
3
0 1 1
3
1 1 1
4
0 0 0 0
4
1 0 0 0
4
0 1 0 0
4
1 1 0 0
4
0 0 1 0
4
1 0 1 0
4
0 1 1 0
4
1 1 1 0
4
