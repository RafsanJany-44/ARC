# %%
m,n=map(int,input().split())
gonona=0
x=m+n
while True:
  x=x-2
  if x<=2:
    break
if gonona%2==0:
  print("Malvika")
else:
  print("Akshat")
# Out:
# 3 3
# Malvika

# %%
print("Malvika") if (min(list(map(int,input().split()))))%2==0 else print("Akshat")
#compile your imagination......
# Out:
# 65 63
# Akshat
