# %%
for _ in range(int(input())):
  x,y,n=map(int,input().split())
  print(raf(x,y,n))
# Out:
# 1
# 17 8 54321
# 54323

# %%
def raf(x,y,n): 
    if (int(n/x)*x+y) <=n:
      return (int(n/x)*x+y)
    else:
      return (int(n/x)*x)-x+y    

print()
# Out:
# 12339
