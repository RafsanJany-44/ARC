# %%
def raf(n):
  i=0
  sum=0
  while True:
    sum=sum+2**i
    if n%sum==0 and sum!=1:
      break
    i+=1
  return int(n/sum)
t=int(input())
for _ in range(t):
  print(raf(int(input())))
# Out:
# 1
# 999999984
# 333333328
