# %%
def remove_at(i, s):
    return s[:i] + s[i+1:]

# %%
bakkangsho=input().replace('WUB'," ")
b=[]
j=1
for i in range(len(bakkangsho)-1):

  if bakkangsho[i]==' '==bakkangsho[i+j]:
    b.append(i)

print ("".join([char for idx, char in enumerate(bakkangsho) if idx not in b]))
# Out:
# WUBWUBABCWUB
#  ABC
