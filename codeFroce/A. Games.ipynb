# %%
bakko=list(map(int,input().split()))
bakko2=list(map(int,input().split()))
talika=[]
for i in range(len(bakko)):
  talika.append(bakko2.count(bakko[i]))
print(sum(talika))
# Out:
# 1 1
# 2 2
# 0
# [0, 0]

# %%
kotobar=int(input())
shagotik=[]
soforKari=[]
for i in range(kotobar):
  x,y=map(int,input().split())
  shagotik.append(x)
  soforKari.append(y)
talika=[]
for i in range(kotobar):
  talika.append(soforKari.count(shagotik[i]))
print(sum(talika))
#comPile your dreams, deBug your imaginations
# Out:
# 4
# 100 42
# 42 100
# 5 42
# 100 5
# 5

# %%
4
100 42
42 100
5 42
100 5
