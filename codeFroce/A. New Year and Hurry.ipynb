# %%
n,k=map(int,input().split())
remain=240-k
time=0
flag=0
for i in range(1,n+1):
  time=time+i*5
  if time>remain:
    flag=1
    break
print(i-1) if flag==1 else print(n)
# Out:
# 3 222
# 2

# %%
# Out:
# 3 222
# 2
