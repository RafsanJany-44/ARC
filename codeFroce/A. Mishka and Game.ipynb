# %%
n=int(input())
m=0
c=0
for _ in range(n):
  k,l=map(int,input().split())
  if k==l:
    continue
  elif k>l:
    m+=1
  elif k<l:
    c+=1
if m==c:
  print("Friendship is magic!^^")
elif m>c:
  print("Mishka")
elif c>m:
  print("Chris")
# Out:
# 3
# 4 6
# 3 2
# 4 1
# Mishka

# %%
print(m,c)
# Out:
# 1 1

# %%
3
3 5
2 1
4 2
