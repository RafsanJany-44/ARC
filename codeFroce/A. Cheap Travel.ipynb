# %%
n,m,a,b=map(int,input().split())
ans=b+a*(n-m)
print(ans)
# Out:
# 5 2 2 3
# 9

# %%
n,m,a,b=map(int,input().split())
i=1
while True:
  if (m*i)>n:
    break
  i+=1
raf=i*b
j=i-1
tut=(j*b+(n-j*m)*a)
talika=[raf,tut,n*a]
print(min(talika))
# Out:
# 9 3 3 10
# 27
