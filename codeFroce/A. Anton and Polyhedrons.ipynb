# %%
ovidhan={"Tetrahedron":4,"Cube":6,"Octahedron":8,"Dodecahedron":12,"Icosahedron":20}
kotobar=int(input())
jogfol=0
for i in range(kotobar):
  jogfol=jogfol+ovidhan[input()]
print(jogfol)
#compile your dream, deBug your imagination
# Out:
# 4
# Icosahedron
# Cube
# Tetrahedron
# Dodecahedron
# 42
