# %%
bakko=input()+input()
bakko=input()
print(sorted(bakko))
# Out:
# PAPAINOEL
# JOULUPUKKI
# ['A', 'A', 'E', 'I', 'I', 'J', 'K', 'K', 'L', 'L', 'N', 'O', 'O', 'P', 'P', 'P', 'U', 'U', 'U']

# %%
print("YES") if sorted(input()+input())==sorted(input()) else print("NO")
# Out:
# SANTACLAUS
# DEDMOROZ
# SANTAMOROZDEDCLAUS
# YES
