# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/practice_cell/blob/master/Kingston_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #12

# %%
x=int(input('Enter a number :'))
y=int(input('Enter another number :'))
if x>y:
    print(y)
    print(x)
else:
    print(x)
    print(y)
# Out:
# Enter a number :43
# Enter another number :23
# 23
# 43

# %% [markdown]
# #13

# %%
x=int(input('Enter a number less then 20 :'))
if x>=20 :
    print('Too high')
else:
    print('Thank you')
# Out:
# Enter a number less then 20 :11113
# Too high

# %% [markdown]
# #14

# %%
x=int(input('Enter a number between 10 and 20 :'))
if 10<=x<=20 :
    print('Thank you')
else:
    print('Incorrect answer')
# Out:
# Enter a number between 10 and 20 :12
# Thank you

# %% [markdown]
# #15

# %%
x=input('Enter your favourite color :')
if x=='Red' or x=='RED' or x=='red':
    print('I like red too')
else:
    print(' I dont like ',x,',I prefer red')
# Out:
# Enter your favourite color :Red
# I like red too

# %% [markdown]
# #16

# %%
x=input('Is it raining ?')

if x.lower()=='yes':
    y=input('Is it windy ?')
    if y.lower()=='yes':
      print('It is too windy for a umbrella')
    else:
      print("Take an umbrella")
else:
    print('Enjoy your day')
# Out:
# Is it raining ?yes
# Is it windy ?no
# Take an umbrella

# %% [markdown]
# #17

# %%
x=int(input('Enter your age :'))
if x>=18:
    print('You can vote')
elif x==17:
    print('You can learn to drive')
elif x==16:
    print('You can buy a lottery ticket')
else:
    print('You can go to Trick-or-Treating')
# Out:
# Enter your age :118
# You can vote

# %% [markdown]
# #18

# %%
x=int(input('Enter a number :'))
if x<10:
    print('Too low')
elif 10<=x<=20:
    print('Correct')
else:
    print('Too high')
# Out:
# Enter a number :23
# Too high

# %% [markdown]
# #19

# %%
x=int(input('enter 1 or 2 or 3 :'))
if x==1:
    print('Thank you')
elif x==2:
    print('Well done')
elif x==3:
    print('Correct')
else:
    print('Error message')
# Out:
# enter 1 or 2 or 3 :2
# Well done
