# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/cluster_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

# %%
import random

data_table={
    "x": random.sample(range(1, 150), 40),
    "y": random.sample(range(1, 150), 40)
}

data=pd.DataFrame(data_table)



plt.scatter(
   data["x"], data['y'],
   c='white', marker='o',
   edgecolor='red', s=30
)
plt.show()

# %%
data.head()
# Out:
#      x   y
# 0  135  85
# 1   19  38
# 2   79  76
# 3   47  42
# 4  102  46

# %%
num_of_cluster = 4
kmeans = KMeans(n_clusters=num_of_cluster)
kmeans.fit(data)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_

print(centroids)
print(labels)
# Out:
# [[ 33.11111111  37.77777778]
#  [119.875      106.125     ]
#  [ 63.58333333 107.41666667]
#  [123.27272727  36.63636364]]
# [1 0 2 0 3 2 2 3 0 1 2 3 0 1 0 3 0 1 1 3 2 3 1 2 2 2 3 2 0 0 0 2 3 3 1 3 3
#  2 2 1]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data['labels'] = labels
data
# Out:
#       x    y  labels
# 0   135   85       1
# 1    19   38       0
# 2    79   76       2
# 3    47   42       0
# 4   102   46       3
# 5    48  103       2
# 6    59  102       2
# 7   134   55       3
# 8    17   67       0
# 9    97   87       1
# 10   41  108       2
# 11  149    7       3
# 12   24   45       0
# 13   98  122       1
# 14   20   41       0
# 15   88   33       3
# 16   35   59       0
# 17  127   86       1
# 18  133   82       1
# 19   82   39       3
# 20   81  111       2
# 21  128   63       3
# 22  112  107       1
# 23   52   75       2
# 24   65  140       2
# 25   66   69       2
# 26  144   60       3
# 27   62  126       2
# 28   45   26       0
# 29   64    6       0
# 30   27   16       0
# 31   86  148       2
# 32  141   37       3
# 33  146   21       3
# 34  118  149       1
# 35  113   15       3
# 36  129   27       3
# 37   73  137       2
# 38   51   94       2
# 39  139  131       1

# %%
data['labels'] = labels




import random
get_colors = lambda n: ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(n)]
get_colors(num_of_cluster)





initial_group = data[data['labels']==0].plot( kind='scatter', x='x', y='y', color='DarkGreen', label="Group 1" )

for i in range(1,num_of_cluster):
   data[data['labels']==i].plot( kind='scatter', x='x', y='y', color=get_colors(num_of_cluster)[i], ax=initial_group, label="Group "+str(i) )







initial_group.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)


plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()
