# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Auto_mail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import smtplib
from email import message

# %%
from_addr = 'you@example.com'
to_addr = 'me@example.com'
subject = 'I just sent this email from Python!'
body = 'How neat is that?'

# %%
msg = message.Message()
msg.add_header('from', from_addr)
msg.add_header('to', to_addr)
msg.add_header('subject', subject)
msg.set_payload(body)

# %%
https://tonyteaches.tech/send-email-from-python/
