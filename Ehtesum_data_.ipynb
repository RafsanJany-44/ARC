# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Ehtesum_data_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('https://raw.githubusercontent.com/Ahtesham-Ibne-Mostafa/Gold_Mining/main/EEG_HMC_underscore.csv')

# %%
data.head(10)
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0           W         0.00051           8.74146        18.48195
# 1           W         0.00040          10.24000        17.48293
# 2           W         0.00036           9.74049        17.98244
# 3           W         0.00035          10.11512        17.60780
# 4           W         0.00033           9.74049        17.60780
# 5           W         0.00036          10.24000        16.98341
# 6          N1         0.00034          10.11512        17.85756
# 7          N1         0.00035          10.73951        17.60780
# 8          N1         0.00035           9.36585        17.60780
# 9          N2         0.00050          10.36488        16.60878
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293         8.24195        0.00071         19.73073
# 1                16.85854        10.61463        0.00051         17.23317
# ...

# %%
data.describe()
# Out:
#        MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# count   108451.000000     108451.000000   108451.000000
# mean         0.001315          9.083249       15.611500
# std          0.012327          1.954552        4.051531
# min          0.000000          0.124880        0.874150
# 25%          0.000370          8.366830       13.861460
# 50%          0.000590          9.116100       15.235120
# 75%          0.000940          9.865370       16.733660
# max          1.034330        127.875120      127.875120
#
#        Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# count           108451.000000   108451.000000  108451.000000    108451.000000
# mean                14.831974        9.080123       0.001250        17.282671
# std                  4.324595        5.159732       0.008012        14.226341
# min                  0.124880        0.124880       0.000000         6.243900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108451 entries, 0 to 108450
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Sleep_Stage             108451 non-null  object
#  1   MeanP_Alpha_F4          108451 non-null  float64
#  2   MedianF_Alpha_F4        108451 non-null  float64
#  3   MeanF_Alpha_F4          108451 non-null  float64
#  4   Spectral Edge_Alpha_F4  108451 non-null  float64
#  5   PeakF_Alpha_F4          108451 non-null  float64
#  6   MeanP_Beta_F4           108451 non-null  float64
#  7   MedianF_Beta_F4         108451 non-null  float64
#  8   MeanF_Beta_F4           108451 non-null  float64
#  9   Spectral Edge_Beta_F4   108451 non-null  float64
#  10  PeakF_Beta_F4           108451 non-null  float64
#  11  MeanP_Theta_F4          108451 non-null  float64
#  12  MedianF_Theta_F4        108451 non-null  float64
# ...

# %%
x=0
dict={'meanp_beta_f4'=[]}
for i in data['MeanP_Alpha_F4','MeanP_Beta_F4','MeanP_Gamma_O2',]:
    
    if i==0.000:
# Out:
#   File "<ipython-input-7-c36a3ce18af2>", line 2
#     dict={'meanp_beta_f4'=[]}
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Approach 1 : Dropping missing values column wise

# %%
a = data.dropna(axis = 1)

# %%
a.head()

# %%
a.info()

# %% [markdown]
# ## Dropping null values row waise

# %%
b=data.dropna(axis =0)

# %%
b.info()

# %% [markdown]
# ## Using Fillna() Method

# %%
cols = []

# %% [markdown]
# ## Using Imputer

# %%
data.isnull().sum()

# %% [markdown]
# ### searching indexes of zeros

# %%
# %%time
import csv
dict={}
with open("EEG_HMC_underscore.csv", 'r') as a:
    csv_reader=csv.reader(a)
    x=1
    for row in csv_reader:
        for column in row:
            index=0
            dict[column]=[]
            for i in data[column]:
                if i==0.0000:
                    dict[column].append(index)
                index+=1
            
        if x==1:
            break
dict1={}

count=0
for i in dict.keys():
    if dict[i]!=[]:
        count+=1
        dict1[i]=dict[i]
        data[i].replace(0.0000000,0.000001,inplace=True)
        print(i)
#print(dict1)
print(count)
# Out:
# MeanP_Alpha_F4
# MeanP_Beta_F4
# MeanP_Gamma_F4
# MeanP_Alpha_C4
# MeanP_Beta_C4
# MeanP_Gamma_C4
# MeanP_Alpha_O2
# MeanP_Beta_O2
# MeanP_Gamma_O2
# 9
# Wall time: 1.55 s

# %%
a=data['MeanP_Beta_F4']
for i in a :
    if i ==0.00000:
        print('f')
print('finish')
# Out:
# finish

# %% [markdown]
# ### Exporting csv file

# %%
data.to_csv('datas.csv', index=False)

# %%
import csv

def check(index):
    for i in range(index,index+15):                       
        if index<=i<=index+4 :
          try:
            x=round((float(row[i-10])/float(row[i-25])),5)
            talika.append(x)
          except:
            print("Zero found!!")
          finally:
            print("Rafsan vai pro!!")
            continue
        elif index+5<=i<=index+9:
          try:
            x=round((float(row[i-15])/float(row[i-20])),5)
            talika.append(x)
          except:
            print("Zero found!!")
          finally:
            print("Rafsan vai ultra pro!!!")
            continue
        elif index+10<=i<=index+14:
          try:
            x=round(((float(row[i-20])+float(row[i-25]))/(float(row[i-35])+float(row[i-30]))),5)
            talika.append(str(x))
          except:
            print("Zero found!!")
          finally:
            print("Rafsan vai ultra pro dual sim quad cemera!!!!!!")
            continue
with open("datas.csv", 'r') as a:
    csv_reader=csv.reader(a)
    
    with open("new.csv", 'w', newline='') as new_file:
        csv_writer=csv.writer(new_file)
        for row in csv_reader:
            talika=[]
            index=0
            for colum in row:
                index+=1
                talika.append(colum)
                if index==26:
                    talika+=['MeanP_DAR_F4','MedianF_DAR_F4','MeanF_DAR_F4','Spectral Edge_DAR_F4', 'PeakF_DAR_F4','MeanP_DTR_F4','MedianF_DTR_F4','MeanF_DTR_F4','Spectral Edge_DTR_F4', 'PeakF_DTR_F4','MeanP_DTABR_F4','MedianF_DTABR_F4','MeanF_DTABR_F4','Spectral Edge_DTABR_F4', 'PeakF_DTABR_F4']
                elif index==51:
                    talika+=['MeanP_DAR_C4','MedianF_DAR_C4','MeanF_DAR_C4','Spectral Edge_DAR_C4', 'PeakF_DAR_C4','MeanP_DTR_C4','MedianF_DTR_C4','MeanF_DTR_C4','Spectral Edge_DTR_C4', 'PeakF_DTR_C4','MeanP_DTABR_C4','MedianF_DTABR_C4','MeanF_DTABR_C4','Spectral Edge_DTABR_C4', 'PeakF_DTABR_C4']
                elif index==76:
                    talika+=['MeanP_DAR_O2','MedianF_DAR_O2','MeanF_DAR_O2','Spectral Edge_DAR_O2', 'PeakF_DAR_O2','MeanP_DTR_O2','MedianF_DTR_O2','MeanF_DTR_O2','Spectral Edge_DTR_O2', 'PeakF_DTR_O2','MeanP_DTABR_O2','MedianF_DTABR_O2','MeanF_DTABR_O2','Spectral Edge_DTABR_O2', 'PeakF_DTABR_O2']

            csv_writer.writerow(talika)
            break
        for row in csv_reader:
            index=0
            talika=[]
            for colum in row: 
                index+=1
                talika.append(colum)
                if index==26 :
                    check(index)
                elif index==51:
                    check(index)
                elif index==76:
                    check(index)
                            
            csv_writer.writerow(talika)
print('Finish')
# Out:
# Streaming output truncated to the last 5000 lines.
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai ultra pro dual sim quad cemera!!!!!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai pro!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro!!!
# Rafsan vai ultra pro!!!
# ...
