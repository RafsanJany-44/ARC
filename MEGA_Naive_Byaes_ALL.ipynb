# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/practice_cell/blob/master/MEGA_Naive_Byaes_ALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NAIVE BAYES

# %%
# On importe les librairies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,MultinomialNB,CategoricalNB

# %%
# On importe le dataset
f="/content/S_W.csv"
dataset = pd.read_csv(f)
dataset.head()

# %%
# On sépare notre dataframe en deux les inputs et les targets ( survived )
X = dataset.drop('Sleep_Stage',axis='columns')
Y = dataset.Sleep_Stage

# %%
# Identifier les colonnes ou il manque des données
X.columns[X.isna().any()]

# %%
X.describe()

# %%
X.fillna(X.mean(), inplace=True)
X.describe()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = CategoricalNB()

# %%
model.fit(X_train,y_train)

# %%
print(f)
print(model.score(X_train,y_train))
