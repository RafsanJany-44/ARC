# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Afdddfsfg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 01

# %% [markdown]
# The dataset contains information of several patients and their corresponding disease. Your task will be to clean this data , visualize it and perform mathematical operation to replace some missing values in the dataset.Please follow the below steps to complete the task:
#
# **(1)** Load the excel data file using pandas dataframe.
# **(2)** Print first 10 rows of the dataframe to identify the features.
# **(3)** Determine the datatype of the features and whether the data contains any missing values or not (Hint: Print summary of the dataframe).
# **(4)** If Symptomps of any patient or patients are missing then drop the entire record of those patients.
# **(5)** Print count values of each disease catagory to identify whether the dataset is balanced or not.
# **(6)** Create a new dataframe by taking only the Height, Weight and BMI columns of the data
# **(7)** Convert the dataframe into numpy array
# **(8)** Replace the missing BMI values in the array by using the height and weight of the patients. The formula for BMI is : weight / height^2
# **(9)** Replace the BMI column of the previous dataframe with newly obtained values(Hint: Convert the numpy array to a new dataframe giving same column names and replace the BMI column of the old dataframe with the new one)
# **(10)** Create a barplot of the patients based on their BMI.(4 catagories for the barplot: Underweight(<18.5), Normal(18.5-24.9), Overweight(25-29.9), Obese(>30)) )

# %% [markdown]
# (1) Load the excel data file using pandas dataframe.

# %%
import numpy as np
import pandas as pd

ass_data = pd.read_excel("/content/CSE445_Assignment01.xlsx")

# %% [markdown]
# (2) Print first 10 rows of the dataframe to identify the features

# %%
ass_data.head(10)
# Out:
#                                        Clinical_text          Disease  \
# 0  35 years old Masuma Begum is seeing change in ...  Cronh's Disease
# 1  Hanif Ahmed at the age of 55 presents to the c...  Cronh's Disease
# 2  Apu Sarker is a male of 32 years having fecal ...  Cronh's Disease
# 3  Samia Nasreen, a 24 years old female is having...  Cronh's Disease
# 4  43 years old Babu Das comes to the clinic for ...  Cronh's Disease
# 5  67 years old Abdullah is experiencing change i...  Cronh's Disease
# 6  Ridita Haque, a 19 years old female is having ...  Cronh's Disease
# 7  Nasir Hasan, a male of 60 years came to the cl...  Cronh's Disease
# 8  Hiya Tabassum, 23 years old female is experien...  Cronh's Disease
# 9  46 years old Runa Farhana presents to the clin...  Cronh's Disease
#
#                                             Symptoms  Height (m)  Weight (kg)  \
# 0                   ['burning sensations', 'sweats']        1.61           80
# 1  ['bowel incontinence', 'swelling', 'sweats', '...        1.63           59
# 2                  ['fecal incontinence', 'itching']        1.62           60
# 3                 ['bleeding', 'swelling', 'sweats']        1.71           53
# 4  ['fecal incontinence', 'sweats', 'itching sens...        1.64           69
# 5                   ['itching sensations', 'sweats']        1.77           92
# 6                            ['itching', 'swelling']        1.69           50
# 7       ['bowel incontinence', 'bleeding', 'sweats']        1.72           89
# 8                  ['itching', 'swelling', 'sweats']        1.64           74
# 9      ['bowel incontinence', 'swelling', 'itching']        1.69           66
#
#      BMI
# 0  30.86
# 1  22.21
# 2  22.86
# 3  18.13
# 4  25.65
# 5  29.37
# 6  17.51
# 7  30.08
# 8  27.51
# 9  23.11

# %% [markdown]
# (3) Determine the datatype of the features and whether the data contains any missing values or not (Hint: Print summary of the dataframe).

# %%
ass_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Clinical_text  359 non-null    object
#  1   Disease        359 non-null    object
#  2   Symptoms       354 non-null    object
#  3   Height (m)     359 non-null    float64
#  4   Weight (kg)    359 non-null    int64
#  5   BMI            349 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 17.0+ KB

# %% [markdown]
# (4) If Symptomps of any patient or patients are missing then drop the entire record of those patients.

# %%
ass_data.dropna(subset = ['Symptoms'], inplace=True)

# %%
ass_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 0 to 358
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Clinical_text  354 non-null    object
#  1   Disease        354 non-null    object
#  2   Symptoms       354 non-null    object
#  3   Height (m)     354 non-null    float64
#  4   Weight (kg)    354 non-null    int64
#  5   BMI            344 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 19.4+ KB

# %% [markdown]
# (5) Print count values of each disease catagory to identify whether the dataset is balanced or not.

# %%
ass_data["Disease"].value_counts()
# Out:
# Depression              60
# Hay Fever               55
# Parkinson's Disease     50
# Stress                  50
# Hepatitis B             50
# Raynaud's phenomenon    50
# Cronh's Disease         39
# Name: Disease, dtype: int64

# %% [markdown]
# (6) Create a new dataframe by taking only the Height, Weight and BMI columns of the data

# %%
new_ass_data = ass_data[["Height (m)","Weight (kg)","BMI"]]

# %%
new_ass_data
# Out:
#      Height (m)  Weight (kg)    BMI
# 0          1.61           80  30.86
# 1          1.63           59  22.21
# 2          1.62           60  22.86
# 3          1.71           53  18.13
# 4          1.64           69  25.65
# ..          ...          ...    ...
# 354        1.82           98  29.59
# 355        1.80           98  30.25
# 356        1.77           61  19.47
# 357        1.61           88  33.95
# 358        1.72           78  26.37
#
# [354 rows x 3 columns]

# %% [markdown]
# (7) Convert the dataframe into numpy array

# %%
np_data = new_ass_data.to_numpy()

print('\nNumpy Array\n----------\n', np_data)
print('\nNumpy Array Datatype :', np_data.dtype)
# Out:
# Numpy Array
# ----------
#  [[ 1.61 80.   30.86]
#  [ 1.63 59.   22.21]
#  [ 1.62 60.   22.86]
#  ...
#  [ 1.77 61.   19.47]
#  [ 1.61 88.   33.95]
#  [ 1.72 78.   26.37]]
#
# Numpy Array Datatype : float64

# %% [markdown]
# (8) Replace the missing BMI values in the array by using the height and weight of the patients. The formula for BMI is : weight / height^2

# %%
for i in np_data:
  if str(i[2]) == 'nan':
    i[2]=i[1]/i[0]**2


for i in np_data:
  print(i)
# Out:
# [ 1.61 80.   30.86]
# [ 1.63 59.   22.21]
# [ 1.62 60.   22.86]
# [ 1.71 53.   18.13]
# [ 1.64 69.   25.65]
# [ 1.77 92.   29.37]
# [ 1.69 50.   17.51]
# [ 1.72 89.   30.08]
# [ 1.64 74.   27.51]
# [ 1.69 66.   23.11]
# [ 1.64 88.   32.72]
# [ 1.81 96.   29.3 ]
# [ 1.63 60.   22.58]
# [ 1.74 57.   18.83]
# [ 1.76 60.   19.37]
# [ 1.78 54.   17.04]
# [ 1.64 60.   22.31]
# [ 1.68 83.   29.41]
# [ 1.69 64.   22.41]
# [ 1.69 81.   28.36]
# [ 1.73       86.         28.73467206]
# [ 1.72 77.   26.03]
# [  1.58 100.    40.06]
# [ 1.57 95.   38.54]
# [ 1.61 98.   37.81]
# [ 1.65 81.   29.75]
# [ 1.64 82.   30.49]
# [ 1.83 98.   29.26]
# [ 1.67 49.   17.57]
# [ 1.62 51.   19.43]
# [ 1.56 84.   34.52]
# [ 1.56 66.   27.12]
# [ 1.79 65.   20.29]
# [ 1.78 69.   21.78]
# [ 1.64 69.   25.65]
# [ 1.73 56.   18.71]
# [ 1.69 72.   25.21]
# [ 1.57 95.   38.54]
# [ 1.71 58.   19.84]
# [ 1.69 63.   22.06]
# [ 1.75 75.   24.49]
# [ 1.65       56.         20.56932966]
# [ 1.57 48.   19.47]
# [ 1.77 53.   16.92]
# [ 1.77 92.   29.37]
# [ 1.62 75.   28.58]
# [ 1.61 48.   18.52]
# [ 1.81 63.   19.23]
# [ 1.65 47.   17.26]
# [ 1.77 47.   15.  ]
# [ 1.74 90.   29.73]
# [ 1.77 82.   26.17]
# [ 1.71 66.   22.57]
# [ 1.82 58.   17.51]
# [ 1.61 66.   25.46]
# [ 1.58 94.   37.65]
# [ 1.57 62.   25.15]
# [ 1.81 96.   29.3 ]
# [ 1.56 51.   20.96]
# [ 1.79 55.   17.17]
# [ 1.68 87.   30.82]
# [ 1.71 91.   31.12]
# [ 1.77 81.   25.85]
# [ 1.7  67.   23.18]
# [ 1.79 77.   24.03]
# [ 1.76 53.   17.11]
# [ 1.58 76.   30.44]
# [ 1.73 60.   20.05]
# [ 1.65 54.   19.83]
# [ 1.77 52.   16.6 ]
# [ 1.56 66.   27.12]
# [ 1.8 69.  21.3]
# [ 1.73 76.   25.39]
# [ 1.72 67.   22.65]
# [ 1.59 87.   34.41]
# [  1.67 100.    35.86]
# [ 1.62 48.   18.29]
# [ 1.66 55.   19.96]
# [ 1.81 56.   17.09]
# [ 1.69 77.   26.96]
# [ 1.75 43.   14.04]
# [ 1.75 81.   26.45]
# [ 1.59 49.   19.38]
# [ 1.54 99.   41.74]
# [ 1.55 47.   19.56]
# [ 1.63 90.   33.87]
# [ 1.76 71.   22.92]
# [ 1.79 93.   29.03]
# [ 1.76 73.   23.57]
# [ 1.75 90.   29.39]
# [ 1.67 94.   33.71]
# [ 1.76 45.   14.53]
# [ 1.81 77.   23.5 ]
# [ 1.62 47.   17.91]
# [ 1.6  77.   30.08]
# [ 1.79 61.   19.04]
# [ 1.67 83.   29.76]
# [ 1.76 52.   16.79]
# [ 1.57 90.   36.51]
# [ 1.69 43.   15.06]
# [ 1.73 89.   29.74]
# [ 1.6  56.   21.88]
# [ 1.73 51.   17.04]
# [ 1.81 61.   18.62]
# [ 1.64 69.   25.65]
# [ 1.71 78.   26.67]
# [ 1.63 86.   32.37]
# [ 1.64 73.   27.14]
# [ 1.64 76.   28.26]
# [ 1.58 61.   24.44]
# [ 1.63 90.   33.87]
# [ 1.61 50.   19.29]
# [ 1.7  74.   25.61]
# [ 1.67 77.   27.61]
# [ 1.65 85.   31.22]
# [  1.58 100.    40.06]
# [ 1.59 64.   25.32]
# [ 1.59 50.   19.78]
# [ 1.66 94.   34.11]
# [ 1.81 69.   21.06]
# [ 1.7 87.  30.1]
# [ 1.67 98.   35.14]
# [ 1.56 69.   28.35]
# [ 1.71 67.   22.91]
# [ 1.61 47.   18.13]
# [ 1.78 91.   28.72]
# [ 1.6  83.   32.42]
# [ 1.55 51.   21.23]
# [ 1.76 65.   20.98]
# [ 1.78 95.   29.98]
# [ 1.58 73.   29.24]
# [ 1.67 60.   21.51]
# [ 1.83 60.   17.92]
# [ 1.72 57.   19.27]
# [ 1.71 71.   24.28]
# [ 1.8  48.   14.81]
# [ 1.56 68.   27.94]
# [ 1.82 73.   22.04]
# [ 1.62 94.   35.82]
# [ 1.72 45.   15.21]
# [ 1.56 81.   33.28]
# [ 1.65 50.   18.37]
# [ 1.66 58.   21.05]
# [ 1.8  94.   29.01]
# [ 1.68 53.   18.78]
# [ 1.7 76.  26.3]
# [ 1.68 53.   18.78]
# [ 1.58 48.   19.23]
# [ 1.69 44.   15.41]
# [ 1.82 76.   22.94]
# [ 1.57 64.   25.96]
# [ 1.67 82.   29.4 ]
# [ 1.7  73.   25.26]
# [ 1.7  86.   29.76]
# [ 1.59 64.   25.32]
# [ 1.75 83.   27.1 ]
# [ 1.66 73.   26.49]
# [ 1.63 89.   33.5 ]
# [ 1.82 51.   15.4 ]
# [ 1.65 95.   34.89]
# [ 1.56 99.   40.68]
# [ 1.59 44.   17.4 ]
# [ 1.6 53.  20.7]
# [ 1.68 59.   20.9 ]
# [ 1.73 53.   17.71]
# [ 1.78 60.   18.94]
# [ 1.59 82.   32.44]
# [ 1.82 79.   23.85]
# [ 1.8  76.   23.46]
# [ 1.72 43.   14.53]
# [ 1.64 65.   24.17]
# [ 1.63 55.   20.7 ]
# [ 1.63 72.   27.1 ]
# [ 1.61 91.   35.11]
# [ 1.55 93.   38.71]
# [ 1.66 79.   28.67]
# [ 1.65 65.   23.88]
# [ 1.6  89.   34.77]
# [ 1.69 60.   21.01]
# [ 1.58 67.   26.84]
# [ 1.61 66.   25.46]
# [ 1.72 75.   25.35]
# [ 1.66 54.   19.6 ]
# [ 1.55 80.   33.3 ]
# [  1.57 100.    40.57]
# [ 1.69 93.   32.56]
# [ 1.64 78.   29.  ]
# [ 1.71 55.   18.81]
# [ 1.55 87.   36.21]
# [ 1.74 82.   27.08]
# [ 1.55 90.   37.46]
# [ 1.56 47.   19.31]
# [ 1.67 90.   32.27]
# [ 1.74 46.   15.19]
# [ 1.77       50.         15.95965399]
# [ 1.72 58.   19.61]
# [ 1.55 47.   19.56]
# [ 1.72 43.   14.53]
# [ 1.66 57.   20.69]
# [ 1.68 81.   28.7 ]
# [ 1.72 60.   20.28]
# [ 1.67 93.   33.35]
# [ 1.68 74.   26.22]
# [ 1.72 70.   23.66]
# [ 1.56 58.   23.83]
# [ 1.55 51.   21.23]
# [ 1.69 65.   22.76]
# [ 1.55 65.   27.06]
# [ 1.8 70.  21.6]
# [ 1.77 43.   13.73]
# [ 1.72 46.   15.55]
# [ 1.7  60.   20.76]
# [ 1.76 45.   14.53]
# [ 1.61 50.   19.29]
# [ 1.74 43.   14.2 ]
# [ 1.81 67.   20.45]
# [ 1.65 72.   26.45]
# [ 1.59 86.   34.02]
# [ 1.65 84.   30.85]
# [ 1.61 88.   33.95]
# [ 1.58 78.   31.24]
# [ 1.71       80.         27.35884546]
# [ 1.69 63.   22.06]
# [ 1.62 85.   32.39]
# [ 1.55 68.   28.3 ]
# [ 1.63 43.   16.18]
# [ 1.73 47.   15.7 ]
# [ 1.58 80.   32.05]
# [  1.57 100.    40.57]
# [ 1.77 88.   28.09]
# [ 1.59 43.   17.01]
# [ 1.63 72.   27.1 ]
# [ 1.56 85.   34.93]
# [ 1.78 73.   23.04]
# [ 1.75 77.   25.14]
# [ 1.69 86.   30.11]
# [ 1.77 98.   31.28]
# [ 1.74 85.   28.08]
# [ 1.69 66.   23.11]
# [ 1.64 89.   33.09]
# [ 1.76 92.   29.7 ]
# [ 1.71 82.   28.04]
# [ 1.59 96.   37.97]
# [ 1.69 54.   18.91]
# [ 1.73 88.   29.4 ]
# [ 1.77 75.   23.94]
# [ 1.63 65.   24.46]
# [ 1.78 88.   27.77]
# [ 1.61 45.   17.36]
# [ 1.7  44.   15.22]
# [ 1.71 97.   33.17]
# [ 1.79       63.         19.66230767]
# [ 1.74 84.   27.74]
# [ 1.73 92.   30.74]
# [ 1.69 87.   30.46]
# [ 1.81 83.   25.34]
# [ 1.62 83.   31.63]
# [ 1.72 81.   27.38]
# [ 1.54 62.   26.14]
# [ 1.59 78.   30.85]
# [ 1.72 87.   29.41]
# [ 1.6  95.   37.11]
# [ 1.8 58.  17.9]
# [ 1.61 73.   28.16]
# [ 1.67 53.   19.  ]
# [ 1.65 83.   30.49]
# [ 1.81 98.   29.91]
# [ 1.75 78.   25.47]
# [ 1.61 88.   33.95]
# [ 1.79 63.   19.66]
# [ 1.82 62.   18.72]
# [ 1.82 73.   22.04]
# [ 1.8        82.         25.30864198]
# [ 1.79 63.   19.66]
# [ 1.71 59.   20.18]
# [ 1.54 90.   37.95]
# [ 1.79 70.   21.85]
# [ 1.8  73.   22.53]
# [ 1.57 79.   32.05]
# [ 1.55 72.   29.97]
# [ 1.7  62.   21.45]
# [ 1.64 56.   20.82]
# [ 1.66 73.   26.49]
# [ 1.56 49.   20.13]
# [ 1.71 53.   18.13]
# [ 1.6  91.   35.55]
# [ 1.59 80.   31.64]
# [ 1.67 84.   30.12]
# [ 1.57 63.   25.56]
# [ 1.68 58.   20.55]
# [ 1.79 45.   14.04]
# [ 1.68 66.   23.38]
# [ 1.72 57.   19.27]
# [ 1.83 71.   21.2 ]
# [ 1.57 82.   33.27]
# [ 1.67 92.   32.99]
# [ 1.55 46.   19.15]
# [  1.64 100.    37.18]
# [ 1.75       43.         14.04081633]
# [ 1.78 92.   29.04]
# [ 1.61 57.   21.99]
# [  1.78 100.    31.56]
# [ 1.72 88.   29.75]
# [ 1.77 93.   29.68]
# [ 1.63 89.   33.5 ]
# [ 1.63 56.   21.08]
# [ 1.6  65.   25.39]
# [ 1.56 54.   22.19]
# [ 1.56 49.   20.13]
# [ 1.71 71.   24.28]
# [ 1.56 65.   26.71]
# [ 1.66 97.   35.2 ]
# [ 1.66 70.   25.4 ]
# [ 1.63       97.         36.50871316]
# [ 1.71 43.   14.71]
# [ 1.61 91.   35.11]
# [ 1.75 66.   21.55]
# [ 1.66 81.   29.39]
# [ 1.57 87.   35.3 ]
# [ 1.83 88.   26.28]
# [ 1.64 62.   23.05]
# [ 1.67 58.   20.8 ]
# [ 1.58 49.   19.63]
# [ 1.75 66.   21.55]
# [ 1.83 78.   23.29]
# [ 1.74 82.   27.08]
# [ 1.55 45.   18.73]
# [ 1.8  77.   23.77]
# [ 1.54 76.   32.05]
# [ 1.72       65.         21.97133586]
# [ 1.77 57.   18.19]
# [ 1.54 43.   18.13]
# [ 1.74 85.   28.08]
# [ 1.76 78.   25.18]
# [ 1.74 45.   14.86]
# [ 1.7        59.         20.41522491]
# [ 1.83 83.   24.78]
# [ 1.74 86.   28.41]
# [ 1.67 48.   17.21]
# [ 1.68 52.   18.42]
# [ 1.79 50.   15.61]
# [ 1.62 92.   35.06]
# [ 1.75 65.   21.22]
# [ 1.77 92.   29.37]
# [ 1.79 46.   14.36]
# [ 1.7  95.   32.87]
# [ 1.73 45.   15.04]
# [ 1.66 61.   22.14]
# [ 1.62 62.   23.62]
# [ 1.82 98.   29.59]
# [ 1.8  98.   30.25]
# [ 1.77 61.   19.47]
# [ 1.61 88.   33.95]
# [ 1.72 78.   26.37]

# %% [markdown]
# (9) Replace the BMI column of the previous dataframe with newly obtained values(Hint: Convert the numpy array to a new dataframe giving same column names and replace the BMI column of the old dataframe with the new one)

# %%
new_df = pd.DataFrame(np_data, columns=['Height (m)', 'Weight (kg)', 'BMI'])
ass_data['BMI']=new_df['BMI'].values
ass_data
# Out:
#                                          Clinical_text          Disease  \
# 0    35 years old Masuma Begum is seeing change in ...  Cronh's Disease
# 1    Hanif Ahmed at the age of 55 presents to the c...  Cronh's Disease
# 2    Apu Sarker is a male of 32 years having fecal ...  Cronh's Disease
# 3    Samia Nasreen, a 24 years old female is having...  Cronh's Disease
# 4    43 years old Babu Das comes to the clinic for ...  Cronh's Disease
# ..                                                 ...              ...
# 354  A 63 years old male named Mofiz Sarker is havi...        Hay Fever
# 355  56 years old Shirin Begum is experiencing decr...        Hay Fever
# 356  Nadia Rahman, a 37 years old female presents t...        Hay Fever
# 357  Mashrafi Rahim, 39 years old male has red eyes...        Hay Fever
# 358  Tasmiah Akhter is a 43 years old female with c...        Hay Fever
#
#                                               Symptoms  Height (m)  \
# 0                     ['burning sensations', 'sweats']        1.61
# 1    ['bowel incontinence', 'swelling', 'sweats', '...        1.63
# 2                    ['fecal incontinence', 'itching']        1.62
# 3                   ['bleeding', 'swelling', 'sweats']        1.71
# 4    ['fecal incontinence', 'sweats', 'itching sens...        1.64
# ..                                                 ...         ...
# 354                                 ['blurred vision']        1.82
# 355                  ['itching', 'bad taste in mouth']        1.80
# 356                    ['blurred vision', 'dizziness']        1.77
# 357                      ['cloudy vision', 'bruising']        1.61
# 358       ['cloudy vision', 'dizziness', 'irritation']        1.72
#
#      Weight (kg)    BMI
# 0             80  30.86
# 1             59  22.21
# 2             60  22.86
# 3             53  18.13
# 4             69  25.65
# ..           ...    ...
# 354           98  29.59
# 355           98  30.25
# 356           61  19.47
# 357           88  33.95
# 358           78  26.37
#
# [354 rows x 6 columns]

# %% [markdown]
# (10) Create a barplot of the patients based on their BMI.(4 catagories for the barplot: Underweight(<18.5), Normal(18.5-24.9), Overweight(25-29.9), Obese(>30)) )

# %%
import numpy as np
import matplotlib.pyplot as plt

uw=0
norm=0
over=0
ob=0

for i in ass_data['BMI']:
  if i<18.5:
    uw+=1
  if 18.5<=i<=24.9:
    norm+=1
  if 25<=i<=29.9:
    over+=1
  if 30<=i:
    ob+=1

data = {'Underweight':uw, 'Normal':norm, 'Overweight':over,
        'Obese':ob}

type_bmi = list(data.keys())
counts = list(data.values())

plt.bar(type_bmi, counts, color ='coral',
        width = 0.4)

plt.xlabel("Type")
plt.ylabel("Count")
plt.show()
