# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/PAIED_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


# a function to genarate list of 50 numbers
def genarate_number():             
  uniqe=[]             
  for i in range(0,50):
    num = random.randint(0,10000)
    if num not in uniqe:
      uniqe.append(num)
  return uniqe

def begin():     #Start and How to play
  print("-------------Welcome-------------")
  print("-----------Math Is FUN-----------")
  print()
  print("How to Play: Questions related to simple math problem will be given. You can chose how many questions you will answer.")
  print(" According to diffrent mathematical oparators, you can chose types of your questions.")
  print()


def decision():       #type of questions
  print("Questions Type:")
  print("Enter:")
  print("----- 1 (+).")
  print("----- 2 (-).")
  print("----- 3 (*).")
  print("----- 4 (/).")
  print("----- 5 (%).")
  print("----- 6 (exponent, '/')")
  print("----- 7 (floor division and multiplication)")
  print("----- 8 ('-','%').")
  print("----- 0 for Exit.")
  return int(input())


#Question Quantity
def Questions_Quantity(): 
  return int(input("Enter Question Quantity:"))     



#questions making
def Question_Genarator(li,questions_quantity,op):     
  correct_ans=0                             
  incorrect_ans=0                              
  for i in range(1,questions_quantity+1):
    
    i1=random.randint(0,len(li)-1)     
    i2=random.randint(0,len(li)-1)
    
    #Addition
    if "+" in op:
      print("********************************************************")
      print("Question No."+str(i)+". Find "+str(li[i1])+" + "+str(li[i2])+"=?")
      answer=input()
      if(answer==str(li[i1]+li[i2])):
        print("The Answer is Correct")
        correct_ans+=1
      else:
        print("The Answer is Incorrect")
        print("The correct answer is: ",li[i1]+li[i2])
        incorrect_ans+=1
      print()
    
    
    #Substraction
    elif "-" in op:
      print("********************************************************")
      print("Question No."+str(i)+". Find "+str(li[i1])+" - "+str(li[i2])+"=?")
      answer=input()
      if(answer==str(li[i1]-li[i2])):
        print("The Answer is Correct")
        correct_ans+=1
      else:
        print("The Answer is Incorrect")
        print("The correct answer is: ",li[i1]-li[i2])
        incorrect_ans+=1
      print()
    
    
    #Multiplication
    elif "*" in op:
      print("********************************************************")
      print("Question No."+str(i)+". Find "+str(li[i1])+" * "+str(li[i2])+"=?")
      answer=input()
      if(answer==str(li[i1]*li[i2])):
        print("The Answer is Corrct")
        correct_ans+=1
      else:
        print("The Answer is Incorrect")
        print("The correct answer is: ",li[i1]*li[i2])
        incorrect_ans+=1
      print()
    
    
    #devidation
    elif "/" in op:
      print("********************************************************")
      print("Question No."+str(i)+". Find "+str(li[i1])+" / "+str(li[i2])+"=?")
      answer=input()
      if(answer=="{:.2f}".format(li[i1]/li[i2])):
        print("The Answer is Correct")
        correct_ans+=1
      else:
        print("The Answer is Incorrect")
        print("The correct answer is: "+"{:.2f}".format(li[i1]/li[i2]))
        incorrect_ans+=1
      print()
    
    
    #exponent and multiplication.
    elif "**" in op and "*" in op:
      d=r.randint(0,1)
      if d==0:            
        print("********************************************************")
        print("Question No."+str(i)+". Find "+str(li[i1])+" ^ "+str(li[i2])+"=?")
        answer=input()
        if(answer==str(li[i1]**li[i2])):
          print("The Answer is Correct")
          correct_ans+=1
        else:
          print("The Answer is Incorrect")
          print("The correct answer is: ",li[i1]**li[i2])
          incorrect_ans+=1
          print()
      else:
        print("********************************************************")
        print("Question No."+str(i)+". Find "+str(li[i1])+" * "+str(li[i2])+"=?")
        answer=input()
        if(answer==str(li[i1]*li[i2])):
          print("The Answer is Correct")
          correct_ans+=1
        else:
          print("The Answer is Incorrect")
          print("The correct answer is: ",li[i1]*li[i2])
          incorrect_ans+=1
          print()
    
    
    #floor division and multiplication.
    elif "/" in op and "*" in op:
      d=r.randint(0,1)
      if d==0:          
        print("********************************************************")
        print("Question No."+str(i)+". Find "+str(li[i1])+" / "+str(li[i2])+"=?")
        answer=input()
        if(answer=="{:.2f}".format(li[i1]/li[i2])):
          print("The Answer is Correct")
          correct_ans+=1
        else:
          print("The Answer is Incorrect")
          print("The correct answer is: "+"{:.2f}".format(li[i1]/li[i2]))
          incorrect_ans+=1
          print()
      else:
        print("********************************************************")
        print("Question No."+str(i)+". Find "+str(li[i1])+" * "+str(li[i2])+"=?")
        answer=input()
        if(answer==str(li[i1]*li[i2])):
          print("The Answer is Correct")
          correct_ans+=1
        else:
          print("The Answer is Incorrect")
          print("The correct answer is: ",li[i1]*li[i2])
          incorrect_ans+=1
          print()
    
    
    #fsubtraction and modulo
    elif "%" in op and "-" in op:
      d=random.randint(0,1)
      if d==0:         
        print("********************************************************")
        print("Question No."+str(i)+". Find "+str(li[i1])+" % "+str(li[i2])+"=?")
        answer=input()
        if(answer=="{:.2f}".format(li[i1]%li[i2])):
          print("The Answer is Correct")
          correct_ans+=1
        else:
          print("The Answer is Incorrect")
          print("The correct answer is: ",li[i1]%li[i2])
          incorrect_ans+=1
          print()
      else:
        print("********************************************************")
        print("Question No."+str(i)+". Find "+str(li[i1])+" - "+str(li[i2])+"=?")
        answer=input()
        if(answer==str(li[i1]-li[i2])):
          print("The Answer is Correct")
          correct_ans+=1
        else:
          print("The Answer is Incorrect")
          print("The correct answer is: ",li[i1]-li[i2])
          incorrect_ans+=1
          print()
    elif "%%" in op:
      print("********************************************************")
      per=random.randint(1,100)          
      print("Question No."+str(i)+". What is the "+str(per)+"% of "+str(li[i2])+"=?")
      answer=input()
      if(answer=="{:.2f}".format((per/li[i2])*100)):
        print("The Answer is Correct")
        correct_ans+=1
      else:
        print("The Answer is Incorrect")
        print("The correct answer is: "+"{:.2f}".format((per/li[i2])*100))
        incorrect_ans+=1
      print()
  return correct_ans,incorrect_ans


#result
def Over_All(q,correct_ans,incorrect_ans):        
  percentage=(correct_ans/q)*100
  print("Total Questions: ",q)
  print("Correct Answer: ",correct_ans)
  print("Incorrect Answer: ",incorrect_ans)
  print("Rate of Success: "+"{:.1f}".format(percentage)+"%.")
  print()



#Main programm
begin()

while(1):
  print("********************************************************")
  dec=decision()
  if dec==0:
    break

  lis=genarate_number()
  dic={                         
      1:["+"],
      2:["-"],
      3:["*"],
      4:["/"],
      5:["%%"],
      6:["**","*"],
      7:["/","*"],
      8:["-","%"]
    }

  q=Questions_Quantity()
  correct_ans,incorrect_ans=Question_Genarator(lis,q,dic[dec])
  Over_All(q,correct_ans,incorrect_ans)



  print()
  print()
  print("TRY again? (yes/no)")
  if(input()=='no'):
    break


print("--------------------------Math is Fun--------------------------")
# Out:
# -------------Welcome-------------
# -----------Math Is FUN-----------
#
# How to Play: Questions related to simple math problem will be given. You can chose how many questions you will answer.
#  According to diffrent mathematical oparators, you can chose types of your questions.
#
# ********************************************************
# Questions Type:
# Enter:
# ----- 1 (+).
# ----- 2 (-).
# ----- 3 (*).
# ----- 4 (/).
# ----- 5 (%).
# ----- 6 (exponent, '/')
# ----- 7 (floor division and multiplication)
# ----- 8 ('-','%').
# ----- 0 for Exit.
# 5
# Enter Question Quantity:3
# ********************************************************
# Question No.1. What is the 66% of 3964=?
# 67
# The Answer is Incorrect
# The correct answer is: 1.66
#
# ********************************************************
# Question No.2. What is the 9% of 2550=?
# 54
# The Answer is Incorrect
# The correct answer is: 0.35
#
# ********************************************************
# ...

# %%
Cover Page

Introduction
Python is an interpreter-based, powerful full-programming language. Python is very popular for its simplicity and worldwide developer community. Guido van Rossum designed it between 1985 and 1990. Python programming is used in artificial intelligence, machine learning, data science, web development, etc. It’s an object-oriented programming language. The libraries are very extensive and well supported by the community. The simplicity of this language makes it more friendly to the beginner programmer. 

Integrated Development Environment
An IDE is an integrated development environment where developers have all the tools with a graphical interface for developing. For Python programming, there are lots of IDEs, such as PyCharm, Spider, Jupiter NoteBook, etc. For this project, I have used Jupiter NoteBook. Jupiter NoteBook is a very powerful IDE for Python development. The most advantageous feature of this IDE is that it provides block or section-wise execution and saves each instance. So the result can be found after execution. Another advantage is that any software is not needed for this. Jupiter NoteBook can be run in any browser. Jupiter NoteBook is easily customisable and shareable.

Python
Python has a large and extended community of developers. This made this language very user-friendly. Any beginner programmer can get any kind of help from this community. So there are always people around them to help with programming. The libraries are vast and easy to import and use. The syntax are easy to implement. Python provides clear readability to its users. So, the code is written in Python and is clean to be understood.

Mathematic Game
In this project a mathematical game is asked to be implemented with Python where user will chose the arithmetic and the number of questions. Then the code will generate a list size of 50. The list will contain random number of 0 to 10000. The program will select two number randomly and an arithmetic. Then it will show it to the user and ask for the correct answer. The user will give the answer and program will check it. If the answer is wrong then the program will show the correct answer with an appropriate message. If the answer is correct than the program will show a relevant message. This is a basic structure of the game. 


Fig: Flow Diagram


Pseudocode:

	•	Print welcome message
	•	Input choice
	•	Create num_list[50]
	•	dic={
	•	      1: [“+”],
	•	      2:[“-“],
	•	      3:[“*“],
	•	      4:[“/”],
	•	      5:[“%%”],
	•	      6:[“**”,”*’],
	•	      7:[“/“,”*”],
	•	      8:[“-“,”%”]
	•	}
	•	Input number_of_question
	•	right,wrong=Question_Genarator(num_list, question, dic[choice])
	•	Over_All(question, right, wrong)
	•	Input y/n
	•	If y
	•	 Then goto line 2
	•	Else
	•	 Goto line 22
	•	Print End Message
	•	End


Function starting() shows the welcome message. Function decision() shows the list of question types according to arithmetic expression.The function Question_Genarator() generates questions according to the user input. This function returns the number of right answers and wrong answers. The function Over_All() takes two parameters and generates result.
