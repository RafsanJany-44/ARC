# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Nahid_GUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title String fields

Input_DATA_Path = 'https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM.csv' #@param {type:"string"}
Select_Type = 'Single Prediction' #@param ["Single Prediction", "Series Prediction"]
Select_Algorithm = 'Random Forest' #@param ["Random Forest", "XGBoosting", "GradientBoosting"]


print(Input_DATA_Path)
print(Select_Type)
print(Select_Algorithm)
# Out:
# https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM.csv
# Series Prediction
# Random Forest

# %%
#@title String fields

Input_DATA_Path = 'https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM.csv' #@param {type:"string"}
Select_Type = 'Single Prediction' #@param ["Single Prediction", "Series Prediction"]
Select_Algorithm = 'XGBoosting' #@param ["Random Forest", "XGBoosting", "GradientBoosting"]


print(Input_DATA_Path)
print(Select_Type)
print(Select_Algorithm)
# Out:
# https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM.csv
# Single Prediction
# XGBoosting

# %%
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
import joblib


def load_model(model_name):
  return joblib.load(model_name)


model_path_dict = {
    "Random Forest": "/content/drive/MyDrive/Nahid/rf.sav",
    "XGBoosting": "/content/drive/MyDrive/Nahid/xgb.sav",
    "GradientBoosting": "/content/drive/MyDrive/Nahid/gb.sav"
}



dataset = pd.read_csv(Input_DATA_Path)
model = load_model(model_path_dict[Select_Algorithm])


if Select_Type == "Series Prediction"

# %%
# Out:
# '/content/drive/MyDrive/Nahid/xgb.sav'

# %%
dataset.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0        NREM         0.00034          10.11512        17.85756
# 1        NREM         0.00035          10.73951        17.60780
# 2        NREM         0.00035           9.36585        17.60780
# 3        NREM         0.00050          10.36488        16.60878
# 4        NREM         0.00072           9.36585        15.98439
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293        10.24000        0.00047         17.73268
# 1                17.10829         9.11610        0.00048         16.85854
# 2                16.98341         9.24098        0.00042         17.35805
# 3                15.85951         7.99220        0.00053         15.48488
# 4                15.48488         7.99220        0.00067         15.11024
#
#    MeanF_Beta_F4  Spectral Edge_Beta_F4  ...  MeanP_Delta_O2  \
# 0       25.35024               27.47317  ...         0.00112
# ...
