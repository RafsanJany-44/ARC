# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/AR_null_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


primary_dataset = pd.read_csv("/content/penguins.csv")

# %%
primary_dataset
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
primary_dataset.shape
# Out:
# (344, 17)

# %%
primary_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
list(primary_dataset.columns)
# Out:
# ['studyName',
#  'Sample Number',
#  'Species',
#  'Region',
#  'Island',
#  'Stage',
#  'Individual ID',
#  'Clutch Completion',
#  'Date Egg',
#  'Culmen Length (mm)',
#  'Culmen Depth (mm)',
#  'Flipper Length (mm)',
#  'Body Mass (g)',
#  'Sex',
#  'Delta 15 N (o/oo)',
#  'Delta 13 C (o/oo)',
#  'Comments']

# %%
seletec_col = [
 'Species',
 'Region',
 'Island',
 'Clutch Completion',
 'Culmen Length (mm)',
 'Culmen Depth (mm)',
 'Flipper Length (mm)',
 'Body Mass (g)',
 'Delta 15 N (o/oo)',
 'Delta 13 C (o/oo)']

# %%
primary_dataset = primary_dataset.loc[:,seletec_col]

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %% [markdown]
# #Checking Null/NaN Vlues

# %%
primary_dataset.isnull().sum()
# Out:
# Species                 0
# Region                  0
# Island                  0
# Clutch Completion       0
# Culmen Length (mm)      2
# Culmen Depth (mm)       2
# Flipper Length (mm)     2
# Body Mass (g)           2
# Delta 15 N (o/oo)      14
# Delta 13 C (o/oo)      13
# dtype: int64

# %% [markdown]
# #Filling Null/NaN Vlues with a specific value

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df1 = primary_dataset.fillna(6.12)

# %%
df1
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %% [markdown]
# #Filling Null/NaN with previous Value (row wise)

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df2 = primary_dataset.fillna(method = 'pad')

# %%
df2
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df2.isnull().sum()
# Out:
# Species                0
# Region                 0
# Island                 0
# Clutch Completion      0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Delta 15 N (o/oo)      1
# Delta 13 C (o/oo)      1
# dtype: int64

# %% [markdown]
# #Filling Null/NaN with next Value (row wise)

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df3 = primary_dataset.fillna(method = 'bfill')

# %%
df3
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %% [markdown]
# #Filling Null/NaN with next Value (col wise)

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df4 = primary_dataset.fillna(method='pad',axis=1)

# %%
df4
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %% [markdown]
# #<font color = 'cyan'>Fill Null/NaN value for diffrent columns with diffrent values

# %% [markdown]
# Delta 15 N (o/oo) - > 43.44<br>
# Delta 13 C (o/oo) - > 9.13

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df5 = primary_dataset.fillna({
    "Delta 15 N (o/oo)":43.44,
    "Delta 13 C (o/oo)":9.13
})

# %%
df5
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %% [markdown]
# #<font color = "coral">Filling Null/NaN with the mean value of column (only for that columns)

# %%
primary_dataset
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
df6 = primary_dataset.fillna({
    "Delta 15 N (o/oo)": primary_dataset["Delta 15 N (o/oo)"].mean(),
    "Delta 13 C (o/oo)": primary_dataset["Delta 13 C (o/oo)"].mean()
})

# %%
primary_dataset["Delta 13 C (o/oo)"].mean()
# Out:
# -25.6862915407855

# %%
df6
# Out:
#                                  Species  Region     Island Clutch Completion  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen               Yes
# ..                                   ...     ...        ...               ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe                No
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe               Yes
#
# ...

# %%
new_dataset = .........................
