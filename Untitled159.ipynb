# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Untitled159.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Connecting  Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Importing

# %%
import pandas as pd
import numpy as np
import glob
from tqdm.notebook import tqdm

# %% [markdown]
# #Setting Path

# %%
path = "/content/drive/MyDrive/Fahmida_Nourin/CSE_299-main/CSE_299-main"

# %% [markdown]
# #Get all paths in a list

# %%
all_files = glob.glob(path+"/*")

# %% [markdown]
# #Creating a Main dataframe with Comments and Type Columns

# %%
main_dataframe = pd.DataFrame(columns=["Comments","Type"])

# %% [markdown]
# #Concatinating

# %%
for i in tqdm(all_files):
  df = pd.read_excel(i)
  main_dataframe = pd.concat([main_dataframe,df[0:100]], ignore_index=True)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %% [markdown]
# #Droping NaN value containing Columns

# %%
main_dataframe = main_dataframe.drop(main_dataframe.columns[2:], axis=1)

# %%
main_dataframe
# Out:
#                                                Comments  Type
# 0     one suggestion is that never makes extra sound...   1.0
# 1                              thank you very much sir    1.0
# 2     most awaited topic from you. rest youtube vide...   1.0
# 3                                   amazing explanation   1.0
# 4                            waiting for the 2nd video!   1.0
# ...                                                 ...   ...
# 2631              thanks dave, i care for your efforts.   1.0
# 2632  hi dave ,how long did you work at the help des...   1.0
# 2633                      thanks man! you are the best!   1.0
# 2634      thanks for sharing your knowledge of linux...   1.0
# 2635  thanks for the tutorials idol. do you have you...   1.0
#
# [2636 rows x 2 columns]

# %% [markdown]
# #Saving File In Google Drive

# %%
main_dataframe.to_csv("Main_data.csv",index=False)
