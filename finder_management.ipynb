# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/finder_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install glob2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pytest-shutil
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
from glob import glob
import shutil

# %%
data_folder = "dataset"

# %%
d_i = os.path.join(data_folder,"dicom_inital")
d_i_images = os.path.join(d_i,"images")
d_i_labels = os.path.join(d_i,"labels")


d_f = os.path.join(data_folder, "dicom_final")
d_f_images = os.path.join(d_i,"images")
d_f_labels = os.path.join(d_i,"labels")

list_l = [os.path.join(data_folder,"dicom_inital"),
          os.path.join(d_i,"images"),
          os.path.join(d_i,"labels"),
          os.path.join(data_folder, "dicom_final"),
          os.path.join(d_i,"images"),
          os.path.join(d_i,"labels")
          ]

# %%
for i in list_l:
  print(i)
# Out:
# dataset/dicom_inital
# dataset/dicom_inital/images
# dataset/dicom_inital/labels
# dataset/dicom_final
# dataset/dicom_inital/images
# dataset/dicom_inital/labels

# %%
os.mkdir(data_folder)

# %%
glob(data_folder)
# Out:
# ['dataset']
