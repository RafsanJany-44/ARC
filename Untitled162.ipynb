# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Untitled162.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/weather.csv")
#df = pd.read_excel()

# %%
df.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
list(df.columns)
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RISK_MM',
#  'RainTomorrow']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %% [markdown]
# #Null value Dropping

# %%
df.dropna(axis = 0, how = 'any', inplace = True)

# %%
df = df.reset_index(drop = True)

# %%
df.tail(10)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 318      9.0     20.6       0.0          9.0       6.2         ENE
# 319      3.4     15.0       0.8          4.8      11.7           S
# 320      3.2     18.0       0.0          7.4      12.2         SSE
# 321      0.9     20.7       0.0          5.4       8.4         NNW
# 322      3.3     25.5       0.0          5.2      10.8           N
# 323      9.0     30.7       0.0          7.6      12.1         NNW
# 324      7.1     28.4       0.0         11.6      12.7           N
# 325     12.5     19.9       0.0          8.4       5.3         ESE
# 326     12.5     26.9       0.0          5.0       7.1          NW
# 327     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 318           39.0          S         SW          11.0  ...           28
# 319           70.0          S          S          35.0  ...           24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        328 non-null    float64
#  1   MaxTemp        328 non-null    float64
#  2   Rainfall       328 non-null    float64
#  3   Evaporation    328 non-null    float64
#  4   Sunshine       328 non-null    float64
#  5   WindGustDir    328 non-null    object
#  6   WindGustSpeed  328 non-null    float64
#  7   WindDir9am     328 non-null    object
#  8   WindDir3pm     328 non-null    object
#  9   WindSpeed9am   328 non-null    float64
#  10  WindSpeed3pm   328 non-null    int64
#  11  Humidity9am    328 non-null    int64
#  12  Humidity3pm    328 non-null    int64
#  13  Pressure9am    328 non-null    float64
#  14  Pressure3pm    328 non-null    float64
#  15  Cloud9am       328 non-null    int64
#  16  Cloud3pm       328 non-null    int64
# ...

# %%
df.shape
# Out:
# (328, 22)

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df["WindGustDir"].value_counts()
# Out:
# NW     64
# NNW    35
# E      34
# WNW    32
# ENE    29
# ESE    23
# S      21
# N      21
# NE     15
# W      15
# SSE    12
# SE     11
# NNE     7
# SSW     4
# SW      3
# WSW     2
# Name: WindGustDir, dtype: int64

# %%
df["WindGustDir"] = enc.fit_transform(df["WindGustDir"])

# %%
df["WindGustDir"].value_counts()
# Out:
# 7     64
# 6     35
# 0     34
# 14    32
# 1     29
# 2     23
# 8     21
# 3     21
# 4     15
# 13    15
# 10    12
# 9     11
# 5      7
# 11     4
# 12     3
# 15     2
# Name: WindGustDir, dtype: int64

# %%
df["WindDir9am"] = enc.fit_transform(df["WindDir9am"])
df["WindDir3pm"] = enc.fit_transform(df["WindDir3pm"])
df["RainToday"] = enc.fit_transform(df["RainToday"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        328 non-null    float64
#  1   MaxTemp        328 non-null    float64
#  2   Rainfall       328 non-null    float64
#  3   Evaporation    328 non-null    float64
#  4   Sunshine       328 non-null    float64
#  5   WindGustDir    328 non-null    int64
#  6   WindGustSpeed  328 non-null    float64
#  7   WindDir9am     328 non-null    int64
#  8   WindDir3pm     328 non-null    int64
#  9   WindSpeed9am   328 non-null    float64
#  10  WindSpeed3pm   328 non-null    int64
#  11  Humidity9am    328 non-null    int64
#  12  Humidity3pm    328 non-null    int64
#  13  Pressure9am    328 non-null    float64
#  14  Pressure3pm    328 non-null    float64
#  15  Cloud9am       328 non-null    int64
#  16  Cloud3pm       328 non-null    int64
# ...

# %%
df["RainTomorrow"].value_counts()
# Out:
# No     268
# Yes     60
# Name: RainTomorrow, dtype: int64

# %%
df["RainTomorrow"] = enc.fit_transform(df["RainTomorrow"])

# %%
df["RainTomorrow"].value_counts()
# Out:
# 0    268
# 1     60
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# #Dataset Slicing

# %% [markdown]
# loc -> index,column_name<br>
#
# `df.loc[starting_row:ending_row, [col names]]`<br>
#
#
#
# iloc-> index<br>
# `df.iloc[starting_row:ending_row, starting_col:ending_col]`

# %%
df2 = df.loc[100:210,["Rainfall","Evaporation","RISK_MM"]]

# %%
df2
# Out:
#      Rainfall  Evaporation  RISK_MM
# 100       0.0          4.0      0.0
# 101       0.0          5.8      0.0
# 102       0.0          5.0      4.4
# 103       4.4          6.6     11.0
# 104      11.0          3.2      0.2
# ..        ...          ...      ...
# 206       0.6          3.2      0.0
# 207       0.0          2.2      0.0
# 208       0.0          2.6      0.0
# 209       0.0          2.6      0.0
# 210       0.0          1.6      0.0
#
# [111 rows x 3 columns]

# %%
df2 = df.iloc[100:210,0:5]

# %%
df2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 100     10.4     20.9       0.0          4.0       8.9
# 101      9.1     23.1       0.0          5.8       9.6
# 102      8.9     26.0       0.0          5.0      10.7
# 103     14.5     24.2       4.4          6.6       5.9
# 104     12.6     18.2      11.0          3.2       0.4
# ..       ...      ...       ...          ...       ...
# 205      7.3     16.4       0.2          1.2       8.5
# 206      8.7     13.0       0.6          3.2       7.1
# 207      1.0     11.8       0.0          2.2       7.2
# 208      2.1     14.7       0.0          2.6       8.2
# 209      6.4     16.9       0.0          2.6       5.9
#
# [110 rows x 5 columns]

# %% [markdown]
# #Dataset SPliting

# %%
X = df.loc[:, df.columns != "RainTomorrow"]

# %%
X
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3            7
# 1       14.0     26.9       3.6          4.4       9.7            1
# 2       13.7     23.4       3.6          5.8       3.3            7
# 3       13.3     15.5      39.8          7.2       9.1            7
# 4        7.6     16.1       2.8          5.6      10.6           10
# ..       ...      ...       ...          ...       ...          ...
# 323      9.0     30.7       0.0          7.6      12.1            6
# 324      7.1     28.4       0.0         11.6      12.7            3
# 325     12.5     19.9       0.0          8.4       5.3            2
# 326     12.5     26.9       0.0          5.0       7.1            7
# 327     12.3     30.2       0.0          6.0      12.6            7
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# ...

# %%
y = df["RainTomorrow"]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 323    0
# 324    0
# 325    0
# 326    0
# 327    0
# Name: RainTomorrow, Length: 328, dtype: int64

# %% [markdown]
# #Spliting dataset into Training and testing set

# %%
from sklearn.model_selection import  train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (262, 21)

# %%
X_test.shape
# Out:
# (66, 21)

# %% [markdown]
# #RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# #Ada

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier()
clf.fit(X_train, y_train)



y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
0.7

# %% [markdown]
# #Deploy model

# %%
X.loc[101:101,:]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 101      9.1     23.1       0.0          5.8       9.6            1
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 101           41.0          10          13          17.0  ...           66
#
#      Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 101           37       1013.6       1011.4         1         7     14.0
#
#      Temp3pm  RainToday  RISK_MM
# 101     21.4          0      0.0
#
# [1 rows x 21 columns]

# %%
result = clf.predict(X.loc[101:101,:])

# %%
result
# Out:
# array([0])

# %%
clf
