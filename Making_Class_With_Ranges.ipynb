# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC/blob/master/Making_Class_With_Ranges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/Fitbit_feature_merged_version_2023.06.26_ST-II&ST-V_Pre.csv")

target = 'sd1'

# %%
df[target]
# Out:
# 0       6.012997
# 1       6.145682
# 2       6.782934
# 3       8.357614
# 4       9.978556
#           ...
# 2873    6.715103
# 2874    5.448991
# 2875    6.285354
# 2876    5.828536
# 2877    5.261615
# Name: sd1, Length: 2878, dtype: float64

# %%
round(df['Subject'].value_counts().sum()*0.8)
# Out:
# 1081

# %%
def sub_wise_splt(df,col,flage):
  total_count = len(set(df[col]))
  subjects=sorted(set(df[col]))

  train_axis = []
  test_axis = []

  count = 0

  for i in subjects:
    if count <= flage:
      train_axis.append(df.query(col+" == '"+i+"'"))
    else:
      test_axis.append(df.query(col+" == '"+i+"'"))
    count+=1

  return pd.concat(train_axis, axis=0),pd.concat(test_axis, axis=0)

# %%
train,test = sub_wise_splt(df,"Subject",20)

# %%
df.shape
# Out:
# (1351, 84)

# %%
train.shape
# Out:
# (858, 84)

# %%
test.shape
# Out:
# (493, 84)

# %%
pd.concat([df1, df2], axis=0)

# %%
df.query("Subject == '"+l[0]+"'")
# Out:
#     Subject Condition  Activity  Epoch Duration(min)  Epoch  \
# 826  001-JV       pre   Extreme                   10      1
# 827  001-JV       pre     Heavy                   10      1
# 828  001-JV       pre     Light                   10      1
# 829  001-JV       pre     Light                   10     10
# 830  001-JV       pre     Light                   10    100
# ..      ...       ...       ...                  ...    ...
# 990  001-JV       pre     Light                   10     95
# 991  001-JV       pre     Light                   10     99
# 992  001-JV       pre  Moderate                   10      1
# 993  001-JV       pre  Moderate                   10      2
# 994  001-JV       pre  Moderate                   10      3
#
#      ST-II Max. Increase  ST-II Max. decrease  ST-II Max-Min Difference  \
# 826                  0.5                  0.2                       0.7
# 827                  0.5                  0.2                       0.7
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
def target_filtering(df,target,thrashold):
  drop=[]
  for i in range(len(df[target])):
    if df[target][i] < thrashold:
      drop.append(i)
  df = df.drop(drop).reset_index(drop=True)
  return df

# %%
df = target_filtering(df,target,8)

# %%
df.head()
# Out:
#   Subject Condition Activity  Epoch Duration(min)  Epoch  ST-II Max. Increase  \
# 0  002-JR       pre    Light                   10     12                  0.2
# 1  002-JR       pre    Light                   10     13                  0.2
# 2  002-JR       pre    Light                   10      2                  0.2
# 3  002-JR       pre    Light                   10     21                  0.2
# 4  002-JR       pre    Light                   10     23                  0.2
#
#    ST-II Max. decrease  ST-II Max-Min Difference  ST-V Max. Increase  \
# 0                  0.3                       0.5                 0.3
# 1                  0.3                       0.5                 0.3
# 2                  0.3                       0.5                 0.3
# 3                  0.3                       0.5                 0.3
# 4                  0.3                       0.5                 0.3
#
#    ST-V Max. decrease  ...  ar_norm_high  ar_ratio     ar_total       sd1  \
# ...

# %%
from tqdm.notebook import tqdm


df = pd.read_csv("/content/Fitbit_feature_merged_version_2023.06.26_ST-II&ST-V_Pre.csv")

target = 'sd1'


print(df[target].min())
print(df[target].max())

for i in tqdm(range(len(df[target]))):

  #First condition
  if df[target][i] <= 5:
    df[target][i] = "class_1"

  #Second condition
  elif 6 <= df[target][i] <= 10:
    df[target][i] = "class_2"

  #Third condition
  elif 11 <= df[target][i] <= 15:
    df[target][i] = "class_3"

  #Fifth condition
  elif 16 <= df[target][i] <= 20:
    df[target][i] = "class_4"

  #Sixth condition
  elif 21 <= df[target][i] <= 25:
    df[target][i] = "class_5"

  #Seventh condition
  elif 26 <= df[target][i]:
    df[target][i] = "class_6"
# Out:
# 1.247397183
# 31.88234453
#   0%|          | 0/2878 [00:00<?, ?it/s]
# <ipython-input-112-f5699793d29c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[target][i] = "class_2"

# %%
df[target][i]
# Out:
# 'class_2'
